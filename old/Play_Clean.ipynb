# %% [markdown]
# # Clinical Trials Prediction Market Generator
#
# This notebook fetches behavioral intervention studies from ClinicalTrials.gov and generates prediction market questions.

# %%
# Import required libraries
import urllib.request
import urllib.parse
import json
import csv
from typing import Dict, List, Optional, Generator
from collections import Counter

# %%
PAGE_SIZE = 1000
MAX_PAGES = 5

# %% [markdown]
# ## API Functions

# %%
def fetch_studies(page_size: int = PAGE_SIZE, max_pages: int = MAX_PAGES, sleep_sec: float = 0.1) -> Generator[Dict, None, None]:
    """
    Fetch behavioral intervention studies from ClinicalTrials.gov API
    """
    BASE = "https://clinicaltrials.gov/api/v2/studies"
    
    fields = [
        "protocolSection.identificationModule.nctId",
        "protocolSection.identificationModule.briefTitle",
        "protocolSection.outcomesModule.primaryOutcomes",
        "protocolSection.conditionsModule.conditions",
        "protocolSection.armsInterventionsModule.interventions",
        "protocolSection.statusModule.overallStatus",
        "protocolSection.statusModule.whyStopped",
        "hasResults",
        "resultsSection.outcomeMeasuresModule.outcomeMeasures"
    ]
    
    query = "AREA[InterventionType]BEHAVIORAL"
    next_page_token = None
    
    for page in range(max_pages):
        params = {
            "pageSize": page_size,
            "query.term": query,
            "fields": ",".join(fields)
        }
        
        if next_page_token:
            params["pageToken"] = next_page_token
        
        full_url = f"{BASE}?{urllib.parse.urlencode(params)}"
        
        req = urllib.request.Request(full_url)
        req.add_header('User-Agent', 'Python-urllib/3.11')
        req.add_header('Accept', 'application/json')
        
        try:
            with urllib.request.urlopen(req, timeout=30) as response:
                if response.status != 200:
                    break
                
                data = json.loads(response.read().decode())
                studies = data.get('studies', [])
                
                if not studies:
                    break
                
                for study in studies:
                    yield study
                
                next_page_token = data.get('nextPageToken')
                if not next_page_token or len(studies) < page_size:
                    break
                    
        except Exception as e:
            print(f"Error fetching page {page}: {e}")
            break
        
        if sleep_sec > 0:
            import time
            time.sleep(sleep_sec)

print("API functions loaded ✅")
# Out:
# API functions loaded ✅

# %% [markdown]
# ## Success Assessment

# %%
def assess_study_success(study_data: Dict) -> Dict:
    """
    Comprehensive assessment of intervention success based on actual results data.
    Combines statistical analysis with fallback to study status assessment.
    """
    protocol_section = study_data.get('protocolSection', {})
    status_module = protocol_section.get('statusModule', {})
    
    overall_status = status_module.get('overallStatus', '')
    why_stopped = status_module.get('whyStopped', '')
    has_results = study_data.get('hasResults', False)
    
    # First, try to analyze actual intervention results if available
    if has_results and "resultsSection" in study_data:
        results_analysis = analyze_intervention_results(study_data)
        if results_analysis['success'] is not None:
            return {
                'status': overall_status,
                'success': results_analysis['success'],
                'confidence': results_analysis['confidence'],
                'has_results': has_results,
                'termination_reason': why_stopped if why_stopped else None,
                'assessment_method': 'statistical_analysis',
                'details': results_analysis.get('summary', '')
            }
    
    # Fallback to status-based assessment
    assessment = {
        'status': overall_status,
        'success': 'INCONCLUSIVE',
        'confidence': 'low',
        'has_results': has_results,
        'termination_reason': why_stopped if why_stopped else None,
        'assessment_method': 'status_only',
        'details': ''
    }
    
    if overall_status == 'COMPLETED':
        if has_results:
            assessment['success'] = 'COMPLETED_WITH_RESULTS'
            assessment['confidence'] = 'medium'
            assessment['details'] = 'Study completed and results posted, but detailed analysis unavailable'
        else:
            assessment['success'] = 'COMPLETED_NO_RESULTS'
            assessment['details'] = 'Study completed but no results posted yet'
    
    elif overall_status == 'TERMINATED' and why_stopped:
        why_stopped_lower = why_stopped.lower()
        
        success_terms = ['efficacy demonstrated', 'objectives achieved', 'met endpoint']
        failure_terms = ['futility', 'lack of efficacy', 'safety concerns', 'ineffective']
        
        if any(term in why_stopped_lower for term in success_terms):
            assessment['success'] = 'SUCCESS'
            assessment['confidence'] = 'high'
            assessment['details'] = f'Terminated early for success: {why_stopped}'
        elif any(term in why_stopped_lower for term in failure_terms):
            assessment['success'] = 'FAILURE' 
            assessment['confidence'] = 'high'
            assessment['details'] = f'Terminated early for failure: {why_stopped}'
        else:
            assessment['success'] = 'TERMINATED_UNCLEAR'
            assessment['confidence'] = 'medium'
            assessment['details'] = f'Terminated: {why_stopped}'
    
    elif overall_status in ['ACTIVE_NOT_RECRUITING', 'RECRUITING', 'NOT_YET_RECRUITING']:
        assessment['success'] = 'ONGOING'
        assessment['confidence'] = 'high'
        assessment['details'] = 'Study still in progress'
    
    elif overall_status == 'WITHDRAWN':
        assessment['success'] = 'WITHDRAWN'
        assessment['confidence'] = 'high'
        assessment['details'] = 'Study withdrawn before completion'
    
    return assessment


def analyze_intervention_results(study_data: Dict) -> Dict:
    """
    Analyze actual intervention results from ClinicalTrials.gov results data.
    Returns statistical assessment of intervention success.
    """
    if not study_data.get("hasResults") or "resultsSection" not in study_data:
        return {"success": None, "confidence": "unknown", "summary": "No results available"}
    
    results = []
    outcome_measures = study_data["resultsSection"].get("outcomeMeasuresModule", {}).get("outcomeMeasures", [])
    
    # Focus on primary outcomes first
    primary_outcomes = [om for om in outcome_measures if om.get("type") == "PRIMARY"]
    if not primary_outcomes:
        primary_outcomes = outcome_measures[:3]  # Take first few if no primary outcomes
    
    for outcome in primary_outcomes:
        title = outcome.get("title", "Unknown outcome")
        unit = outcome.get("unitOfMeasure", "")
        
        # Method 1: Check statistical analyses (most reliable)
        analyses = outcome.get("analyses", [])
        has_statistical_analysis = False
        
        for analysis in analyses:
            has_statistical_analysis = True
            p_value = analysis.get("pValue")
            param_value = analysis.get("paramValue")
            ci_lower = analysis.get("ciLowerLimit")
            ci_upper = analysis.get("ciUpperLimit")
            
            is_significant = False
            confidence = "low"
            
            if p_value:
                try:
                    # Handle p-values like ".001" or "0.001"
                    p_val = float(p_value.replace('.', '0.') if p_value.startswith('.') else p_value)
                    is_significant = p_val < 0.05
                    confidence = "high" if p_val < 0.001 else "medium" if p_val < 0.01 else "low"
                except (ValueError, TypeError):
                    pass
            
            # Check if confidence interval excludes null effect
            ci_excludes_null = False
            if ci_lower and ci_upper:
                try:
                    lower = float(ci_lower)
                    upper = float(ci_upper)
                    # For most outcomes, null effect is 0 (no change)
                    if (lower > 0 and upper > 0) or (lower < 0 and upper < 0):
                        ci_excludes_null = True
                except (ValueError, TypeError):
                    pass
            
            results.append({
                "outcome": title,
                "method": "statistical_analysis",
                "p_value": p_value,
                "effect_size": param_value,
                "is_significant": is_significant,
                "ci_excludes_null": ci_excludes_null,
                "confidence": confidence,
                "unit": unit
            })
        
        # Method 2: If no statistical analysis, look at raw measurements  
        if not has_statistical_analysis and outcome.get("classes"):
            for result_class in outcome["classes"]:
                if result_class.get("categories"):
                    for category in result_class["categories"]:
                        measurements = category.get("measurements", [])
                        
                        if len(measurements) >= 2:  # Need at least 2 groups to compare
                            values = []
                            for m in measurements:
                                try:
                                    val = float(m.get("value", 0))
                                    values.append(val)
                                except (ValueError, TypeError):
                                    continue
                            
                            if len(values) >= 2:
                                # Basic assessment - is there a notable difference?
                                diff = abs(values[0] - values[1])
                                avg = sum(values) / len(values)
                                percent_diff = (diff / abs(avg)) * 100 if avg != 0 else 0
                                
                                # Heuristic: >20% difference might be meaningful
                                is_meaningful = percent_diff > 20
                                
                                results.append({
                                    "outcome": title,
                                    "method": "measurement_comparison",
                                    "values": values,
                                    "percent_difference": percent_diff,
                                    "is_significant": is_meaningful,
                                    "confidence": "low",  # Low confidence without proper stats
                                    "unit": unit
                                })
                            break  # Only analyze first category
                    break  # Only analyze first class
    
    # Overall assessment
    significant_results = [r for r in results if r.get("is_significant")]
    
    if not results:
        return {"success": None, "confidence": "unknown", "summary": "No analyzable outcome measures"}
    
    # Success if any primary outcome shows significant positive effect
    overall_success = len(significant_results) > 0
    
    if significant_results:
        confidence_scores = {"high": 3, "medium": 2, "low": 1}
        overall_confidence = max([r["confidence"] for r in significant_results], key=lambda x: confidence_scores.get(x, 0))
    else:
        overall_confidence = "low"
    
    return {
        "success": 'SUCCESS' if overall_success else 'FAILURE',
        "confidence": overall_confidence,
        "summary": f"{len(significant_results)}/{len(results)} primary outcomes significant",
        "details": results
    }

print("Success assessment function loaded ✅")
# Out:
# Success assessment function loaded ✅

# %% [markdown]
# ## Study Analysis

# %%
def analyze_study(study: Dict) -> Dict:
    """
    Analyze a study and return structured data including intervention success assessment
    """
    protocol_section = study.get('protocolSection', {})
    identification = protocol_section.get('identificationModule', {})
    
    nct_id = identification.get('nctId', 'Unknown')
    title = identification.get('briefTitle', 'No title available')
    
    # Get conditions and interventions
    conditions = protocol_section.get('conditionsModule', {}).get('conditions', [])
    interventions = protocol_section.get('armsInterventionsModule', {}).get('interventions', [])
    primary_outcomes = protocol_section.get('outcomesModule', {}).get('primaryOutcomes', [])
    
    # Find behavioral interventions
    behavioral_interventions = [i for i in interventions if i.get('type') == 'BEHAVIORAL']
    
    # Comprehensive success assessment
    assessment = assess_study_success(study)
    
    # Generate prediction question
    prediction_question = None
    if primary_outcomes and behavioral_interventions:
        intervention_name = behavioral_interventions[0].get('name', 'the intervention')
        measure = primary_outcomes[0].get('measure', 'outcomes')
        timeframe = primary_outcomes[0].get('timeFrame', 'study completion')
        condition_text = ', '.join(conditions) if conditions else 'participants'
        prediction_question = f"Will {intervention_name} improve {measure} at {timeframe} in {condition_text} for trial {nct_id}?"
    
    # Determine intervention success category for easier analysis
    success_category = 'unknown'
    if assessment['success'] in ['SUCCESS']:
        success_category = 'success'
    elif assessment['success'] in ['FAILURE']:
        success_category = 'failure'
    elif assessment['success'] in ['COMPLETED_WITH_RESULTS', 'RESULTS_AVAILABLE']:
        success_category = 'completed_with_results'
    elif assessment['success'] in ['ONGOING', 'ACTIVE', 'RECRUITING']:
        success_category = 'ongoing'
    elif assessment['success'] in ['WITHDRAWN']:
        success_category = 'withdrawn'
    else:
        success_category = 'inconclusive'
    
    return {
        'nct_id': nct_id,
        'title': title,
        'conditions': conditions,
        'interventions': len(interventions),
        'behavioral_interventions': len(behavioral_interventions),
        'primary_outcomes': len(primary_outcomes),
        'assessment': assessment,
        'success_category': success_category,
        'prediction_question': prediction_question,
        'suitable_for_prediction': bool(prediction_question),
        'evidence_url': f"https://clinicaltrials.gov/study/{nct_id}"
    }

print("Analysis function loaded ✅")
# Out:
# Analysis function loaded ✅

# %% [markdown]
# ## Fetch and Analyze Studies

# %%
page_size = 1000
num_pages = 25
# Fetch studies
print(f"Fetching {page_size * num_pages} behavioral intervention studies...")
studies = list(fetch_studies(page_size=page_size, max_pages=num_pages))
print(f"✅ Fetched {len(studies)} studies")

# Analyze all studies
print("\nAnalyzing studies...")
outcomes = [analyze_study(study) for study in studies]
print(f"✅ Analyzed {len(outcomes)} studies")
# Out:
# Fetching 25000 behavioral intervention studies...

# %% [markdown]
# ## Results Summary

# %%
# Summary statistics
print("📊 STUDY ANALYSIS SUMMARY")
print("=" * 50)

# Basic counts
suitable_for_prediction = sum(1 for o in outcomes if o['suitable_for_prediction'])
with_results = sum(1 for o in outcomes if o['assessment']['has_results'])
completed = sum(1 for o in outcomes if o['assessment']['status'] == 'COMPLETED')
statistical_analysis = sum(1 for o in outcomes if o['assessment'].get('assessment_method') == 'statistical_analysis')

print(f"Total studies: {len(outcomes)}")
print(f"Suitable for prediction markets: {suitable_for_prediction} ({suitable_for_prediction/len(outcomes)*100:.1f}%)")
print(f"Studies with results: {with_results} ({with_results/len(outcomes)*100:.1f}%)")
print(f"Studies with statistical analysis: {statistical_analysis} ({statistical_analysis/len(outcomes)*100:.1f}%)")
print(f"Completed studies: {completed} ({completed/len(outcomes)*100:.1f}%)")

# Success assessment distribution
print("\n🎯 SUCCESS ASSESSMENT DISTRIBUTION:")
success_counts = Counter(o['assessment']['success'] for o in outcomes)
for success_type, count in success_counts.most_common():
    print(f"  • {success_type}: {count} ({count/len(outcomes)*100:.1f}%)")

# Success categories (simplified view)
print("\n📈 INTERVENTION SUCCESS CATEGORIES:")
category_counts = Counter(o['success_category'] for o in outcomes)
for category, count in category_counts.most_common():
    print(f"  • {category}: {count} ({count/len(outcomes)*100:.1f}%)")

# Assessment method distribution
print("\n🔍 ASSESSMENT METHOD DISTRIBUTION:")
method_counts = Counter(o['assessment'].get('assessment_method', 'unknown') for o in outcomes)
for method, count in method_counts.most_common():
    print(f"  • {method}: {count} ({count/len(outcomes)*100:.1f}%)")

# Show examples of successful interventions (if any)
successful_studies = [o for o in outcomes if o['success_category'] == 'success']
if successful_studies:
    print(f"\n✅ EXAMPLES OF SUCCESSFUL INTERVENTIONS ({len(successful_studies)} total):")
    for i, study in enumerate(successful_studies[:3]):
        print(f"{i+1}. {study['nct_id']}: {study['title'][:80]}...")
        print(f"   Assessment: {study['assessment']['success']} (confidence: {study['assessment']['confidence']})")
        if study['assessment'].get('details'):
            print(f"   Details: {study['assessment']['details'][:100]}...")
        print()
# Out:
# 📊 STUDY ANALYSIS SUMMARY
# ==================================================
# Total studies: 2000
# Suitable for prediction markets: 1979 (99.0%)
# Studies with results: 202 (10.1%)
# Studies with statistical analysis: 177 (8.8%)
# Completed studies: 1182 (59.1%)
#
# 🎯 SUCCESS ASSESSMENT DISTRIBUTION:
#   • COMPLETED_NO_RESULTS: 992 (49.6%)
#   • ONGOING: 474 (23.7%)
#   • INCONCLUSIVE: 255 (12.8%)
#   • SUCCESS: 90 (4.5%)
#   • FAILURE: 89 (4.5%)
#   • TERMINATED_UNCLEAR: 49 (2.5%)
#   • WITHDRAWN: 29 (1.5%)
#   • COMPLETED_WITH_RESULTS: 22 (1.1%)
#
# 📈 INTERVENTION SUCCESS CATEGORIES:
#   • inconclusive: 1296 (64.8%)
#   • ongoing: 474 (23.7%)
#   • success: 90 (4.5%)
#   • failure: 89 (4.5%)
#   • withdrawn: 29 (1.5%)
#   • completed_with_results: 22 (1.1%)
#
# 🔍 ASSESSMENT METHOD DISTRIBUTION:
#   • status_only: 1823 (91.1%)
#   • statistical_analysis: 177 (8.8%)
#
# ✅ EXAMPLES OF SUCCESSFUL INTERVENTIONS (90 total):
# 1. NCT03099369: Daily Step-based Exercise Using Fitness Monitors for Peripheral Artery Disease...
#    Assessment: SUCCESS (confidence: low)
#    Details: 1/1 primary outcomes significant...
#
# 2. NCT04025229: High Intensity Interval Training in Endometrial Cancer...
#    Assessment: SUCCESS (confidence: low)
#    Details: 1/1 primary outcomes significant...
#
# 3. NCT02944877: HOPE Social Media Intervention for HIV Testing and Studying Social Networks...
#    Assessment: SUCCESS (confidence: low)
#    Details: 1/1 primary outcomes significant...

# %% [markdown]
# ## Generate Prediction Market Questions

# %%
# Generate prediction market questions from suitable studies
# Create one question per primary outcome measure
questions = []
for outcome in outcomes:
    if outcome['suitable_for_prediction']:
        # Get the study data to access all primary outcomes
        study_nct = outcome['nct_id']
        study_data = next((s for s in studies if s.get('protocolSection', {}).get('identificationModule', {}).get('nctId') == study_nct), None)
        
        if study_data:
            protocol_section = study_data.get('protocolSection', {})
            primary_outcomes = protocol_section.get('outcomesModule', {}).get('primaryOutcomes', [])
            conditions = protocol_section.get('conditionsModule', {}).get('conditions', [])
            interventions = protocol_section.get('armsInterventionsModule', {}).get('interventions', [])
            behavioral_interventions = [i for i in interventions if i.get('type') == 'BEHAVIORAL']
            
            # Base data for all questions from this study
            base_data = {
                'nct_id': outcome['nct_id'],
                'title': outcome['title'],
                'conditions': ', '.join(outcome['conditions']),
                'study_status': outcome['assessment']['status'],
                'success_assessment': outcome['assessment']['success'],
                'success_category': outcome['success_category'],
                'confidence': outcome['assessment']['confidence'],
                'assessment_method': outcome['assessment'].get('assessment_method', 'unknown'),
                'has_results': outcome['assessment']['has_results'],
                'termination_reason': outcome['assessment'].get('termination_reason', ''),
                'assessment_details': outcome['assessment'].get('details', ''),
                'evidence_url': outcome['evidence_url'],
                'question_type': 'efficacy'
            }
            
            # Generate one question per primary outcome
            if primary_outcomes and behavioral_interventions:
                intervention_name = behavioral_interventions[0].get('name', 'the intervention')
                condition_text = ', '.join(conditions) if conditions else 'participants'
                
                for i, primary_outcome in enumerate(primary_outcomes):
                    measure = primary_outcome.get('measure', 'outcomes')
                    timeframe = primary_outcome.get('timeFrame', 'study completion')
                    
                    # Create the question for this specific outcome
                    question_text = f"Will {intervention_name} improve {measure} at {timeframe} in {condition_text} for trial {outcome['nct_id']}?"
                    
                    # Create a copy of base data for this question
                    question_data = base_data.copy()
                    question_data.update({
                        'question': question_text,
                        'primary_outcome_measure': measure,
                        'primary_outcome_timeframe': timeframe,
                        'outcome_number': i + 1,
                        'total_primary_outcomes': len(primary_outcomes)
                    })
                    
                    questions.append(question_data)
            
        # Fallback: if we can't access study data, use the single question we already generated
        elif outcome['prediction_question']:
            fallback_data = {
                'nct_id': outcome['nct_id'],
                'title': outcome['title'],
                'question': outcome['prediction_question'],
                'conditions': ', '.join(outcome['conditions']),
                'study_status': outcome['assessment']['status'],
                'success_assessment': outcome['assessment']['success'],
                'success_category': outcome['success_category'],
                'confidence': outcome['assessment']['confidence'],
                'assessment_method': outcome['assessment'].get('assessment_method', 'unknown'),
                'has_results': outcome['assessment']['has_results'],
                'termination_reason': outcome['assessment'].get('termination_reason', ''),
                'assessment_details': outcome['assessment'].get('details', ''),
                'evidence_url': outcome['evidence_url'],
                'question_type': 'efficacy',
                'primary_outcome_measure': 'Unknown',
                'primary_outcome_timeframe': 'Unknown',
                'outcome_number': 1,
                'total_primary_outcomes': 1
            }
            questions.append(fallback_data)

print(f"🎲 Generated {len(questions)} prediction market questions from {len([o for o in outcomes if o['suitable_for_prediction']])} suitable studies")
print(f"📊 Ratio: {len(questions)/len([o for o in outcomes if o['suitable_for_prediction']]):.1f} questions per study on average")

# Show breakdown by number of primary outcomes
outcome_counts = Counter(q['total_primary_outcomes'] for q in questions)
print(f"\n📋 PRIMARY OUTCOMES PER STUDY:")
for outcome_count, freq in sorted(outcome_counts.items()):
    studies_with_count = freq // outcome_count if outcome_count > 0 else freq
    print(f"  • {outcome_count} primary outcome(s): {studies_with_count} studies ({freq} questions)")

# # Show sample questions grouped by study
# print("\n📝 SAMPLE QUESTIONS BY STUDY:")
# questions_by_study = {}
# for q in questions:
#     nct_id = q['nct_id']
#     if nct_id not in questions_by_study:
#         questions_by_study[nct_id] = []
#     questions_by_study[nct_id].append(q)

# # Show first few studies with multiple outcomes
# multi_outcome_studies = [(nct, qs) for nct, qs in questions_by_study.items() if len(qs) > 1]
# single_outcome_studies = [(nct, qs) for nct, qs in questions_by_study.items() if len(qs) == 1]

# if multi_outcome_studies:
#     print(f"\n🎯 STUDIES WITH MULTIPLE PRIMARY OUTCOMES ({len(multi_outcome_studies)} studies):")
#     for i, (nct_id, study_questions) in enumerate(multi_outcome_studies[:2]):
#         print(f"\n{i+1}. Study {nct_id} ({len(study_questions)} primary outcomes):")
#         print(f"   Title: {study_questions[0]['title'][:60]}...")
#         for j, q in enumerate(study_questions):
#             print(f"   Outcome {j+1}: {q['primary_outcome_measure'][:50]}...")
#             print(f"     Question: {q['question'][:80]}...")
#             print()

# if single_outcome_studies:
#     print(f"📍 STUDIES WITH SINGLE PRIMARY OUTCOME ({len(single_outcome_studies)} studies):")
#     for i, (nct_id, study_questions) in enumerate(single_outcome_studies[:2]):
#         q = study_questions[0]
#         print(f"{i+1}. {nct_id}: {q['question'][:80]}...")
#         print(f"   Assessment: {q['success_assessment']} ({q['assessment_method']})")
#         print()


# Show sample questions by success category
print("\n📊 SAMPLE QUESTIONS BY SUCCESS CATEGORY:")
category_samples = {}
for q in questions:
    category = q['success_category']
    if category not in category_samples:
        category_samples[category] = []
    category_samples[category].append(q)

for category in sorted(category_samples.keys()):
    sample_questions = category_samples[category][:5]  # Get first 5
    print(f"\n🏷️  {category.upper()} ({len(category_samples[category])} total questions):")
    for i, q in enumerate(sample_questions):
        print(f"{i+1}. {q['nct_id']}: {q['question']}...")
        print(f"   Assessment: {q['success_assessment']} (confidence: {q['confidence']})")
        if q['assessment_method'] != 'unknown':
            print(f"   Method: {q['assessment_method']}")
        print()
# Out:
# 🎲 Generated 1221 prediction market questions from 497 suitable studies
# 📊 Ratio: 2.5 questions per study on average
#
# 📋 PRIMARY OUTCOMES PER STUDY:
#   • 1 primary outcome(s): 288 studies (288 questions)
#   • 2 primary outcome(s): 83 studies (166 questions)
#   • 3 primary outcome(s): 48 studies (144 questions)
#   • 4 primary outcome(s): 24 studies (96 questions)
#   • 5 primary outcome(s): 12 studies (60 questions)
#   • 6 primary outcome(s): 5 studies (30 questions)
#   • 7 primary outcome(s): 5 studies (35 questions)
#   • 8 primary outcome(s): 4 studies (32 questions)
#   • 9 primary outcome(s): 5 studies (45 questions)
#   • 10 primary outcome(s): 6 studies (60 questions)
#   • 11 primary outcome(s): 1 studies (11 questions)
#   • 12 primary outcome(s): 5 studies (60 questions)
#   • 13 primary outcome(s): 2 studies (26 questions)
#   • 14 primary outcome(s): 2 studies (28 questions)
#   • 16 primary outcome(s): 1 studies (16 questions)
#   • 17 primary outcome(s): 1 studies (17 questions)
#   • 18 primary outcome(s): 2 studies (36 questions)
#   • 22 primary outcome(s): 2 studies (44 questions)
#   • 27 primary outcome(s): 1 studies (27 questions)
#
# 📊 SAMPLE QUESTIONS BY SUCCESS CATEGORY:
#
# 🏷️  COMPLETED_WITH_RESULTS (28 total questions):
# 1. NCT04751656: Will Steady Intervention improve Intervention Satisfaction at 12 months. in Overweight and Obesity for trial NCT04751656?...
#    Assessment: COMPLETED_WITH_RESULTS (confidence: medium)
#    Method: status_only
#
# 2. NCT04646213: Will Managing Cancer and Living Meaningfully (CALM) Therapy improve Recruitment for CALM at 1 day in Mood, Cancer Brain for trial NCT04646213?...
#    Assessment: COMPLETED_WITH_RESULTS (confidence: medium)
#    Method: status_only
#
# 3. NCT04646213: Will Managing Cancer and Living Meaningfully (CALM) Therapy improve Completion of CALM Sessions at 3 months in Mood, Cancer Brain for trial NCT04646213?...
#    Assessment: COMPLETED_WITH_RESULTS (confidence: medium)
#    Method: status_only
#
# 4. NCT04646213: Will Managing Cancer and Living Meaningfully (CALM) Therapy improve Post-session Assessment Completion at 4 months in Mood, Cancer Brain for trial NCT04646213?...
#    Assessment: COMPLETED_WITH_RESULTS (confidence: medium)
#    Method: status_only
#
# 5. NCT04646213: Will Managing Cancer and Living Meaningfully (CALM) Therapy improve Follow-up Assessment Completion at 6 months in Mood, Cancer Brain for trial NCT04646213?...
#    Assessment: COMPLETED_WITH_RESULTS (confidence: medium)
#    Method: status_only
#
...
#    Assessment: WITHDRAWN (confidence: high)
#    Method: status_only

# %%
# Generate prediction market questions from suitable studies
# Create one question per primary outcome measure
questions = []
for outcome in outcomes:
    if outcome['suitable_for_prediction']:
        # Get the study data to access all primary outcomes
        study_nct = outcome['nct_id']
        study_data = next((s for s in studies if s.get('protocolSection', {}).get('identificationModule', {}).get('nctId') == study_nct), None)
        
        if study_data:
            protocol_section = study_data.get('protocolSection', {})
            primary_outcomes = protocol_section.get('outcomesModule', {}).get('primaryOutcomes', [])
            conditions = protocol_section.get('conditionsModule', {}).get('conditions', [])
            interventions = protocol_section.get('armsInterventionsModule', {}).get('interventions', [])
            behavioral_interventions = [i for i in interventions if i.get('type') == 'BEHAVIORAL']
            
            # Base data for all questions from this study
            base_data = {
                'nct_id': outcome['nct_id'],
                'title': outcome['title'],
                'conditions': ', '.join(outcome['conditions']),
                'study_status': outcome['assessment']['status'],
                'success_assessment': outcome['assessment']['success'],
                'success_category': outcome['success_category'],
                'confidence': outcome['assessment']['confidence'],
                'assessment_method': outcome['assessment'].get('assessment_method', 'unknown'),
                'has_results': outcome['assessment']['has_results'],
                'termination_reason': outcome['assessment'].get('termination_reason', ''),
                'assessment_details': outcome['assessment'].get('details', ''),
                'evidence_url': outcome['evidence_url'],
                'question_type': 'efficacy'
            }
            
            # Generate one question per primary outcome
            if primary_outcomes and behavioral_interventions:
                intervention_name = behavioral_interventions[0].get('name', 'the intervention')
                condition_text = ', '.join(conditions) if conditions else 'participants'
                
                for i, primary_outcome in enumerate(primary_outcomes):
                    measure = primary_outcome.get('measure', 'outcomes')
                    timeframe = primary_outcome.get('timeFrame', 'study completion')
                    
                    # Create the question for this specific outcome
                    question_text = f"Will {intervention_name} improve {measure} at {timeframe} in {condition_text} for trial {outcome['nct_id']}?"
                    
                    # Create a copy of base data for this question
                    question_data = base_data.copy()
                    question_data.update({
                        'question': question_text,
                        'primary_outcome_measure': measure,
                        'primary_outcome_timeframe': timeframe,
                        'outcome_number': i + 1,
                        'total_primary_outcomes': len(primary_outcomes)
                    })
                    
                    questions.append(question_data)
            
        # Fallback: if we can't access study data, use the single question we already generated
        elif outcome['prediction_question']:
            fallback_data = {
                'nct_id': outcome['nct_id'],
                'title': outcome['title'],
                'question': outcome['prediction_question'],
                'conditions': ', '.join(outcome['conditions']),
                'study_status': outcome['assessment']['status'],
                'success_assessment': outcome['assessment']['success'],
                'success_category': outcome['success_category'],
                'confidence': outcome['assessment']['confidence'],
                'assessment_method': outcome['assessment'].get('assessment_method', 'unknown'),
                'has_results': outcome['assessment']['has_results'],
                'termination_reason': outcome['assessment'].get('termination_reason', ''),
                'assessment_details': outcome['assessment'].get('details', ''),
                'evidence_url': outcome['evidence_url'],
                'question_type': 'efficacy',
                'primary_outcome_measure': 'Unknown',
                'primary_outcome_timeframe': 'Unknown',
                'outcome_number': 1,
                'total_primary_outcomes': 1
            }
            questions.append(fallback_data)

print(f"🎲 Generated {len(questions)} prediction market questions from {len([o for o in outcomes if o['suitable_for_prediction']])} suitable studies")
print(f"📊 Ratio: {len(questions)/len([o for o in outcomes if o['suitable_for_prediction']]):.1f} questions per study on average")

# Show breakdown by number of primary outcomes
outcome_counts = Counter(q['total_primary_outcomes'] for q in questions)
print(f"\n📋 PRIMARY OUTCOMES PER STUDY:")
for outcome_count, freq in sorted(outcome_counts.items()):
    studies_with_count = freq // outcome_count if outcome_count > 0 else freq
    print(f"  • {outcome_count} primary outcome(s): {studies_with_count} studies ({freq} questions)")

# # Show sample questions grouped by study
# print("\n📝 SAMPLE QUESTIONS BY STUDY:")
# questions_by_study = {}
# for q in questions:
#     nct_id = q['nct_id']
#     if nct_id not in questions_by_study:
#         questions_by_study[nct_id] = []
#     questions_by_study[nct_id].append(q)

# # Show first few studies with multiple outcomes
# multi_outcome_studies = [(nct, qs) for nct, qs in questions_by_study.items() if len(qs) > 1]
# single_outcome_studies = [(nct, qs) for nct, qs in questions_by_study.items() if len(qs) == 1]

# if multi_outcome_studies:
#     print(f"\n🎯 STUDIES WITH MULTIPLE PRIMARY OUTCOMES ({len(multi_outcome_studies)} studies):")
#     for i, (nct_id, study_questions) in enumerate(multi_outcome_studies[:2]):
#         print(f"\n{i+1}. Study {nct_id} ({len(study_questions)} primary outcomes):")
#         print(f"   Title: {study_questions[0]['title'][:60]}...")
#         for j, q in enumerate(study_questions):
#             print(f"   Outcome {j+1}: {q['primary_outcome_measure'][:50]}...")
#             print(f"     Question: {q['question'][:80]}...")
#             print()

# if single_outcome_studies:
#     print(f"📍 STUDIES WITH SINGLE PRIMARY OUTCOME ({len(single_outcome_studies)} studies):")
#     for i, (nct_id, study_questions) in enumerate(single_outcome_studies[:2]):
#         q = study_questions[0]
#         print(f"{i+1}. {nct_id}: {q['question'][:80]}...")
#         print(f"   Assessment: {q['success_assessment']} ({q['assessment_method']})")
#         print()


# Show sample questions by success category
print("\n📊 SAMPLE QUESTIONS BY SUCCESS CATEGORY:")
category_samples = {}
for q in questions:
    category = q['success_category']
    if category not in category_samples:
        category_samples[category] = []
    category_samples[category].append(q)

for category in sorted(category_samples.keys()):
    sample_questions = category_samples[category][:5]  # Get first 5
    print(f"\n🏷️  {category.upper()} ({len(category_samples[category])} total questions):")
    for i, q in enumerate(sample_questions):
        print(f"{i+1}. {q['nct_id']}: {q['question']}...")
        print(f"   Assessment: {q['success_assessment']} (confidence: {q['confidence']})")
        if q['assessment_method'] != 'unknown':
            print(f"   Method: {q['assessment_method']}")
        print()
# Out:
# 🎲 Generated 1221 prediction market questions from 497 suitable studies
# 📊 Ratio: 2.5 questions per study on average
#
# 📋 PRIMARY OUTCOMES PER STUDY:
#   • 1 primary outcome(s): 288 studies (288 questions)
#   • 2 primary outcome(s): 83 studies (166 questions)
#   • 3 primary outcome(s): 48 studies (144 questions)
#   • 4 primary outcome(s): 24 studies (96 questions)
#   • 5 primary outcome(s): 12 studies (60 questions)
#   • 6 primary outcome(s): 5 studies (30 questions)
#   • 7 primary outcome(s): 5 studies (35 questions)
#   • 8 primary outcome(s): 4 studies (32 questions)
#   • 9 primary outcome(s): 5 studies (45 questions)
#   • 10 primary outcome(s): 6 studies (60 questions)
#   • 11 primary outcome(s): 1 studies (11 questions)
#   • 12 primary outcome(s): 5 studies (60 questions)
#   • 13 primary outcome(s): 2 studies (26 questions)
#   • 14 primary outcome(s): 2 studies (28 questions)
#   • 16 primary outcome(s): 1 studies (16 questions)
#   • 17 primary outcome(s): 1 studies (17 questions)
#   • 18 primary outcome(s): 2 studies (36 questions)
#   • 22 primary outcome(s): 2 studies (44 questions)
#   • 27 primary outcome(s): 1 studies (27 questions)
#
# 📊 SAMPLE QUESTIONS BY SUCCESS CATEGORY:
#
# 🏷️  COMPLETED_WITH_RESULTS (28 total questions):
# 1. NCT04751656: Will Steady Intervention improve Intervention Satisfaction at 12 months. in Overweight and Obesity for trial NCT04751656?...
#    Assessment: COMPLETED_WITH_RESULTS (confidence: medium)
#    Method: status_only
#
# 2. NCT04646213: Will Managing Cancer and Living Meaningfully (CALM) Therapy improve Recruitment for CALM at 1 day in Mood, Cancer Brain for trial NCT04646213?...
#    Assessment: COMPLETED_WITH_RESULTS (confidence: medium)
#    Method: status_only
#
# 3. NCT04646213: Will Managing Cancer and Living Meaningfully (CALM) Therapy improve Completion of CALM Sessions at 3 months in Mood, Cancer Brain for trial NCT04646213?...
#    Assessment: COMPLETED_WITH_RESULTS (confidence: medium)
#    Method: status_only
#
# 4. NCT04646213: Will Managing Cancer and Living Meaningfully (CALM) Therapy improve Post-session Assessment Completion at 4 months in Mood, Cancer Brain for trial NCT04646213?...
#    Assessment: COMPLETED_WITH_RESULTS (confidence: medium)
#    Method: status_only
#
# 5. NCT04646213: Will Managing Cancer and Living Meaningfully (CALM) Therapy improve Follow-up Assessment Completion at 6 months in Mood, Cancer Brain for trial NCT04646213?...
#    Assessment: COMPLETED_WITH_RESULTS (confidence: medium)
#    Method: status_only
#
#
# 🏷️  FAILURE (37 total questions):
# 1. NCT03488927: Will Supporting Survivors and Self: An Intervention for Social Supports of Survivors of Partner Abuse and Sexual Aggression (SSS) improve Negative Social Reactions at Six months in Social Skills, Self-Criticism, Post-traumatic Stress Disorder, Depression, Alcohol Abuse, Drinking, College, Alcohol Drinking, Alcohol; Harmful Use, Social Stigma, Social Norms, Social Responsibility, Social Behavior, Empathy, Coping Skills, Coping Behavior for trial NCT03488927?...
#    Assessment: FAILURE (confidence: low)
#    Method: statistical_analysis
#
# 2. NCT03734666: Will Mindfulness Based Relapse Prevention - Smoking and Alcohol improve Aim 2: Number of Participants Scoring >3 at End of Treatment at 8 Weeks in Tobacco Use, Alcohol Use, Unspecified for trial NCT03734666?...
#    Assessment: FAILURE (confidence: low)
#    Method: statistical_analysis
#
# 3. NCT03734666: Will Mindfulness Based Relapse Prevention - Smoking and Alcohol improve Aim 2: Rate of Recruitment of Eligible Participants at 20 weeks in Tobacco Use, Alcohol Use, Unspecified for trial NCT03734666?...
#    Assessment: FAILURE (confidence: low)
#    Method: statistical_analysis
#
# 4. NCT03734666: Will Mindfulness Based Relapse Prevention - Smoking and Alcohol improve Aim 2: Participant Retention at End of study at Week 16 Follow-up in Tobacco Use, Alcohol Use, Unspecified for trial NCT03734666?...
#    Assessment: FAILURE (confidence: low)
#    Method: statistical_analysis
#
# 5. NCT03734666: Will Mindfulness Based Relapse Prevention - Smoking and Alcohol improve Aim 2: Percentage of Participants That Completed Questionnaires at End of study at Week 16 Follow-up in Tobacco Use, Alcohol Use, Unspecified for trial NCT03734666?...
#    Assessment: FAILURE (confidence: low)
#    Method: statistical_analysis
#
#
# 🏷️  INCONCLUSIVE (732 total questions):
# 1. NCT04246424: Will Fibit + Coaching improve Sleep Duration (Assess changes in sleep quality) at time points at visit 1 (week 1), visit 2 (week 6) and visit 3 (week 12) in Sleep for trial NCT04246424?...
#    Assessment: COMPLETED_NO_RESULTS (confidence: low)
#    Method: status_only
#
# 2. NCT04246424: Will Fibit + Coaching improve Sleep Duration at time points at visit 1 (week 1), visit 2 (week 6) and visit 3 (week 12) in Sleep for trial NCT04246424?...
#    Assessment: COMPLETED_NO_RESULTS (confidence: low)
#    Method: status_only
#
# 3. NCT04246424: Will Fibit + Coaching improve Sleep Duration at time points at visit 1 (week 1), visit 2 (week 6) and visit 3 (week 12) in Sleep for trial NCT04246424?...
#    Assessment: COMPLETED_NO_RESULTS (confidence: low)
#    Method: status_only
#
# 4. NCT02449759: Will ACT Intervention Group improve Change is being assessed using the Quality of Life BREF (WHOQOLBREF; Skevington et al., 2004) questionnaire at Baseline and 6 weeks in Anxiety, Depression for trial NCT02449759?...
#    Assessment: COMPLETED_NO_RESULTS (confidence: low)
#    Method: status_only
#
# 5. NCT00434980: Will Family-Directed Cognitive Adaptation Program improve Social Adaptive Functions Scale (P) at Baseline, end of treatment, and 3 months after end of treatment, 6 months after end of treatment in Schizophrenia, Schizoaffective Disorder, Schizophreniform Disorder for trial NCT00434980?...
#    Assessment: COMPLETED_NO_RESULTS (confidence: low)
#    Method: status_only
#
#
# 🏷️  ONGOING (359 total questions):
# 1. NCT05364879: Will Prehabilitation Exercise Intervention improve Frailty Change (baseline to post exercise intervention) at Change from baseline to end of 4+ week intervention (pre-surgery) in Prehabilitation, Exercise, Frailty, Ovarian Cancer, Surgical Complication, Treatment Outcomes, Enhanced Recovery After Surgery for trial NCT05364879?...
#    Assessment: ONGOING (confidence: high)
#    Method: status_only
#
# 2. NCT05364879: Will Prehabilitation Exercise Intervention improve Frailty Change (baseline to 1-month post surgery) at Change from baseline to about 1-month post-surgery in Prehabilitation, Exercise, Frailty, Ovarian Cancer, Surgical Complication, Treatment Outcomes, Enhanced Recovery After Surgery for trial NCT05364879?...
#    Assessment: ONGOING (confidence: high)
#    Method: status_only
#
# 3. NCT05364879: Will Prehabilitation Exercise Intervention improve Frailty Change (baseline to 3-months post surgery) at Change from baseline to about 3-month post-surgery in Prehabilitation, Exercise, Frailty, Ovarian Cancer, Surgical Complication, Treatment Outcomes, Enhanced Recovery After Surgery for trial NCT05364879?...
#    Assessment: ONGOING (confidence: high)
#    Method: status_only
#
# 4. NCT05364879: Will Prehabilitation Exercise Intervention improve Surgical Complexity Score (1-month post surgery) at Surgical complexity will be assessed about 1-month post-surgery. in Prehabilitation, Exercise, Frailty, Ovarian Cancer, Surgical Complication, Treatment Outcomes, Enhanced Recovery After Surgery for trial NCT05364879?...
#    Assessment: ONGOING (confidence: high)
#    Method: status_only
#
# 5. NCT05364879: Will Prehabilitation Exercise Intervention improve Post-Surgical Outcomes (1-month post surgery) at Post-surgical outcomes will be assessed about 1-month post-surgery. in Prehabilitation, Exercise, Frailty, Ovarian Cancer, Surgical Complication, Treatment Outcomes, Enhanced Recovery After Surgery for trial NCT05364879?...
#    Assessment: ONGOING (confidence: high)
#    Method: status_only
#
#
# 🏷️  SUCCESS (48 total questions):
# 1. NCT03099369: Will Daily Step-based Exercise improve Change in the Mean Daily Walking Distance Over 7 Consecutive Days at Baseline, Month 3 in Peripheral Artery Disease for trial NCT03099369?...
#    Assessment: SUCCESS (confidence: low)
#    Method: statistical_analysis
#
# 2. NCT04025229: Will HIIT exercise improve Change in Proliferative Markers in Endometrium Before and After HIIT Exercises at 3 years in Endometrial Cancer for trial NCT04025229?...
#    Assessment: SUCCESS (confidence: low)
#    Method: statistical_analysis
#
# 3. NCT02944877: Will social media intervention improve Number of Participants Requesting HIV Self-Testing at 5 years in HIV for trial NCT02944877?...
#    Assessment: SUCCESS (confidence: low)
#    Method: statistical_analysis
#
# 4. NCT03739762: Will i-STAND improve Change in Time Spent Sitting or Lying Down at 6 Months at Change from Baseline at 6 months in Sedentary Lifestyle for trial NCT03739762?...
#    Assessment: SUCCESS (confidence: medium)
#    Method: statistical_analysis
#
# 5. NCT03739762: Will i-STAND improve Change in SystolicBlood Pressure at 6 Months at Change from Baseline at 6 months in Sedentary Lifestyle for trial NCT03739762?...
#    Assessment: SUCCESS (confidence: medium)
#    Method: statistical_analysis
#
#
# 🏷️  WITHDRAWN (17 total questions):
# 1. NCT01381146: Will Impact of Crime Modules improve Recidivism - Self report of arrests and undetected crimes at 3 months post-release up to 9 mos in Substance Abuse, HIV Risk, Shame, Guilt, Empathy, Criminogenic Thinking for trial NCT01381146?...
#    Assessment: WITHDRAWN (confidence: high)
#    Method: status_only
#
# 2. NCT01381146: Will Impact of Crime Modules improve Acceptability - number of participants who indicate the module was helpful and number who would recommend treatment to a friend at 1 week post-treatment up to 2 weeks in Substance Abuse, HIV Risk, Shame, Guilt, Empathy, Criminogenic Thinking for trial NCT01381146?...
#    Assessment: WITHDRAWN (confidence: high)
#    Method: status_only
#
# 3. NCT01381146: Will Impact of Crime Modules improve Number of inmates who complete the intervention at 5 sessions over a period of 1 week in Substance Abuse, HIV Risk, Shame, Guilt, Empathy, Criminogenic Thinking for trial NCT01381146?...
#    Assessment: WITHDRAWN (confidence: high)
#    Method: status_only
#
# 4. NCT03117777: Will group cognitive behavioral therapy for insomnia improve Insomnia Severity Index at 5 months in Insomnia for trial NCT03117777?...
#    Assessment: WITHDRAWN (confidence: high)
#    Method: status_only
#
# 5. NCT03117777: Will group cognitive behavioral therapy for insomnia improve Pittsburgh Sleep Quality Index at 5 months in Insomnia for trial NCT03117777?...
#    Assessment: WITHDRAWN (confidence: high)
#    Method: status_only

# %% [markdown]
# ## Export to CSV

# %%
# Export prediction market questions to CSV
if questions:
    filename = "prediction_market_questions.csv"
    with open(filename, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = questions[0].keys()
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        
        writer.writeheader()
        for question in questions:
            writer.writerow(question)
    
    print(f"✅ Exported {len(questions)} questions to {filename}")
else:
    print("❌ No questions to export")

print(f"\n🎯 FINAL SUMMARY:")
print(f"  • Fetched {len(studies)} behavioral intervention studies")
print(f"  • Found {len([o for o in outcomes if o['suitable_for_prediction']])} studies suitable for prediction markets")
print(f"  • Generated {len(questions)} total prediction market questions")
print(f"  • Average: {len(questions)/len([o for o in outcomes if o['suitable_for_prediction']]):.1f} questions per suitable study")

# Count studies by number of primary outcomes
studies_with_multiple = len([nct for nct, qs in questions_by_study.items() if len(qs) > 1])
studies_with_single = len([nct for nct, qs in questions_by_study.items() if len(qs) == 1])
print(f"  • Studies with multiple primary outcomes: {studies_with_multiple}")
print(f"  • Studies with single primary outcome: {studies_with_single}")
# Out:
# ✅ Exported 1221 questions to prediction_market_questions.csv
#
# 🎯 FINAL SUMMARY:
#   • Fetched 500 behavioral intervention studies
#   • Found 497 studies suitable for prediction markets
#   • Generated 1221 total prediction market questions
#   • Average: 2.5 questions per suitable study
#   • Studies with multiple primary outcomes: 209
#   • Studies with single primary outcome: 288

# %%
for question in questions:
    print(question["question"])
# Out:
# Will Fibit + Coaching improve Sleep Duration (Assess changes in sleep quality) at time points at visit 1 (week 1), visit 2 (week 6) and visit 3 (week 12) in Sleep for trial NCT04246424?
# Will Fibit + Coaching improve Sleep Duration at time points at visit 1 (week 1), visit 2 (week 6) and visit 3 (week 12) in Sleep for trial NCT04246424?
# Will Fibit + Coaching improve Sleep Duration at time points at visit 1 (week 1), visit 2 (week 6) and visit 3 (week 
Substance Abuse, HIV Risk, Shame, Guilt, Empathy, Criminogenic Thinking for trial NCT01381146?
# Will Impact of Crime Modules improve Number of inmates who complete the intervention at 5 sessions over a period of 1 week in Substance Abuse, HIV Risk, Shame, Guilt, Empathy, Criminogenic Thinking for trial NCT01381146?
# Will Strengthened health education improve 10-year CVD risk score at 12 months in Hypertension, Diabetes Mellitus Type 2, Cardiovascular Diseases for trial NCT06302127?
# Will education by DVD improve compliance at baseline and after intervention in Chronic Kidney Disease for trial NCT01509027?
# Will education by DVD improve serum phosphate levels at baseline and after intervention in Chronic Kidney Disease for trial NCT01509027?
# Will Standard counseling improve Proportion of participants in the experimental arm who receive the first four intervention sessions between enrollment and week 2 visit at Week 2 in Acute HIV Infection for trial NCT01197027?
# Will Cognitive training improve Fluid intelligence at Change from baseline to post-assessment (after 10 weeks of training) in Schizophrenia for trial NCT02478827?
# Will Cognitive training improve Working Memory at Change from baseline to post-assessment (after 10 weeks of training) in Schizophrenia for trial NCT02478827?
# Will Cognitive training improve Processing Speed at Change from baseline to post-assessment (after 10 weeks of training) in Schizophrenia for trial NCT02478827?
# Will Supporting Survivors and Self: An Intervention for Social Supports of Survivors of Partner Abuse and Sexual Aggression (SSS) improve Negative Social Reactions at Six months in Social Skills, Self-Criticism, Post-traumatic Stress Disorder, Depression, Alcohol Abuse, Drinking, College, Alcohol Drinking, Alcohol; Harmful Use, Social Stigma, Social Norms, Social Responsibility, Social Behavior, Empathy, Coping Skills, Coping Behavior for trial NCT03488927?
# Will Peer support improve A change of health-related quality of life (HRQoL). at From baseline to 3, 6 and 12 months later. in Breast Cancer for trial NCT03394742?
# Will Peer support improve A change of health-related quality of life (HRQoL). at From baseline to 3, 6 and 12 months later. in Breast Cancer for trial NCT03394742?
# Will Mindful Self-Compassion (MSC) training improve Change in perceived general health status from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in Subjective Happiness Scale scores (Lyubomirsky & Lepper, 1999.; Extremera, 2013) from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in Satisfaction with Life Scale scores (Diener et al., 1985; Atienza et al., 2003) from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in Self-Compassion Scale (SCS) scores (Neff, 2003; García-Campayo et al., 2014) from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in Mindful Attention Awareness Scale (MAAS) scores (Brown & Ryan, 2003; Soler et al. 2012) from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in Meaning in Life Questionnaire (MLQ) scores (Steger et al., 2006) from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in Acceptance and Action Questionnaire-II (AAQ-II) scores (Bond et al., 2011;Ruiz et al. 2013) from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in the Activation Subscale of the Behavioural Activation for Depression Scale (BADS) scores (Kanter et al., 2007; Barraca et al., 2011) from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in Positive and Negative Affect Schedule (PANAS) scores (Watson, Clark & Tellegen, 1988; López-Gómez et al., 2015) from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in Cognitive Fusion Questionnaire (CFQ) scores (Gillanders et al.,2014; Romero-Moreno et al., 2014) from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in psychological flexibility scores from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in depression and anxiety scores from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in mental health self-informed status from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in Perceived Stress Scale (PSS) scores (Cohen et al. 1983; Remor & Carrobles, 2001) from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in burnout scores from pre-intervention at 8-week, 6-month and 12-month. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in basal glucose levels at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in cholesterol levels at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in triglyceride levels at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in High-density lipoprotein (HDL)-Cholesterol levels at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in Low-density lipoprotein (LDL)-Cholesterol levels. at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change ultrasensitive C-Reactive Protein (CRP) levels at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in the lipemia index at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in the jaundice index at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in the hemolysis index at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in the levels of aspartate aminotransferase (GOT/AST) at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
# Will Mindful Self-Compassion (MSC) training improve Change in lactate dehydrogenase (LDH) levels at T1 (pre), T2 (8-week), T3 (6-month), T4 (12-month) in Self-compassion, Mindfulness, Mental Health, Well-being, Inflammatory Response, Cardiovascular Health for trial NCT05695586?
#

# Will CBT-GSH with Noom Monitor improve Objective Binge Days at At 0 week in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Objective Binge Days at At 4 weeks in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Objective Binge Days at At 8 weeks in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Objective Binge Days at At 12 weeks in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Objective Binge Days at At 26 weeks in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Objective Binge Days at At 52 weeks in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Sum of Compensatory Episodes at At 0 week in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Sum of Compensatory Episodes at At 4 weeks in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Sum of Compensatory Episodes at At 8 weeks in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Sum of Compensatory Episodes at At 12 weeks in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Sum of Compensatory Episodes at At 26 weeks in Binge Eating Disorder for trial NCT02555553?
# Will CBT-GSH with Noom Monitor improve Sum of Compensatory Episodes at At 52 weeks in Binge Eating Disorder for trial NCT02555553?
# Will Normal therapy improve Central blood pressure at Baseline, up to 12 weeks after baseline. in Stroke for trial NCT05276453?
# Will Normal therapy improve Peripheral blood pressure at Baseline, up to 12 weeks after baseline. in Stroke for trial NCT05276453?
# Will Normal therapy improve Augmentation Index at Baseline, up to 12 weeks after baseline. in Stroke for trial NCT05276453?
# Will Normal therapy improve Pulse Wave Velocity at Baseline, up to 12 weeks after baseline. in Stroke for trial NCT05276453?
# Will Cognitive Behavioral Therapy improve PG-YBOCS at At each visit prior to and after therapy has been completed in Pathological Gambling for trial NCT00337753?
# Will Intensive Lifestyle Intervention improve Change in total body weight at Before intervention, after intervention (after 10-14 weeks) and follow up measurements after 1-13 years depending on when the lifestyle intervention took place in Obesity, Overweight for trial NCT02040753?
# Will Building Regulation in Dual Generations (BRIDGE; DBT + Parenting) improve Changes in child mental illness symptoms at The CBCL 1.5-5 and 6-18 will be assessed during eligibility screening (T0), pre-intervention (T1), within a month following the intervention (T2), and at 3-month follow-up (T3). in Maternal Depression, Self-Regulation, Emotion, Child Mental Disorder, Child Development, Attention Problems, Behaviour Problems, Parental Stress for trial NCT07083037?
# Will Building Regulation in Dual Generations (BRIDGE; DBT + Parenting) improve Changes in parent report measures of their children's executive function skills at Assessed at pre-intervention (T1) and within a month following the intervention (T2), and at 3-month follow-up (T3). in Maternal Depression, Self-Regulation, Emotion, Child Mental Disorder, Child Development, Attention Problems, Behaviour Problems, Parental Stress for trial NCT07083037?
# Will Building Regulation in Dual Generations (BRIDGE; DBT + Parenting) improve Changes in maternal mental health symptoms at The PHQ-9 will be assessed during eligibility screening (T0) , pre-intervention (T1), immediately after the intervention (T2), and at 3-month follow-up (T3). in Maternal Depression, Self-Regulation, Emotion, Child Mental Disorder, Child Development, Attention Problems, Behaviour Problems, Parental Stress for trial NCT07083037?
# Will Building Regulation in Dual Generations (BRIDGE; DBT + Parenting) improve Program Engagement at Attendance is measured weekly throughout the 12-week program and immediately after the intervention (T2). in Maternal Depression, Self-Regulation, Emotion, Child Mental Disorder, Child Development, Attention Problems, Behaviour Problems, Parental Stress for trial NCT07083037?
# Will Cardiovascular Health Awareness Program improve Healthcare Utilization Composite - Change in CVD-related emergency department visits and hospitalizations at Monthly from 1 year pre-intervention to 1 year post-intervention in Cardiovascular Diseases, Cardiovascular Risk Factor, Diabetes Mellitus for trial NCT03549845?
# Will Dietary program improve Change in Body Weight (Percentage) at 12 weeks in Obesity for trial NCT04614545?
# Will Autism Eats nutrition intervention improve Change in fruit and vegetable intake from baseline, as measured by the daily amount of fruit and vegetables consumed by children at baseline, post-intervention (10 weeks from baseline), and 5-month follow-up in Autism Spectrum Disorder for trial NCT05194345?
# Will Orientation improve Patients with orthosis, exercises and orientation will show better results in the evaluation scales regarding strength compared to the group with only orientation. at 2 years in Osteoarthritis Hand for trial NCT03173989?

# %%
with_results = [s for s in studies if s["hasResults"]]
without_results = [s for s in studies if not s["hasResults"]]
with_results[1]["protocolSection"]
without_results[0]["protocolSection"]
# Out:
# {'identificationModule': {'nctId': 'NCT04246424',
#   'briefTitle': 'Randomized Experiment of Sleep Technology'},
#  'statusModule': {'overallStatus': 'COMPLETED'},
#  'conditionsModule': {'conditions': ['Sleep']},
#  'armsInterventionsModule': {'interventions': [{'type': 'BEHAVIORAL',
#     'name': 'Fibit + Coaching',
#     'description': 'This intervention is a combination of the coaching and fitbit interventions',
#     'armGroupLabels': ['Fitbit + Coaching']},
#    {'type': 'BEHAVIORAL',
#     'name': 'Coaching',
#     'description': 'Coaching Participants who are assigned coaching group will receive telephone coaching. Coaches follow a guide developed by Kelly Glazer Baron, Jennifer Duffecy, Kathryn Reid, and Lauren Caccamo. The first session is an approximately 30 minute engagement session, with the purpose of "getting to know" the participant to increase likelihood for participation. The end goal is to have participants express Desire, Ability, Reason, Need, Can (DARN-C) to make changes in sleep). The remainder calls (week 2-6) are follow-up calls lasting about 5 minutes. The goal of these calls is to keep participants motivated and address any issues with the Fitbit hard or software.\n\nParticipants will also receive weekly email lessons to their personal email address for 1-6 weeks.',
#     'armGroupLabels': ['Coaching']},
#    {'type': 'BEHAVIORAL',
#     'name': 'Fitbit',
#     'description': 'Fitbit Participants in the fitbit group will receive a Fitbit Charge 3 black, and asked to wear it for 1-6 weeks. Participants will monitor their sleep through the sleep section in the Fitbit app on the smartphone. Participants will be provided login information so that researchers can access this data and asked to keep Bluetooth on. After week 6, participants can choose to continue to wear the device for the duration of the study (12 weeks). Though wear at weeks 7-12 is not required, researchers will still use any data that was collected from the fitbit during that time. At the completion of their participation, researchers retain the login information and the device is switched to a personal login of the participants choice.',
#     'armGroupLabels': ['Fitbit']}]},
#  'outcomesModule': {'primaryOutcomes': [{'measure': 'Sleep Duration (Assess changes in sleep quality)',
#     'description': 'Assess changes in sleep quality:Using the Philips Respironics Actiwatch (scoring completed using Philips Actiware 6), sleep duration and sleep quality will be assessed. Measures include bed/wake time, total time in bed, total sleep time, onset latency, sleep efficiency, number of awakenings and minutes awake during the night, or Wake After Sleep Onset (WASO). White, red, green and blue light will be measured using the device but only white light will be used in the assessment.',
#     'timeFrame': 'time points at visit 1 (week 1), visit 2 (week 6) and visit 3 (week 12)'},
#    {'measure': 'Sleep Duration',
#     'description': 'Assesses changes in daytime sleepiness: Using questionnaires Patient-Reported Outcomes Measurement Information System (PROMIS) Sleep-Related Impairment (2008-2012 PROMIS Health Organization and PROMIS Cooperative Group)',
#     'timeFrame': 'time points at visit 1 (week 1), visit 2 (week 6) and visit 3 (week 12)'},
#    {'measure': 'Sleep Duration',
#     'description': 'Assesses changes in daytime sleepiness: Munich Chronotype Questionnaire (Chronotype(en) 2008 Till Roenneberg, \\& Martha Merrow, LMU Munich) , daytime sleepiness and changes over the three time points will be assessed.',
#     'timeFrame': 'time points at visit 1 (week 1), visit 2 (week 6) and visit 3 (week 12)'}]}}
