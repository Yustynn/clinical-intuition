# %%
import pandas as pd
import ujson as json
import os


from glob import glob
from tqdm import tqdm

# %%
RAW_STUDIES_DIR = "../data/raw_studies"

# %%
paths = glob(os.path.join(RAW_STUDIES_DIR, "*.json"))
len(paths)
# Out:
# 34562

# %%
raw_studies = []

for path in tqdm(paths):
    with open(path, "r") as f:
        s = json.load(f)
        if s["hasResults"]:
            raw_studies.append(s)

print(f"Loaded {len(raw_studies)} raw studies with results")
# Out:
# 100%|██████████| 34562/34562 [00:07<00:00, 4537.59it/s]
# Loaded 5858 raw studies with results

# %%
sample = raw_studies[1]
sample["resultsSection"].keys()

id_mod = sample["protocolSection"]["identificationModule"]
print("Chosen sample study:", id_mod["briefTitle"])
print("https://clinicaltrials.gov/study/" + id_mod["nctId"])


outcomes = sample["resultsSection"]["outcomeMeasuresModule"]["outcomeMeasures"]
primary_outcomes_results = [o for o in outcomes if o["type"] == "PRIMARY"]
# Out:
# Chosen sample study: Computerized PAINRelieveIt Protocol for Cancer Pain Control in Hospice
# https://clinicaltrials.gov/study/NCT02026115

# %%
# Out:
# {'protocolSection': {'identificationModule': {'nctId': 'NCT02026115',
#    'orgStudyIdInfo': {'id': '2013-0986'},
#    'secondaryIdInfos': [{'id': 'IH-1304-6553',
#      'type': 'OTHER_GRANT',
#      'domain': 'Patient Centered Outcomes Research Institute (PCORI)'}],
#    'organization': {'fullName': 'University of Illinois at Chicago',
#     'class': 'OTHER'},
#    'briefTitle': 'Computerized PAINRelieveIt Protocol for Cancer Pain Control in Hospice',
#    'officialTitle': 'Computerized PAINRelieveIt Protocol for Cancer Pain Control in Hospice'},
#   'statusModule': {'statusVerifiedDate': '2025-08',
#    'overallStatus': 'COMPLETED',
#    'expandedAccessInfo': {'hasExpandedAccess': False},
#    'startDateStruct': {'date': '2014-01'},
#    'primaryCompletionDateStruct': {'date': '2016-09', 'type': 'ACTUAL'},
#    'completionDateStruct': {'date': '2016-09', 'type': 'ACTUAL'},
#    'studyFirstSubmitDate': '2013-12-28',
#    'studyFirstSubmitQcDate': '2013-12-30',
#    'studyFirstPostDateStruct': {'date': '2014-01-01', 'type': 'ESTIMATED'},
#    'resultsFirstSubmitDate': '2024-02-12',
#    'resultsFirstSubmitQcDate': '2025-08-25',
#    'resultsFirstPostDateStruct': {'date': '2025-09-15', 'type': 'ESTIMATED'},
#    'lastUpdateSubmitDate': '2025-08-25',
#    'lastUpdatePostDateStruct': {'date': '2025-09-15', 'type': 'ESTIMATED'}},
#   'sponsorCollaboratorsModule': {'responsibleParty': {'type': 'PRINCIPAL_INVESTIGATOR',
#     'investigatorFullName': 'Diana J. Wilkie',
#     'investigatorTitle': 'Adjunct Professor',
#     'investigatorAffiliation': 'University of Illinois at Chicago'},
#    'leadSponsor': {'name': 'University of Illinois at Chicago',
#     'class': 'OTHER'},
#    'collaborators': [{'name': 'Patient-Centered Outcomes Research Institute',
#      'class': 'OTHER'},
#     {'name': 'JourneyCare Home Health & Hospice', 'class': 'UNKNOWN'},
#     {'name': 'Rainbow Hospice', 'class': 'OTHER'}]},
#   'descriptionModule': {'briefSummary': "The study purpose is to compare usual hospice care and PAINRelieveIt groups for effects on: (1) patient outcomes (analgesic adherence; worst pain intensity, satisfaction, and misconceptions) and lay caregiver outcome (pain misconceptions) in a diverse sample of 250 cancer patient-caregiver dyads receiving hospice care; and (2) nurse outcomes (obtained appropriate analgesics for patient) in a sample of hospice nurses. The investigators hypothesize that at posttest, controlling for pretest data and compared to the usual care group, the PAINRelieveIt group will: a) report decreased scores for worst pain intensity and pain misconceptions; b) have increased analgesic adherence (primary outcome); and c) have a larger proportion who report satisfaction with pain intensity and whose nurses obtained appropriate analgesics for the patients' pain.",
#    'detailedDescription': "Unrelieved cancer pain at the end of life is a major health problem and is inconsistent with patient-centered goals for their last days. Building on a successful approach researched in outpatient oncology settings, the investigators propose a study testing PAINRelieveIt, a system-level intervention of computerized tools with patient-reported pain outcomes (in English, Spanish, Chinese languages), decision support for clinicians (English) and multimedia education tailored to each cancer patient and lay caregiver.\n\nUsing a 1-week pre-test/post-test randomized design in patients receiving home level hospice care provided by two Chicago-area hospices, we will compare effects of usual hospice care with PAINReportIt Summary and usual hospice care with PAINRelieveIt on pain outcomes. The tablet-based PAINRelieveIt includes valid and reliable pain tools (PAINReportIt), a summary of the patient's pain data with decision support for hospice nurses to obtain recommendations for algorithm-based analgesic therapies (PAINConsultN), and multimedia education tailored to the patient's and lay caregiver's pain management misconceptions (PainUCope). Patient's/caregiver's answers are automatically stored in an electronic database, from which the system generates a PAINReportIt Summary (usual hospice care control group); PAINConsultN and PainUCope (experimental group). All patients will receive usual hospice care. All patients/caregivers will complete PAINReportIt at pretest and 1-week later (posttest); patients also complete parts of PAINReportIt daily. Via daily e-mail updates, the control-group hospice nurses will receive a PAINReportIt Summary and experimental-group hospice nurses will receive a PAINConsultN. Additionally, experimental group patients/caregivers will view multimedia educational materials via PAINUCope to help patients report pain and adhere to prescribed analgesics.\n\nSpecific aims are to compare usual hospice care and PAINRelieveIt groups for effects on:\n\n1. Patient outcomes (analgesic adherence; worst pain intensity, satisfaction, and misconceptions) and lay caregiver outcome (pain misconceptions) in a diverse sample of 250 cancer patient-caregiver dyads receiving hospice care.\n2. Nurse outcomes (obtained appropriate analgesics for patient) in a sample of hospice nurses.\n\nThe investigators hypothesize that at posttest, controlling for pretest data and compared to the usual care group, the PAINRelieveIt group will: a) report decreased scores for worst pain intensity and pain misconceptions; b) have increased analgesic adherence (primary outcome); and c) have a larger proportion who report satisfaction with pain intensity and whose nurses obtained appropriate analgesics for the patients' pain.\n\nFindings will guide future system-level research to implement PAINRelieveIt in a multi-site, longitudinal trial that will test the effect of disseminating this technology on clinical decisions for managing pain and patient/caregiver pain outcomes in a national sample of hospices. This approach offers improved pain control for dying patients and other populations."},
#   'conditionsModule': {'conditions': ['Cancer', 'Pain'],
#    'keywords': ['cancer', 'hospice', 'pain']},
#   'designModule': {'studyType': 'INTERVENTIONAL',
#    'phases': ['NA'],
#    'designInfo': {'allocation': 'RANDOMIZED',
#     'interventionModel': 'PARALLEL',
#     'primaryPurpose': 'SUPPORTIVE_CARE',
#     'maskingInfo': {'masking': 'TRIPLE',
#      'whoMasked': ['PARTICIPANT', 'CARE_PROVIDER', 'INVESTIGATOR']}},
#    'enrollmentInfo': {'count': 262, 'type': 'ACTUAL'}},
#   'armsInterventionsModule': {'armGroups': [{'label': 'usual hospice care',
#      'type': 'ACTIVE_COMPARATOR',
#      'description': 'The usual care group will receive the typical hospice care and interact with PAINReportIt to provide data necessary for the analysis of study aims. They will use the tablet computer at baseline and at the study end and daily between. They also will have access to what looks like PAINUCope, but is really computer games so that they have similar attention with the computer as the experimental group. For ethical purposes, we will provide a PAINReportIt Summary to their hospice nurses to have access to their pain assessment information, something we did not do in previous studies focused on efficacy of the interventions.',
#      'interventionNames': ['Behavioral: PAINReportIt']},
#     {'label': 'PAINRelieveIt (experimental group)',
#      'type': 'EXPERIMENTAL',
#      'description': "We will use Nursing Consult LLC's PAINRelieveIt software that includes: (1) PAINReportIt that has screens to collect pain, medications, and misconception data; (2) the intervention for the nurse clinicians, PAINConsultN; and (3) the intervention for the patients and lay caregiver, PAINUCope. This innovative, new program is the first computerized, multi-dimensional, self-report measure of pain with clinician decision support for analgesic prescriptions and multimedia patient education tailored to the patient's misconceptions and pain. Prototype versions of PAINConsultN and PAINUCope were tested in recently completed studies among outpatients with cancer and patients with sickle cell disease in outpatient, emergency and hospital settings.",
#      'interventionNames': ['Behavioral: PAINReportIt',
#       'Behavioral: PAINConsultN',
#       'Behavioral: PAINUCope']}],
#    'interventions': [{'type': 'BEHAVIORAL',
#      'name': 'PAINReportIt',
#      'description': 'PAINReportIt is a software program developed with an electronic McGill Pain Questionnaire (MPQ) and now includes questions about analgesics used by patients and a shortened version of the pain Barriers Questionnaire (BQ). It is designed as an interactive, touch screen way to assess pain. It can be self-administered and requires little or no patient computer experience and little or no provider time. The patient can read instructions on-screen and practice all types of selection responses found the program. Directions from the paper tools were modified to address the touch screen method of recording responses. The copyright is owned by Dr. Ronald Melzack for the MPQ and Dr. Sandra Ward for the BQ. Both individuals authorized the modifications, format, and computerized use of the tools.',
#      'armGroupLabels': ['PAINRelieveIt (experimental group)',
#       'usual hospice care'],
#      'otherNames': ["PAINRelieveIt's PAINReportIt"]},
#     {'type': 'BEHAVIORAL',
#      'name': 'PAINConsultN',
#      'description': "PAINConsultN for hospice nurses. Our previous studies support the feasibility and clinical effect of PAINConsultN. This narrative and graphic tool provides decision support for the nurse's clinical decisions regarding management of the patient's pain. Based on the PAINReportIt output and published cancer pain guidelines, PAINConsultN generates an algorithm-based consultation report with a list of recommendations that could be useful to provide improved pain relief. If the patient's PAINReportIt output indicates the pain level is consistent with the patient's goals for pain management and represents no pain or a mild pain level, the consultation report acknowledges the therapy plan and reinforces its consistency with pain guidelines.",
#      'armGroupLabels': ['PAINRelieveIt (experimental group)'],
#      'otherNames': ["PAINRelieveIt's PANConsultN"]},
#     {'type': 'BEHAVIORAL',
#      'name': 'PAINUCope',
#      'description': "We tested the PAINUCope piece of the intervention in 3 completed studies. PAINUCope is a multimedia, computer generated tool that gives tailored information to overcome patients' misconceptions about pain and help them engage in activities that help reduce their pain. PAINUCope focuses on 2 crucial aspects of pain management: 1) reporting cancer pain and 2) safe and effective use of pain medicines. The educational materials are written at a 6th grade reading level and presented as 21st Century best-practices, evidence-based facts or scripts for the person with cancer or sickle cell disease (in one study). The facts or scripts are customized to the patient's need for this type of health information. The patient's responses on PAINReportIt guide the specific information shared via PAINUCope.",
#      'armGroupLabels': ['PAINRelieveIt (experimental group)'],
#      'otherNames': ["PAINRelieveIt's PAINUCope"]}]},
#   'outcomesModule': {'primaryOutcomes': [{'measure': 'Analgesic Adherence-patient',
#      'description': 'Analgesic adherence is derived from data regarding analgesics documented as prescribed (available to the patient as indicated from the medication list in the home) and analgesics consumed (from PAINReportIt). We calculate an analgesic adherence rate (dose reported as consumed divided by dose documented as prescribed, multiplied by 100) for all World Health Organization (WHO) analgesics (adjuvants, NSAIDs and non-opioids, and ATC and PRN Step 2 and Step 3 opioids).',
#      'timeFrame': 'Average of daily adherence (days 1 to 7)'}],
#    'secondaryOutcomes': [{'measure': 'Worst Pain Intensity-patient',
#      'description': 'worst pain intensity in previous 24 hours measured on 0 to 10 scale where 0 means no pain and 10 means pain as bad as it can be.',
#      'timeFrame': 'Average of daily worse pain intensity (days 1 to 7)'}],
#    'otherOutcomes': [{'measure': 'Misconceptions About Pain and Pain Management--patient',
#      'description': 'Misconceptions are measured with a computer version of the Barriers Questionnaire (BQ) with response options from 0 to 5 indicating the amount of agreement with statements about barriers to pain assessment or management. Items relate to communicating with the physician about pain, side effects of analgesics, concerns about addiction, tolerance, disease progression, and being perceived as a good patient. Validity of the BQ is supported by its ability to discriminate cancer patients who report high BQ scores and also were under-medicated for their pain level and were hesitant to report their pain to their clinicians. To improve the acceptability of the tool to patients with cancer, we reduced the tool to 13 items with demonstrated validity and reliability. In prior cancer studies, patients found it to be a simple, easily understood tool that they completed in 5 minutes or less on 13 screens using a touch-screen pentablet computer.',
#      'timeFrame': 'pretest at baseline (day 0) & posttest on day 7; day 7 reported'},
#     {'measure': 'Satisfaction With Pain Levels -- Patient',
#      'description': 'Satisfaction with pain levels is measured by two single item questions that ask the patient if he or she is satisfied with the level of pain. A three-option response allows the patient to indicate yes, no, or not sure. We tested this item in our previous study and found that 49% of patients were satisfied with their pain level at baseline were also satisfied 4 weeks later, 21% became satisfied, 18% became less satisfied and 12% were never satisfied during the 4-week study. These data are consistent with the high percentage (98%) of patients who reported a desire for no pain but whose worst pain was greater than the level they desired. Focusing on satisfaction with level of pain allows us to have greater variability in this variable than has been typically noted by other investigators.',
#      'timeFrame': 'Average of distribution of satisfaction with pain level reported each day (days 1 to 7).'},
#     {'measure': 'Misconceptions About Pain and Pain Management--caregiver',
#      'description': 'Misconceptions are measured with a computer version of the Barriers Questionnaire (BQ) with response options from 0 to 5 indicating the amount of agreement with statements about barriers to pain assessment or management. Items relate to communicating with the physician about pain, side effects of analgesics, concerns about addiction, tolerance, disease progression, and being perceived as a good patient. Validity of the BQ is supported by its ability to discriminate cancer patients who report high BQ scores and also were under-medicated for their pain level and were hesitant to report their pain to their clinicians. To improve the acceptability of the tool to patients with cancer, we reduced the tool to 13 items with demonstrated validity and reliability. In prior cancer studies, patients found it to be a simple, easily understood tool that they completed in 5 minutes or less on 13 screens using a touch-screen pentablet computer.',
#      'timeFrame': 'pretest at baseline (day 0) & posttest on day 7; day 7 reported'},
#     {'measure': 'Appropriateness of Analgesics Prescribed --Hospice Nurse',
#      'description': "We will measure the appropriateness of a patient's analgesic prescription on a given day using Cleeland's Pain Management Index (PMI). For a given day, a patient's analgesic score (0=no analgesic, 1=non-opioid, 2=weak opioid, 3=strong opioid) is subtracted by their pain intensity category (0 = worst pain of 0; 1 = worst pain of 1-3; 2 = worst pain of 4-6; 3 = worst pain of 7-10) to obtain their PMI score for the day. Negative PMI scores indicate inadequate analgesics while 0 or positive PMI scores indicate appropriate analgesics. For each patient, the outcome measure is the proportion of day with appropriate analgesics.",
#      'timeFrame': 'proportion of days (days 1 to 7) with appropriate analgesics'}]},
#   'eligibilityModule': {'eligibilityCriteria': 'Inclusion Criteria:\n\nStudy inclusion criteria require that the patient: (1) be admitted to home care level of hospice service; (2) has a diagnosis of cancer; (3) has experienced worst pain in the past 24 hours \\>3 on a 0-10 scale; (4) speaks, reads and writes English, Spanish, or Chinese; (5) is \\> 18 years of age; 6) has a lay caregiver who is \\> 18 years of age and willing to participate; and (7) has a life expectancy of about 19 days at the time of study enrollment, as suggested by a Palliative Performance Scale (PPS)41 score of \\> 40.\n\nThe lay caregiver inclusion criteria require that the individual: (1) be designated as the primary lay caregiver for the participating patient during the 7-day study period; (2) speaks, reads and writes English, Spanish, or Chinese; and (3) is \\> 18 years of age.\n\nThe hospice nurse inclusion criteria require that the individual: (1) be assigned as the primary hospice nurse for the participating patient during the 7-day study period; (2) speaks, reads and writes English (since the PAINConsultN is in English) but may speak Spanish or Chinese for clinical care purposes; and (3) is \\> 18 years of age.\n\nExclusion Criteria:\n\n* Patients and lay caregivers will be excluded if they: (1) are legally blind or deaf; or (2) have cognitive or physical impairments making it impossible to communicate or to complete study instruments at enrollment or any time during the study.',
#    'healthyVolunteers': False,
#    'sex': 'ALL',
#    'minimumAge': '18 Years',
#    'stdAges': ['ADULT', 'OLDER_ADULT']}},
#  'resultsSection': {'participantFlowModule': {'groups': [{'id': 'FG000',
#      'title': 'Usual Hospice Care',
#      'description': 'The usual care group will receive the typical hospice care and interact with PAINReportIt to provide data necessary for the analysis of study aims. They will use the tablet computer at baseline and at the study end and daily between. They also will have access to what looks like PAINUCope, but is really computer games so that they have similar attention with the computer as the experimental group. For ethical purposes, we will provide a PAINReportIt Summary to their hospice nurses to have access to their pain assessment information, something we did not do in previous studies focused on efficacy of the interventions.'},
#     {'id': 'FG001',
#      'title': 'PAINRelieveIt (Experimental Group)',
#      'description': "We will use Nursing Consult LLC's PAINRelieveIt software that includes: (1) PAINReportIt that has screens to collect pain, medications, and misconception data; (2) the intervention for the nurse clinicians, PAINConsultN; and (3) the intervention for the patients and lay caregiver, PAINUCope. This innovative, new program is the first computerized, multi-dimensional, self-report measure of pain with clinician decision support for analgesic prescriptions and multimedia patient education tailored to the patient's misconceptions and pain. Prototype versions of PAINConsultN and PAINUCope were tested in recently completed studies among outpatients with cancer and patients with sickle cell disease in outpatient, emergency and hospital settings."}],
#    'periods': [{'title': 'Overall Study',
#      'milestones': [{'type': 'STARTED',
#        'achievements': [{'groupId': 'FG000', 'numSubjects': '170'},
#         {'groupId': 'FG001', 'numSubjects': '92'}]},
#       {'type': 'COMPLETED',
#        'achievements': [{'groupId': 'FG000', 'numSubjects': '154'},
#         {'groupId': 'FG001', 'numSubjects': '80'}]},
#       {'type': 'NOT COMPLETED',
#        'achievements': [{'groupId': 'FG000', 'numSubjects': '16'},
#         {'groupId': 'FG001', 'numSubjects': '12'}]}]}]},
#   'baselineCharacteristicsModule': {'groups': [{'id': 'BG000',
#      'title': 'Usual Hospice Care',
#      'description': 'The usual care group will receive the typical hospice care and interact with PAINReportIt to provide data necessary for the analysis of study aims. They will use the tablet computer at baseline and at the study end and daily between. They also will have access to what looks like PAINUCope, but is really computer games so that they have similar attention with the computer as the experimental group. For ethical purposes, we will provide a PAINReportIt Summary to their hospice nurses to have access to their pain assessment information, something we did not do in previous studies focused on efficacy of the interventions.'},
#     {'id': 'BG001',
#      'title': 'PAINRelieveIt (Experimental Group)',
#      'description': "We will use Nursing Consult LLC's PAINRelieveIt software that includes: (1) PAINReportIt that has screens to collect pain, medications, and misconception data; (2) the intervention for the nurse clinicians, PAINConsultN; and (3) the intervention for the patients and lay caregiver, PAINUCope. This innovative, new program is the first computerized, multi-dimensional, self-report measure of pain with clinician decision support for analgesic prescriptions and multimedia patient education tailored to the patient's misconceptions and pain. Prototype versions of PAINConsultN and PAINUCope were tested in recently completed studies among outpatients with cancer and patients with sickle cell disease in outpatient, emergency and hospital settings."},
#     {'id': 'BG002',
#      'title': 'Total',
#      'description': 'Total of all reporting groups'}],
#    'denoms': [{'units': 'Participants',
#      'counts': [{'groupId': 'BG000', 'value': '154'},
#       {'groupId': 'BG001', 'value': '80'},
#       {'groupId': 'BG002', 'value': '234'}]}],
#    'measures': [{'title': 'Age, Continuous',
#      'paramType': 'MEAN',
#      'dispersionType': 'STANDARD_DEVIATION',
#      'unitOfMeasure': 'years',
#      'classes': [{'categories': [{'measurements': [{'groupId': 'BG000',
#            'value': '67.9',
#            'spread': '14.4'},
#           {'groupId': 'BG001', 'value': '69.5', 'spread': '13.1'},
#           {'groupId': 'BG002', 'value': '68.4', 'spread': '14.0'}]}]}]},
#     {'title': 'Sex: Female, Male',
#      'paramType': 'COUNT_OF_PARTICIPANTS',
#      'unitOfMeasure': 'Participants',
#      'classes': [{'categories': [{'title': 'Female',
#          'measurements': [{'groupId': 'BG000', 'value': '81'},
#           {'groupId': 'BG001', 'value': '38'},
#           {'groupId': 'BG002', 'value': '119'}]},
#         {'title': 'Male',
#          'measurements': [{'groupId': 'BG000', 'value': '73'},
#           {'groupId': 'BG001', 'value': '42'},
#           {'groupId': 'BG002', 'value': '115'}]}]}]},
#     {'title': 'Ethnicity (NIH/OMB)',
#      'paramType': 'COUNT_OF_PARTICIPANTS',
#      'unitOfMeasure': 'Participants',
#      'classes': [{'categories': [{'title': 'Hispanic or Latino',
#          'measurements': [{'groupId': 'BG000', 'value': '28'},
#           {'groupId': 'BG001', 'value': '14'},
#           {'groupId': 'BG002', 'value': '42'}]},
#         {'title': 'Not Hispanic or Latino',
#          'measurements': [{'groupId': 'BG000', 'value': '126'},
#           {'groupId': 'BG001', 'value': '66'},
#           {'groupId': 'BG002', 'value': '192'}]},
#         {'title': 'Unknown or Not Reported',
#          'measurements': [{'groupId': 'BG000', 'value': '0'},
#           {'groupId': 'BG001', 'value': '0'},
#           {'groupId': 'BG002', 'value': '0'}]}]}]},
#     {'title': 'Race (NIH/OMB)',
#      'paramType': 'COUNT_OF_PARTICIPANTS',
#      'unitOfMeasure': 'Participants',
#      'classes': [{'categories': [{'title': 'American Indian or Alaska Native',
#          'measurements': [{'groupId': 'BG000', 'value': '0'},
#           {'groupId': 'BG001', 'value': '0'},
#           {'groupId': 'BG002', 'value': '0'}]},
#         {'title': 'Asian',
#          'measurements': [{'groupId': 'BG000', 'value': '1'},
#           {'groupId': 'BG001', 'value': '0'},
#           {'groupId': 'BG002', 'value': '1'}]},
#         {'title': 'Native Hawaiian or Other Pacific Islander',
#          'measurements': [{'groupId': 'BG000', 'value': '0'},
#           {'groupId': 'BG001', 'value': '0'},
#           {'groupId': 'BG002', 'value': '0'}]},
#         {'title': 'Black or African American',
#          'measurements': [{'groupId': 'BG000', 'value': '56'},
#           {'groupId': 'BG001', 'value': '25'},
#           {'groupId': 'BG002', 'value': '81'}]},
#         {'title': 'White',
#          'measurements': [{'groupId': 'BG000', 'value': '71'},
#           {'groupId': 'BG001', 'value': '44'},
#           {'groupId': 'BG002', 'value': '115'}]},
#         {'title': 'More than one race',
#          'measurements': [{'groupId': 'BG000', 'value': '4'},
#           {'groupId': 'BG001', 'value': '0'},
#           {'groupId': 'BG002', 'value': '4'}]},
#         {'title': 'Unknown or Not Reported',
#          'measurements': [{'groupId': 'BG000', 'value': '22'},
#           {'groupId': 'BG001', 'value': '11'},
#           {'groupId': 'BG002', 'value': '33'}]}]}]},
#     {'title': 'Adherence Rate for Scheduled Opioids',
#      'description': 'Analgesic adherence is derived from data regarding analgesics documented as prescribed (available to the patient as indicated from the medication list in the home) and analgesics consumed (from PAINReportIt). We calculate an analgesic adherence rate (dose reported as consumed divided by dose documented as prescribed) for all World Health Organization (WHO) analgesics (adjuvants, NSAIDs and non-opioids, and ATC and PRN Step 2 and Step 3 opioids).',
#      'paramType': 'MEAN',
#      'dispersionType': 'STANDARD_DEVIATION',
#      'unitOfMeasure': 'proportion of adherence (0-1)',
#      'classes': [{'categories': [{'measurements': [{'groupId': 'BG000',
#            'value': '0.59',
#            'spread': '0.33'},
#           {'groupId': 'BG001', 'value': '0.66', 'spread': '0.31'},
#           {'groupId': 'BG002', 'value': '0.61', 'spread': '0.33'}]}]}]},
#     {'title': 'Worst Pain Intensity',
#      'description': 'worst pain intensity in previous 24 hours measured on 0 to 10 scale where 0 means no pain and 10 means pain as bad as it can be.',
#      'paramType': 'MEAN',
#      'dispersionType': 'STANDARD_DEVIATION',
#      'unitOfMeasure': 'units on a scale (0-10)',
#      'classes': [{'categories': [{'measurements': [{'groupId': 'BG000',
#            'value': '7.09',
#            'spread': '2.29'},
#           {'groupId': 'BG001', 'value': '6.99', 'spread': '2.52'},
#           {'groupId': 'BG002', 'value': '7.06', 'spread': '2.37'}]}]}]},
#     {'title': 'Least Pain Intensity',
#      'description': 'least pain intensity in previous 24 hours measured on 0 to 10 scale where 0 means no pain and 10 means pain as bad as it can be.',
#      'paramType': 'MEAN',
#      'dispersionType': 'STANDARD_DEVIATION',
#      'unitOfMeasure': 'units on a scale (0-10)',
#      'classes': [{'categories': [{'measurements': [{'groupId': 'BG000',
#            'value': '3.17',
#            'spread': '2.40'},
#           {'groupId': 'BG001', 'value': '3.09', 'spread': '2.27'},
#           {'groupId': 'BG002', 'value': '3.15', 'spread': '2.35'}]}]}]},
#     {'title': 'Current Pain Intensity',
#      'paramType': 'MEAN',
#      'dispersionType': 'STANDARD_DEVIATION',
#      'unitOfMeasure': 'units on a scale (0-10)',
#      'classes': [{'categories': [{'measurements': [{'groupId': 'BG000',
#            'value': '4.76',
#            'spread': '2.72'},
#           {'groupId': 'BG001', 'value': '4.64', 'spread': '2.51'},
#           {'groupId': 'BG002', 'value': '4.72', 'spread': '2.64'}]}]}]},
#     {'title': 'Satisfaction with Pain Level',
#      'paramType': 'COUNT_OF_PARTICIPANTS',
#      'unitOfMeasure': 'Participants',
#      'classes': [{'categories': [{'title': 'Satisfied',
#          'measurements': [{'groupId': 'BG000', 'value': '56'},
#           {'groupId': 'BG001', 'value': '31'},
#           {'groupId': 'BG002', 'value': '87'}]},
#         {'title': 'Not sure',
#          'measurements': [{'groupId': 'BG000', 'value': '16'},
#           {'groupId': 'BG001', 'value': '10'},
#           {'groupId': 'BG002', 'value': '26'}]},
#         {'title': 'Not satisfied',
#          'measurements': [{'groupId': 'BG000', 'value': '82'},
#           {'groupId': 'BG001', 'value': '39'},
#           {'groupId': 'BG002', 'value': '121'}]}]}]},
#     {'title': 'Pain Barrier -- Patient',
#      'description': 'Misconceptions are measured with a computer version of the Barriers Questionnaire (BQ) with response options from 0 to 5 indicating the amount of agreement with statements about barriers to pain assessment or management. Items relate to communicating with the physician about pain, side effects of analgesics, concerns about addiction, tolerance, disease progression, and being perceived as a good patient. To improve the acceptability of the tool to patients with cancer, we reduced the tool to 13 items with demonstrated validity and reliability.',
#      'paramType': 'MEAN',
#      'dispersionType': 'STANDARD_DEVIATION',
#      'unitOfMeasure': 'units on a scale (0-5)',
#      'classes': [{'categories': [{'measurements': [{'groupId': 'BG000',
#            'value': '2.75',
#            'spread': '0.81'},
#           {'groupId': 'BG001', 'value': '2.44', 'spread': '0.86'},
#           {'groupId': 'BG002', 'value': '2.64', 'spread': '0.84'}]}]}]},
#     {'title': 'Pain Barrier -- Caregiver',
#      'description': 'Misconceptions are measured with a computer version of the Barriers Questionnaire (BQ) with response options from 0 to 5 indicating the amount of agreement with statements about barriers to pain assessment or management. Items relate to communicating with the physician about pain, side effects of analgesics, concerns about addiction, tolerance, disease progression, and being perceived as a good patient. To improve the acceptability of the tool to patients with cancer, we reduced the tool to 13 items with demonstrated validity and reliability.',
#      'paramType': 'MEAN',
#      'dispersionType': 'STANDARD_DEVIATION',
#      'unitOfMeasure': 'units on a scale (0-5)',
#      'classes': [{'categories': [{'measurements': [{'groupId': 'BG000',
#            'value': '2.74',
#            'spread': '0.93'},
#           {'groupId': 'BG001', 'value': '2.81', 'spread': '0.85'},
#           {'groupId': 'BG002', 'value': '2.77', 'spread': '0.90'}]}]}]}]},
#   'outcomeMeasuresModule': {'outcomeMeasures': [{'type': 'PRIMARY',
#      'title': 'Analgesic Adherence-patient',
#      'description': 'Analgesic adherence is derived from data regarding analgesics documented as prescribed (available to the patient as indicated from the medication list in the home) and analgesics consumed (from PAINReportIt). We calculate an analgesic adherence rate (dose reported as consumed divided by dose documented as prescribed, multiplied by 100) for all World Health Organization (WHO) analgesics (adjuvants, NSAIDs and non-opioids, and ATC and PRN Step 2 and Step 3 opioids).',
#      'populationDescription': 'Intent to treat analysis with multiple imputation based missing data processing.',
#      'reportingStatus': 'POSTED',
#      'paramType': 'MEAN',
#      'dispersionType': 'Standard Deviation',
#      'unitOfMeasure': 'proportion (0-1), higher is better',
#      'timeFrame': 'Average of daily adherence (days 1 to 7)',
#      'groups': [{'id': 'OG000',
#        'title': 'Usual Hospice Care',
#        'description': 'The usual care group will receive the typical hospice care and interact with PAINReportIt to provide data necessary for the analysis of study aims. They will use the tablet computer at baseline and at the study end and daily between. They also will have access to what looks like PAINUCope, but is really computer games so that they have similar attention with the computer as the experimental group. For ethical purposes, we will provide a PAINReportIt Summary to their hospice nurses to have access to their pain assessment information, something we did not do in previous studies focused on efficacy of the interventions.'},
#       {'id': 'OG001',
#        'title': 'PAINRelieveIt (Experimental Group)',
#        'description': "We will use Nursing Consult LLC's PAINRelieveIt software that includes: (1) PAINReportIt that has screens to collect pain, medications, and misconception data; (2) the intervention for the nurse clinicians, PAINConsultN; and (3) the intervention for the patients and lay caregiver, PAINUCope. This innovative, new program is the first computerized, multi-dimensional, self-report measure of pain with clinician decision support for analgesic prescriptions and multimedia patient education tailored to the patient's misconceptions and pain. Prototype versions of PAINConsultN and PAINUCope were tested in recently completed studies among outpatients with cancer and patients with sickle cell disease in outpatient, emergency and hospital settings."}],
#      'denoms': [{'units': 'Participants',
#        'counts': [{'groupId': 'OG000', 'value': '154'},
#         {'groupId': 'OG001', 'value': '80'}]}],
#      'classes': [{'categories': [{'measurements': [{'groupId': 'OG000',
#            'value': '0.66',
#            'spread': '0.27'},
#           {'groupId': 'OG001', 'value': '0.67', 'spread': '0.24'}]}]}],
#      'analyses': [{'groupIds': ['OG000', 'OG001'],
#        'nonInferiorityType': 'SUPERIORITY',
#        'pValue': '.43',
#        'statisticalMethod': 'Mixed Models Analysis'}]},
#     {'type': 'SECONDARY',
#      'title': 'Worst Pain Intensity-patient',
#      'description': 'worst pain intensity in previous 24 hours measured on 0 to 10 scale where 0 means no pain and 10 means pain as bad as it can be.',
#      'populationDescription': 'Intent to treat analysis with multiple imputations.',
#      'reportingStatus': 'POSTED',
#      'paramType': 'MEAN',
#      'dispersionType': 'Standard Deviation',
#      'unitOfMeasure': 'units on a scale (0-10); lower is better',
#      'timeFrame': 'Average of daily worse pain intensity (days 1 to 7)',
#      'groups': [{'id': 'OG000',
#        'title': 'Usual Hospice Care',
#        'description': 'The usual care group will receive the typical hospice care and interact with PAINReportIt to provide data necessary for the analysis of study aims. They will use the tablet computer at baseline and at the study end and daily between. They also will have access to what looks like PAINUCope, but is really computer games so that they have similar attention with the computer as the experimental group. For ethical purposes, we will provide a PAINReportIt Summary to their hospice nurses to have access to their pain assessment information, something we did not do in previous studies focused on efficacy of the interventions.'},
#       {'id': 'OG001',
#        'title': 'PAINRelieveIt (Experimental Group)',
#        'description': "We will use Nursing Consult LLC's PAINRelieveIt software that includes: (1) PAINReportIt that has screens to collect pain, medications, and misconception data; (2) the intervention for the nurse clinicians, PAINConsultN; and (3) the intervention for the patients and lay caregiver, PAINUCope. This innovative, new program is the first computerized, multi-dimensional, self-report measure of pain with clinician decision support for analgesic prescriptions and multimedia patient education tailored to the patient's misconceptions and pain. Prototype versions of PAINConsultN and PAINUCope were tested in recently completed studies among outpatients with cancer and patients with sickle cell disease in outpatient, emergency and hospital settings."}],
#      'denoms': [{'units': 'Participants',
#        'counts': [{'groupId': 'OG000', 'value': '154'},
#         {'groupId': 'OG001', 'value': '80'}]}],
#      'classes': [{'categories': [{'measurements': [{'groupId': 'OG000',
#            'value': '6.05',
#            'spread': '2.24'},
#           {'groupId': 'OG001', 'value': '6.63', 'spread': '2.12'}]}]}],
#      'analyses': [{'groupIds': ['OG000', 'OG001'],
#        'nonInferiorityType': 'SUPERIORITY',
#        'pValue': '.02',
#        'pValueComment': 'Experimental group performed worse than usual care.',
#        'statisticalMethod': 'Mixed Models Analysis'}]},
#     {'type': 'OTHER_PRE_SPECIFIED',
#      'title': 'Misconceptions About Pain and Pain Management--patient',
#      'description': 'Misconceptions are measured with a computer version of the Barriers Questionnaire (BQ) with response options from 0 to 5 indicating the amount of agreement with statements about barriers to pain assessment or management. Items relate to communicating with the physician about pain, side effects of analgesics, concerns about addiction, tolerance, disease progression, and being perceived as a good patient. Validity of the BQ is supported by its ability to discriminate cancer patients who report high BQ scores and also were under-medicated for their pain level and were hesitant to report their pain to their clinicians. To improve the acceptability of the tool to patients with cancer, we reduced the tool to 13 items with demonstrated validity and reliability. In prior cancer studies, patients found it to be a simple, easily understood tool that they completed in 5 minutes or less on 13 screens using a touch-screen pentablet computer.',
#      'populationDescription': 'Intent to treat analysis with multiple imputation based missing data processing.',
#      'reportingStatus': 'POSTED',
#      'paramType': 'MEAN',
#      'dispersionType': 'Standard Deviation',
#      'unitOfMeasure': 'units on a scale (0-5); lower is better',
#      'timeFrame': 'pretest at baseline (day 0) & posttest on day 7; day 7 reported',
#      'groups': [{'id': 'OG000',
#        'title': 'Usual Hospice Care',
#        'description': 'The usual care group will receive the typical hospice care and interact with PAINReportIt to provide data necessary for the analysis of study aims. They will use the tablet computer at baseline and at the study end and daily between. They also will have access to what looks like PAINUCope, but is really computer games so that they have similar attention with the computer as the experimental group. For ethical purposes, we will provide a PAINReportIt Summary to their hospice nurses to have access to their pain assessment information, something we did not do in previous studies focused on efficacy of the interventions.'},
#       {'id': 'OG001',
#        'title': 'PAINRelieveIt (Experimental Group)',
#        'description': "We will use Nursing Consult LLC's PAINRelieveIt software that includes: (1) PAINReportIt that has screens to collect pain, medications, and misconception data; (2) the intervention for the nurse clinicians, PAINConsultN; and (3) the intervention for the patients and lay caregiver, PAINUCope. This innovative, new program is the first computerized, multi-dimensional, self-report measure of pain with clinician decision support for analgesic prescriptions and multimedia patient education tailored to the patient's misconceptions and pain. Prototype versions of PAINConsultN and PAINUCope were tested in recently completed studies among outpatients with cancer and patients with sickle cell disease in outpatient, emergency and hospital settings."}],
#      'denoms': [{'units': 'Participants',
#        'counts': [{'groupId': 'OG000', 'value': '154'},
#         {'groupId': 'OG001', 'value': '80'}]}],
#      'classes': [{'categories': [{'measurements': [{'groupId': 'OG000',
#            'value': '2.72',
#            'spread': '0.79'},
#           {'groupId': 'OG001', 'value': '2.56', 'spread': '0.87'}]}]}],
#      'analyses': [{'groupIds': ['OG000', 'OG001'],
#        'nonInferiorityType': 'SUPERIORITY',
#        'pValue': '.32',
#        'statisticalMethod': 'Regression, Linear'}]},
#     {'type': 'OTHER_PRE_SPECIFIED',
#      'title': 'Satisfaction With Pain Levels -- Patient',
#      'description': 'Satisfaction with pain levels is measured by two single item questions that ask the patient if he or she is satisfied with the level of pain. A three-option response allows the patient to indicate yes, no, or not sure. We tested this item in our previous study and found that 49% of patients were satisfied with their pain level at baseline were also satisfied 4 weeks later, 21% became satisfied, 18% became less satisfied and 12% were never satisfied during the 4-week study. These data are consistent with the high percentage (98%) of patients who reported a desire for no pain but whose worst pain was greater than the level they desired. Focusing on satisfaction with level of pain allows us to have greater variability in this variable than has been typically noted by other investigators.',
#      'populationDescription': 'Intent to treat analysis with multiple imputation based missing data processing',
#      'reportingStatus': 'POSTED',
#      'paramType': 'COUNT_OF_PARTICIPANTS',
#      'unitOfMeasure': 'Participants',
#      'timeFrame': 'Average of distribution of satisfaction with pain level reported each day (days 1 to 7).',
#      'groups': [{'id': 'OG000',
#        'title': 'Usual Hospice Care',
#        'description': 'The usual care group will receive the typical hospice care and interact with PAINReportIt to provide data necessary for the analysis of study aims. They will use the tablet computer at baseline and at the study end and daily between. They also will have access to what looks like PAINUCope, but is really computer games so that they have similar attention with the computer as the experimental group. For ethical purposes, we will provide a PAINReportIt Summary to their hospice nurses to have access to their pain assessment information, something we did not do in previous studies focused on efficacy of the interventions.'},
#       {'id': 'OG001',
#        'title': 'PAINRelieveIt (Experimental Group)',
#        'description': "We will use Nursing Consult LLC's PAINRelieveIt software that includes: (1) PAINReportIt that has screens to collect pain, medications, and misconception data; (2) the intervention for the nurse clinicians, PAINConsultN; and (3) the intervention for the patients and lay caregiver, PAINUCope. This innovative, new program is the first computerized, multi-dimensional, self-report measure of pain with clinician decision support for analgesic prescriptions and multimedia patient education tailored to the patient's misconceptions and pain. Prototype versions of PAINConsultN and PAINUCope were tested in recently completed studies among outpatients with cancer and patients with sickle cell disease in outpatient, emergency and hospital settings."}],
#      'denoms': [{'units': 'Participants',
#        'counts': [{'groupId': 'OG000', 'value': '154'},
#         {'groupId': 'OG001', 'value': '80'}]}],
#      'classes': [{'title': 'Satisfied',
#        'categories': [{'measurements': [{'groupId': 'OG000', 'value': '50'},
#           {'groupId': 'OG001', 'value': '24'}]}]},
#       {'title': 'Not sure',
#        'categories': [{'measurements': [{'groupId': 'OG000', 'value': '24'},
#           {'groupId': 'OG001', 'value': '13'}]}]},
#       {'title': 'Not satisfied',
#        'categories': [{'measurements': [{'groupId': 'OG000', 'value': '80'},
#           {'groupId': 'OG001', 'value': '43'}]}]}],
#      'analyses': [{'groupIds': ['OG000', 'OG001'],
#        'nonInferiorityType': 'SUPERIORITY',
#        'pValue': '.36',
#        'statisticalMethod': 'Regression, Logistic'}]},
#     {'type': 'OTHER_PRE_SPECIFIED',
#      'title': 'Misconceptions About Pain and Pain Management--caregiver',
#      'description': 'Misconceptions are measured with a computer version of the Barriers Questionnaire (BQ) with response options from 0 to 5 indicating the amount of agreement with statements about barriers to pain assessment or management. Items relate to communicating with the physician about pain, side effects of analgesics, concerns about addiction, tolerance, disease progression, and being perceived as a good patient. Validity of the BQ is supported by its ability to discriminate cancer patients who report high BQ scores and also were under-medicated for their pain level and were hesitant to report their pain to their clinicians. To improve the acceptability of the tool to patients with cancer, we reduced the tool to 13 items with demonstrated validity and reliability. In prior cancer studies, patients found it to be a simple, easily understood tool that they completed in 5 minutes or less on 13 screens using a touch-screen pentablet computer.',
#      'populationDescription': 'Intent to treat analysis with multiple imputation based missing data processing.',
#      'reportingStatus': 'POSTED',
#      'paramType': 'MEAN',
#      'dispersionType': 'Standard Deviation',
#      'unitOfMeasure': 'units on a scale (0-5); lower is better',
#      'timeFrame': 'pretest at baseline (day 0) & posttest on day 7; day 7 reported',
#      'groups': [{'id': 'OG000',
#        'title': 'Usual Hospice Care',
#        'description': 'The usual care group will receive the typical hospice care and interact with PAINReportIt to provide data necessary for the analysis of study aims. They will use the tablet computer at baseline and at the study end and daily between. They also will have access to what looks like PAINUCope, but is really computer games so that they have similar attention with the computer as the experimental group. For ethical purposes, we will provide a PAINReportIt Summary to their hospice nurses to have access to their pain assessment information, something we did not do in previous studies focused on efficacy of the interventions.'},
#       {'id': 'OG001',
#        'title': 'PAINRelieveIt (Experimental Group)',
#        'description': "We will use Nursing Consult LLC's PAINRelieveIt software that includes: (1) PAINReportIt that has screens to collect pain, medications, and misconception data; (2) the intervention for the nurse clinicians, PAINConsultN; and (3) the intervention for the patients and lay caregiver, PAINUCope. This innovative, new program is the first computerized, multi-dimensional, self-report measure of pain with clinician decision support for analgesic prescriptions and multimedia patient education tailored to the patient's misconceptions and pain. Prototype versions of PAINConsultN and PAINUCope were tested in recently completed studies among outpatients with cancer and patients with sickle cell disease in outpatient, emergency and hospital settings."}],
#      'denoms': [{'units': 'Participants',
#        'counts': [{'groupId': 'OG000', 'value': '154'},
#         {'groupId': 'OG001', 'value': '80'}]}],
#      'classes': [{'categories': [{'measurements': [{'groupId': 'OG000',
#            'value': '2.97',
#            'spread': '0.81'},
#           {'groupId': 'OG001', 'value': '2.67', 'spread': '0.82'}]}]}],
#      'analyses': [{'groupIds': ['OG000', 'OG001'],
#        'nonInferiorityType': 'SUPERIORITY',
#        'pValue': '.01',
#        'statisticalMethod': 'Regression, Linear'}]},
#     {'type': 'OTHER_PRE_SPECIFIED',
#      'title': 'Appropriateness of Analgesics Prescribed --Hospice Nurse',
#      'description': "We will measure the appropriateness of a patient's analgesic prescription on a given day using Cleeland's Pain Management Index (PMI). For a given day, a patient's analgesic score (0=no analgesic, 1=non-opioid, 2=weak opioid, 3=strong opioid) is subtracted by their pain intensity category (0 = worst pain of 0; 1 = worst pain of 1-3; 2 = worst pain of 4-6; 3 = worst pain of 7-10) to obtain their PMI score for the day. Negative PMI scores indicate inadequate analgesics while 0 or positive PMI scores indicate appropriate analgesics. For each patient, the outcome measure is the proportion of day with appropriate analgesics.",
#      'reportingStatus': 'POSTED',
#      'paramType': 'MEAN',
#      'dispersionType': 'Standard Deviation',
#      'unitOfMeasure': 'proportion of days (0-1), higher=better',
#      'timeFrame': 'proportion of days (days 1 to 7) with appropriate analgesics',
#      'groups': [{'id': 'OG000',
#        'title': 'Usual Hospice Care',
#        'description': 'The usual care group will receive the typical hospice care and interact with PAINReportIt to provide data necessary for the analysis of study aims. They will use the tablet computer at baseline and at the study end and daily between. They also will have access to what looks like PAINUCope, but is really computer games so that they have similar attention with the computer as the experimental group. For ethical purposes, we will provide a PAINReportIt Summary to their hospice nurses to have access to their pain assessment information, something we did not do in previous studies focused on efficacy of the interventions.'},
#       {'id': 'OG001',
#        'title': 'PAINRelieveIt (Experimental Group)',
#        'description': "We will use Nursing Consult LLC's PAINRelieveIt software that includes: (1) PAINReportIt that has screens to collect pain, medications, and misconception data; (2) the intervention for the nurse clinicians, PAINConsultN; and (3) the intervention for the patients and lay caregiver, PAINUCope. This innovative, new program is the first computerized, multi-dimensional, self-report measure of pain with clinician decision support for analgesic prescriptions and multimedia patient education tailored to the patient's misconceptions and pain. Prototype versions of PAINConsultN and PAINUCope were tested in recently completed studies among outpatients with cancer and patients with sickle cell disease in outpatient, emergency and hospital settings."}],
#      'denoms': [{'units': 'Participants',
#        'counts': [{'groupId': 'OG000', 'value': '154'},
#         {'groupId': 'OG001', 'value': '80'}]}],
#      'classes': [{'categories': [{'measurements': [{'groupId': 'OG000',
#            'value': '0.98',
#            'spread': '0.13'},
#           {'groupId': 'OG001', 'value': '0.91', 'spread': '0.29'}]}]}],
#      'analyses': [{'groupIds': ['OG000', 'OG001'],
#        'nonInferiorityType': 'SUPERIORITY',
#        'pValue': '<0.01',
#        'statisticalMethod': 'Mixed Models Analysis'}]}]}},
#  'hasResults': True}

# %%
s["protocolSection"]["conditionsModule"]
# Out:
# {'conditions': ['Multiple Chronic Conditions', 'Dementia'],
#  'keywords': ['multiple chronic conditions', 'dementia', 'Hispanic']}

# %%
cards = json.load(open("../data/cyyyards/cards.json", "r"))

# %%
search_terms = ['depression', 'diabetes', 'cancer']
counts = {term: 0 for term in search_terms}
for card in cards:
    phrase = ' '.join([c.lower() for c in card["conditions"]])
    phrase += ' '.join([k.lower() for k in card["keywords"]])
    for term in search_terms:
        counts[term] += term in phrase
print(len(cards))
counts
# Out:
# 448
# {'depression': 42, 'diabetes': 32, 'cancer': 29}

# %%
cards = json.load(open("../data/cards/cards.json", "r"))
questions = []

from pprint import pprint
for i, card in enumerate(cards):
    questions.append(card["front_details"]["question"])

with open("../data/cards/questions.txt", "w") as f:
    f.writelines('\n'.join(questions))

# %%
# actual results

outcomes = sample["resultsSection"]["outcomeMeasuresModule"]["outcomeMeasures"]
primary_outcomes_results = [o for o in outcomes if o["type"] == "PRIMARY"]
primary_outcomes_results[0]
# Out:
# {'type': 'PRIMARY',
#  'title': 'Analgesic Adherence-patient',
#  'description': 'Analgesic adherence is derived from data regarding analgesics documented as prescribed (available to the patient as indicated from the medication list in the home) and analgesics consumed (from PAINReportIt). We calculate an analgesic adherence rate (dose reported as consumed divided by dose documented as prescribed, multiplied by 100) for all World Health Organization (WHO) analgesics (adjuvants, NSAIDs and non-opioids, and ATC and PRN Step 2 and Step 3 opioids).',
#  'populationDescription': 'Intent to treat analysis with multiple imputation based missing data processing.',
#  'reportingStatus': 'POSTED',
#  'paramType': 'MEAN',
#  'dispersionType': 'Standard Deviation',
#  'unitOfMeasure': 'proportion (0-1), higher is better',
#  'timeFrame': 'Average of daily adherence (days 1 to 7)',
#  'groups': [{'id': 'OG000',
#    'title': 'Usual Hospice Care',
#    'description': 'The usual care group will receive the typical hospice care and interact with PAINReportIt to provide data necessary for the analysis of study aims. They will use the tablet computer at baseline and at the study end and daily between. They also will have access to what looks like PAINUCope, but is really computer games so that they have similar attention with the computer as the experimental group. For ethical purposes, we will provide a PAINReportIt Summary to their hospice nurses to have access to their pain assessment information, something we did not do in previous studies focused on efficacy of the interventions.'},
#   {'id': 'OG001',
#    'title': 'PAINRelieveIt (Experimental Group)',
#    'description': "We will use Nursing Consult LLC's PAINRelieveIt software that includes: (1) PAINReportIt that has screens to collect pain, medications, and misconception data; (2) the intervention for the nurse clinicians, PAINConsultN; and (3) the intervention for the patients and lay caregiver, PAINUCope. This innovative, new program is the first computerized, multi-dimensional, self-report measure of pain with clinician decision support for analgesic prescriptions and multimedia patient education tailored to the patient's misconceptions and pain. Prototype versions of PAINConsultN and PAINUCope were tested in recently completed studies among outpatients with cancer and patients with sickle cell disease in outpatient, emergency and hospital settings."}],
#  'denoms': [{'units': 'Participants',
#    'counts': [{'groupId': 'OG000', 'value': '154'},
#     {'groupId': 'OG001', 'value': '80'}]}],
#  'classes': [{'categories': [{'measurements': [{'groupId': 'OG000',
#        'value': '0.66',
#        'spread': '0.27'},
#       {'groupId': 'OG001', 'value': '0.67', 'spread': '0.24'}]}]}],
#  'analyses': [{'groupIds': ['OG000', 'OG001'],
#    'nonInferiorityType': 'SUPERIORITY',
#    'pValue': '.43',
#    'statisticalMethod': 'Mixed Models Analysis'}]}

# %%
for s in raw_studies[:3]:
    id_mod = s["protocolSection"]["identificationModule"]
    print("Study:", id_mod["briefTitle"])
    print("https://clinicaltrials.gov/study/" + id_mod["nctId"])
    outcomes = s["resultsSection"]["outcomeMeasuresModule"]["outcomeMeasures"]
    primary_outcomes_results = [o for o in outcomes if o["type"] == "PRIMARY"]
    if len(primary_outcomes_results) == 0:
        print("No primary outcomes results")
        continue
    for i, o in enumerate(primary_outcomes_results):
        print(f"Primary outcome result {i+1}:")
        print("  Title:", o["title"])
        if "description" in o and o["description"]:
            print("  Description:", o["description"])
        if "timeFrame" in o and o["timeFrame"]:
            print("  Time frame:", o["timeFrame"])
        if "resultGroups" in o:
            for rg in o["resultGroups"]:
                print("  Result group:", rg.get("groupTitle", "N/A"))
                if "measures" in rg:
                    for m in rg["measures"]:
                        measure_title = m.get("measureTitle", "N/A")
                        value = m.get("value", "N/A")
                        units = m.get("units", "")
                        if units:
                            print(f"    Measure: {measure_title}, Value: {value} {units}")
                        else:
                            print(f"    Measure: {measure_title}, Value: {value}")
        print()
    print("-" * 40)
# Out:
# Study: Motor Imagery Intervention for Improving Gait and Cognition in the Elderly
# https://clinicaltrials.gov/study/NCT02762604
# Primary outcome result 1:
#   Title: Change in Walking Speed During Single and Dual-task Walking Conditions
#   Description: Change in gait speed (centimeters per second) measured during normal pace walking and walking while talking conditions using an instrumented pathway. A positive mean value is indicative of an improvement (increase) in gait speed post-intervention, whereas a negative mean value is indicative of a decrease in gait speed post-intervention.
#   Time frame: Baseline and 3 months
#
# ----------------------------------------
# Study: Stepping Stones and Creating Futures Intervention Trial
# https://clinicaltrials.gov/study/NCT03022370
# Primary outcome result 1:
#   Title: Any Past Year Physical Intimate Partner Violence Perpetration (Men) and Experience (Women)
#   Description: Physical intimate partner violence is assessed using five items based on the WHO VAW scale. A positive response to any item leads to a person being classified as perpetrating (men) and experiencing (women) in the past year. With 0=none, 1=yes.
#   Time frame: 24 months post baseline
#
# Primary outcome result 2:
#   Title: Any Past Year Sexual Intimate Partner Violence Perpetration (Men) and Experience (Women)
#   Description: Sexual intimate partner violence is assessed using three items based on the WHO VAW scale. A positive response to any item leads to a person being classified as perpetrating (men) and experiencing (women) in the past year. With 0=none, 1=yes.
#   Time frame: 24 months post baseline
#
# Primary outcome result 3:
#   Title: Past Year Severe Sexual and/or Physical Intimate Partner Violence Perpetration (Men) and Experience (Women)
#   Description: Severe sexual and/or physical intimate partner violence perpetration (men) and experience (women) is assessed using 8 items. Past year severe sexual and/or physical IPV is assessed as positive if a person responds to two (or more) items as once, or one item as few (or more), essentially creating a more than once categorization.
#   Time frame: 24 months post baseline
#
# Primary outcome result 4:
#   Title: Controlling Behaviours
#   Description: Controlling behaviours are assessed using a modified Sexual Relationship Power (SRP) scale. Men's control of female sexual partner's and women's experience of controlling behaviours from a male partner. A mean score is calculated with higher scores indicating more controlling (bad). Range: 0-24
#   Time frame: 24 months post baseline
#
# Primary outcome result 5:
#   Title: Earnings in Past Month
#   Description: A single item question asks "Considering all the money you earned from jobs or selling things (excluding grants), how much did you earn last month?" Responses are in Rands and a continuous scale, with no upper limit.
#   Time frame: 24 months post baseline
#
# ----------------------------------------
# Study: Penetrating the Classroom Social Network for Children With Language Impairment Via Peer Mediated Intervention
# https://clinicaltrials.gov/study/NCT06182033
# Primary outcome result 1:
#   Title: Preschool Language Screener 5 (PLS-5) - Growth Scale Value
#   Description: The PLS-5 is used to assess expressive language skills. Specific skills assessed include naming, expressing quantity, describing, using specific prepositions, grammatical markers, sentence structures, and emergent literacy skills. An assessor indicates whether a child passes (1) or does not pass (0) each item. Growth Scale Value: Range: Minimum = 100/Max = 900. Higher scores indicate better expressive language skills. Assessed at baseline, 3 months, and 9 months. Baseline reported.
#   Time frame: at baseline, 3 months, and 9 months
#
# ----------------------------------------

# %%
raw_studies_p = []
for s in raw_studies:
    has_p_value = False

    outcomes = s["resultsSection"]["outcomeMeasuresModule"]["outcomeMeasures"]
    primary_outcomes_results = [o for o in outcomes if o["type"] == "PRIMARY"]
    for o in primary_outcomes_results:
        if has_p_value:
            break

        if "analyses" in o:
            for analysis in o["analyses"]:
                if "pValue" in analysis:
                    # print(f"Study: {id_mod['nctId']}, Primary Outcome: {o['title']}, p-value: {analysis['pValue']}")
                    has_p_value = True
                    raw_studies_p.append(s)
                    break
frac_p_val = len(raw_studies_p) / len(raw_studies)
print(f"{len(raw_studies_p)} out of {len(raw_studies)} ({frac_p_val*100:<.2f}%) studies have p-values reported in primary outcomes analyses.")
# Out:
# 1801 out of 5374 (33.51%) studies have p-values reported in primary outcomes analyses.

# %%
from dataclasses import dataclass

ParsedPValue = tuple[str | None, float | None] # (comparison, value)
def parse_p_value(p: str) -> ParsedPValue:
    """
    Parse a p-value string and return a tuple of (comparison, value).


    Args:
        p (str): A p-value string that may contain comparison operators like '<', '>', '=' 
                 or just a numeric value
                 
    Returns:
        tuple: A tuple containing (comparison_operator, numeric_value) where:
               - comparison_operator is one of '<', '>', '=' or None if parsing failed
               - numeric_value is the float value or None if parsing failed
               
    Examples:
        parse_p_value('<0.05') -> ('<', 0.05)
        parse_p_value('0.032') -> ('=', 0.032)
        parse_p_value('>0.1') -> ('>', 0.1)
        parse_p_value('invalid') -> (None, None)
    """

    # remove whitespace that sometimes occurs (e.g., "< 0.05" --> "<0.05")
    p = ''.join(c for c in p if c != ' ')
    if p.startswith("<"):
        try:
            val = float(p[1:].strip())
            return ("<", val)
        except ValueError:
            return (None, None)
    elif p.startswith(">"):
        try:
            val = float(p[1:].strip())
            return (">", val)
        except ValueError:
            return (None, None)
    elif p.startswith("="):
        try:
            val = float(p[1:].strip())
            return ("=", val)
        except ValueError:
            return (None, None)
    else:
        try:
            val = float(p)
            return ("=", val)
        except ValueError:
            return (None, None)

parsed_p_values = [parse_p_value(p) for p in p_values]


@dataclass
class PValueStatistics:
    n_0_05: int # num p < 0.05
    n_0_01: int # num p < 0.01
    n_0_001: int # num p < 0.001

    f_0_05: float # frac p < 0.05
    f_0_01: float # frac p < 0.01
    f_0_001: float # frac p < 0.001

    n_success: int # num p < 0.05
    n_fail: int # num p >= 0.05

    f_success: float # frac p < 0.05
    f_fail: float # frac p >= 0.05

    n_total: int


def compute_p_value_statistics(parsed_p_values: list[ParsedPValue]):
    """
    Compute statistics from a list of parsed p-values.
    """

    n_total = len(parsed_p_values)
    n_0_05 = sum(1 for cmp, val in parsed_p_values if cmp in ("=", "<") and val is not None and val < 0.05)
    n_0_01 = sum(1 for cmp, val in parsed_p_values if cmp in ("=", "<") and val is not None and val < 0.01)
    n_0_001 = sum(1 for cmp, val in parsed_p_values if cmp in ("=", "<") and val is not None and val < 0.001)

    n_success = n_0_05
    n_fail = n_total - n_success

    f_0_05 = n_0_05 / n_total if n_total > 0 else 0
    f_0_01 = n_0_01 / n_total if n_total > 0 else 0
    f_0_001 = n_0_001 / n_total if n_total > 0 else 0

    f_success = f_0_05
    f_fail = 1 - f_success

    return PValueStatistics(
        n_0_05=n_0_05,
        n_0_01=n_0_01,
        n_0_001=n_0_001,

        f_0_05=f_0_05,
        f_0_01=f_0_01,
        f_0_001=f_0_001,

        n_success=n_success,
        n_fail=n_fail,

        f_success=f_success,
        f_fail=f_fail,

        n_total=n_total
    )

# %%
for s in raw_studies_p[:3]:
    id_mod = s["protocolSection"]["identificationModule"]
    outcomes = s["resultsSection"]["outcomeMeasuresModule"]["outcomeMeasures"]
    primary_outcomes_results = [o for o in outcomes if o["type"] == "PRIMARY"]
    print("Study:", id_mod["briefTitle"])
    print("https://clinicaltrials.gov/study/" + id_mod["nctId"])
    if len(primary_outcomes_results) == 0:
        print("No primary outcomes results")
        continue
    for i, o in enumerate(primary_outcomes_results):
        # note: g["description"] is also useful!

        print(f"Primary outcome result {i+1}:")
        print("  Title:", o["title"])
        if "description" in o and o["description"]:
            print("  Description:", o["description"])
        if "timeFrame" in o and o["timeFrame"]:
            print("  Time frame:", o["timeFrame"])


        if "analyses" in o:
            for analysis in o["analyses"]:
                group_id_to_title = {g["id"]: g["title"] for g in o["groups"]}
                group_id_to_count = {}
                for denom in o["denoms"]:
                    if denom["units"].lower() != "participants":
                         continue
                    for c in denom["counts"]:
                        group_id_to_count[c["groupId"]] = c["value"]
                   
                if "pValue" in analysis:
                    groups = [f"{group_id_to_title[gid]} ({group_id_to_count[gid]})" for gid in analysis["groupIds"]]
                    print(f"    Analysis comparing groups: {', '.join(groups)}")
                    print(f"      p-value: {analysis['pValue']}")
                    print(f"      type: {analysis['nonInferiorityType']}")
       
    print("-" * 40)
# Out:
# Study: Stepping Stones and Creating Futures Intervention Trial
# https://clinicaltrials.gov/study/NCT03022370
# Primary outcome result 1:
#   Title: Any Past Year Physical Intimate Partner Violence Perpetration (Men) and Experience (Women)
#   Description: Physical intimate partner violence is assessed using five items based on the WHO VAW scale. A positive response to any item leads to a person being classified as perpetrating (men) and experiencing (women) in the past year. With 0=none, 1=yes.
#   Time frame: 24 months post baseline
#     Analysis comparing groups: Women - Intervention (260), Women - Control (285)
#       p-value: =0.686
#       type: SUPERIORITY
#     Analysis comparing groups: Men - Intervention (237), Men - Control (268)
#       p-value: =0.032
#       type: SUPERIORITY
# Primary outcome result 2:
#   Title: Any Past Year Sexual Intimate Partner Violence Perpetration (Men) and Experience (Women)
#   Description: Sexual intimate partner violence is assessed using three items based on the WHO VAW scale. A positive response to any item leads to a person being classified as perpetrating (men) and experiencing (women) in the past year. With 0=none, 1=yes.
#   Time frame: 24 months post baseline
#     Analysis comparing groups: Women - Intervention (260), Women - Control (285)
#       p-value: 0.555
#       type: SUPERIORITY
#     Analysis comparing groups: Men - Intervention (237), Men - Control (268)
#       p-value: 0.072
#       type: SUPERIORITY
# Primary outcome result 3:
#   Title: Past Year Severe Sexual and/or Physical Intimate Partner Violence Perpetration (Men) and Experience (Women)
#   Description: Severe sexual and/or physical intimate partner violence perpetration (men) and experience (women) is assessed using 8 items. Past year severe sexual and/or physical IPV is assessed as positive if a person responds to two (or more) items as once, or one item as few (or more), essentially creating a more than once categorization.
#   Time frame: 24 months post baseline
#     Analysis comparing groups: Women - Intervention (260), Women - Control (285)
#       p-value: 0.672
#       type: SUPERIORITY
#     Analysis comparing groups: Men - Intervention (237), Men - Control (268)
#       p-value: 0.019
#       type: SUPERIORITY
# Primary outcome result 4:
#   Title: Controlling Behaviours
#   Description: Controlling behaviours are assessed using a modified Sexual Relationship Power (SRP) scale. Men's control of female sexual partner's and women's experience of controlling behaviours from a male partner. A mean score is calculated with higher scores indicating more controlling (bad). Range: 0-24
#   Time frame: 24 months post baseline
#     Analysis comparing groups: Women - Intervention (260), Women - Control (285)
#       p-value: 0.984
#       type: SUPERIORITY
#     Analysis comparing groups: Men - Intervention (237), Men - Control (268)
#       p-value: 0.839
#       type: SUPERIORITY
# Primary outcome result 5:
#   Title: Earnings in Past Month
#   Description: A single item question asks "Considering all the money you earned from jobs or selling things (excluding grants), how much did you earn last month?" Responses are in Rands and a continuous scale, with no upper limit.
#   Time frame: 24 months post baseline
#     Analysis comparing groups: Women - Intervention (260), Women - Control (285)
#       p-value: <0.0001
#       type: SUPERIORITY
#     Analysis comparing groups: Men - Intervention (237), Men - Control (268)
#       p-value: 0.521
#       type: SUPERIORITY
# ----------------------------------------
# Study: Penetrating the Classroom Social Network for Children With Language Impairment Via Peer Mediated Intervention
# https://clinicaltrials.gov/study/NCT06182033
# Primary outcome result 1:
#   Title: Preschool Language Screener 5 (PLS-5) - Growth Scale Value
#   Description: The PLS-5 is used to assess expressive language skills. Specific skills assessed include naming, expressing quantity, describing, using specific prepositions, grammatical markers, sentence structures, and emergent literacy skills. An assessor indicates whether a child passes (1) or does not pass (0) each item. Growth Scale Value: Range: Minimum = 100/Max = 900. Higher scores indicate better expressive language skills. Assessed at baseline, 3 months, and 9 months. Baseline reported.
#   Time frame: at baseline, 3 months, and 9 months
#     Analysis comparing groups: Peer-mediated Pivotal Response Intervention (12), Control (13)
#       p-value: .84
#       type: OTHER
# ----------------------------------------
# Study: Theta Burst Transcranial Magnetic Stimulation of Fronto-parietal Networks: Modulation by Mental State
# https://clinicaltrials.gov/study/NCT04010461
# Primary outcome result 1:
#   Title: 2-back Minus 1-back Blood Oxygen Level-Dependent (BOLD) Activation, Voxelwise in FPN
#   Description: Fronto-parietal network (FPN) defined by BOLD change while subject performed the n-back working memory task, contrasting high (2-back) versus low (1-back) loads. Using the SPM12 package, data were normalized per standard, open source routines. Using a General Linear Model framework, a model was estimated with regressors (after convolution with hemodynamic response function) for 2-back \& 1-back conditions for each subject to predict BOLD change each day (arm).For analysis of group effects, second-level, between-subject analyses on normalized images of the 2-back minus 1-back beta estimate from the first level were entered into regression models, with mean frame displacement as a co-variate of no-interest to test contrasts between the arms/interventions. Using a FPN mask, the eigenvalues from the second-level estimates were extracted and entered into the analysis as an outcome measure. Note: eigenvalues are arbitrary units. Larger values indicate more BOLD signal.
#   Time frame: 60 minutes after TMS during fMRI
#     Analysis comparing groups: TMS to dlPFC, Without a Concurrent Task (Passive) (37), TMS to dlPFC, During Task (Active) (37)
#       p-value: =0.11
#       type: SUPERIORITY
#     Analysis comparing groups: TMS to dlPFC, Without a Concurrent Task (Passive) (37), TMS to Vertex, Without Concurrent Task (Control) (37)
#       p-value: 0.94
#       type: SUPERIORITY
# Primary outcome result 2:
#   Title: Frontoparietal Network (FPN) Connectivity to Dorsolateral Prefrontal Cortex (dlPFC) Theta Burst Stimulation (TBS) Target
#   Description: Analysis of resting-state connectivity was performed used the CONN toolbox, using standard techniques to demonstrate connectivity between a spherical seed placed on each participant's locus of dlPFC stimulation, and the rest of the brain. Connectivity (correlations of BOLD signal) was first calculated for each participant, and then spatially averaged in MNI brain space, between participants. A 'cluster' of connectivity was identified, only if the number of voxels (thresholded at P \<0.001) exceeded the count of 25. The outcome measure here is a count of the number of clusters exceeding this threshold, across all subjects. It represents significant connectivity between the site of stimulation and that cluster in the brain, for all subjects.
#   Time frame: 60 minutes after TMS during fMRI
#     Analysis comparing groups: TMS to dlPFC, Without a Concurrent Task (Passive) (37), TMS to dlPFC, During Task (Active) (37)
#       p-value: 1
#       type: OTHER
#     Analysis comparing groups: TMS to dlPFC, Without a Concurrent Task (Passive) (37), TMS to Vertex, Without Concurrent Task (Control) (37)
#       p-value: 1
#       type: OTHER
# Primary outcome result 3:
#   Title: Cerebral Blood Flow (rCBF) at Stimulation Target
#   Description: Regional cerebral blood flow measured at the site of theta burst stimulation (TBS) in milliliters per 100 mg tissue per minute
#   Time frame: 15 minutes after TMS during fMRI
#     Analysis comparing groups: TMS to dlPFC, Without a Concurrent Task (Passive) (35), TMS to Vertex, Without Concurrent Task (Control) (35), TMS to dlPFC, During Task (Active) (35)
#       p-value: 0.91
#       type: SUPERIORITY
# Primary outcome result 4:
#   Title: Accuracy to 2-back
#   Description: Correct responses to letter stimuli, as a percentage of all responses
#   Time frame: 60 minutes after TMS during fMRI
#     Analysis comparing groups: TMS to dlPFC, Without a Concurrent Task (Passive) (40), TMS to dlPFC, During Task (Active) (16)
#       p-value: 0.55
#       type: SUPERIORITY
#     Analysis comparing groups: TMS to dlPFC, Without a Concurrent Task (Passive) (40), TMS to Vertex, Without Concurrent Task (Control) (39)
#       p-value: .65
#       type: SUPERIORITY
# ----------------------------------------

# %%
# Only 1 group for p-value test


xs = []
groupses = []
for s in raw_studies_p[:300]:
    id_mod = s["protocolSection"]["identificationModule"]
    outcomes = s["resultsSection"]["outcomeMeasuresModule"]["outcomeMeasures"]
    primary_outcomes_results = [o for o in outcomes if o["type"] == "PRIMARY"]
    # print("Study:", id_mod["briefTitle"])
    # print("https://clinicaltrials.gov/study/" + id_mod["nctId"])
    if len(primary_outcomes_results) == 0:
        print("No primary outcomes results")
        continue
    for i, o in enumerate(primary_outcomes_results):

        if "analyses" in o:
            for analysis in o["analyses"]:
                if "pValue" in analysis:
                    group_id_to_title = {g["id"]: g["title"] for g in o["groups"]}
                    groups = [group_id_to_title[gid] for gid in analysis["groupIds"]]
                    groupses.append(tuple(groups))
                    if len(groups) == 1:
                        print("Study:", id_mod["briefTitle"])
                        print(groups)
                        print(f"    Groups: {', '.join(groups)}")
                        print(f"      p-value: {analysis['pValue']}")
                        print(f"      type: {analysis['nonInferiorityType']}")
                        xs.append((s, o))
# Out:
# Study: Emergency Department Healthcare Education Assessment and Response for Teen Relationships: A Pilot Feasibility Study
# ['ED-HEART (Intervention Arm)']
#     Analysis comparing groups: ED-HEART (Intervention Arm)
#       p-value: .622
#       type: OTHER
# Study: Emergency Department Healthcare Education Assessment and Response for Teen Relationships: A Pilot Feasibility Study
# ['ED-HEART (Intervention Arm)']
#     Analysis comparing groups: ED-HEART (Intervention Arm)
#       p-value: .038
#       type: OTHER
# Study: Peer Intervention to Link Overdose Survivors to Treatment (PILOT)
# ['Treatment as Usual (TAU) Arm']
#     Analysis comparing groups: Treatment as Usual (TAU) Arm
#       p-value: 0.399
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['STEP-Home']
#     Analysis comparing groups: STEP-Home
#       p-value: <.0001
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['STEP-Home']
#     Analysis comparing groups: STEP-Home
#       p-value: <.0001
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['PCGT']
#     Analysis comparing groups: PCGT
#       p-value: <.0001
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['PCGT']
#     Analysis comparing groups: PCGT
#       p-value: <.0001
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['STEP-Home']
#     Analysis comparing groups: STEP-Home
#       p-value: 0.0044
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['STEP-Home']
#     Analysis comparing groups: STEP-Home
#       p-value: <.0001
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['PCGT']
#     Analysis comparing groups: PCGT
#       p-value: 0.0162
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['PCGT']
#     Analysis comparing groups: PCGT
#       p-value: 0.0009
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['STEP-Home']
#     Analysis comparing groups: STEP-Home
#       p-value: 0.0140
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['STEP-Home']
#     Analysis comparing groups: STEP-Home
#       p-value: 0.1548
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['STEP-Home']
#     Analysis comparing groups: STEP-Home
#       p-value: 0.0302
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['PCGT']
#     Analysis comparing groups: PCGT
#       p-value: 0.0158
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['PCGT']
#     Analysis comparing groups: PCGT
#       p-value: 0.0034
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['PCGT']
#     Analysis comparing groups: PCGT
#       p-value: 0.8776
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['STEP-Home']
#     Analysis comparing groups: STEP-Home
#       p-value: 0.0002
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['STEP-Home']
#     Analysis comparing groups: STEP-Home
#       p-value: 0.0198
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['STEP-Home']
#     Analysis comparing groups: STEP-Home
#       p-value: 0.0013
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['PCGT']
#     Analysis comparing groups: PCGT
#       p-value: <.0001
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['PCGT']
#     Analysis comparing groups: PCGT
#       p-value: .0345
#       type: SUPERIORITY
# Study: Multisite RCT of STEP-Home: A Transdiagnostic Skill-based Community Reintegration Workshop
# ['PCGT']
#     Analysis comparing groups: PCGT
#       p-value: 0.5918
#       type: SUPERIORITY
# Study: Evaluation Study of Talk Parenting Skills
# ['The Talk Parenting Skill for Alexa']
#     Analysis comparing groups: The Talk Parenting Skill for Alexa
#       p-value: .690
#       type: EQUIVALENCE
# Study: Evaluation Study of Talk Parenting Skills
# ['The Talk Parenting Skill for Alexa']
#     Analysis comparing groups: The Talk Parenting Skill for Alexa
#       p-value: .052
#       type: EQUIVALENCE
# Study: Evaluation Study of Talk Parenting Skills
# ['The Talk Parenting Skill for Alexa']
#     Analysis comparing groups: The Talk Parenting Skill for Alexa
#       p-value: .135
#       type: EQUIVALENCE
# Study: Evaluation Study of Talk Parenting Skills
# ['The Talk Parenting Skill for Alexa']
#     Analysis comparing groups: The Talk Parenting Skill for Alexa
#       p-value: .026
#       type: EQUIVALENCE
# Study: Evaluation Study of Talk Parenting Skills
# ['The Talk Parenting Skill for Alexa']
#     Analysis comparing groups: The Talk Parenting Skill for Alexa
#       p-value: <.001
#       type: EQUIVALENCE
# Study: Evaluation Study of Talk Parenting Skills
# ['The Talk Parenting Skill for Alexa']
#     Analysis comparing groups: The Talk Parenting Skill for Alexa
#       p-value: <.001
#       type: EQUIVALENCE
# Study: Evaluation Study of Talk Parenting Skills
# ['The Talk Parenting Skill for Alexa']
#     Analysis comparing groups: The Talk Parenting Skill for Alexa
#       p-value: .057
#       type: EQUIVALENCE
# Study: Evaluation Study of Talk Parenting Skills
# ['The Talk Parenting Skill for Alexa']
#     Analysis comparing groups: The Talk Parenting Skill for Alexa
#       p-value: <.001
#       type: EQUIVALENCE
# Study: Evaluation Study of Talk Parenting Skills
# ['The Talk Parenting Skill for Alexa']
#     Analysis comparing groups: The Talk Parenting Skill for Alexa
#       p-value: .352
#       type: EQUIVALENCE
# Study: Evaluation Study of Talk Parenting Skills
# ['The Talk Parenting Skill for Alexa']
#     Analysis comparing groups: The Talk Parenting Skill for Alexa
#       p-value: .104
#       type: EQUIVALENCE
# Study: Cervical Cancer Screening Intervention Among Korean American Women
# ['General Health Education Control']
#     Analysis comparing groups: General Health Education Control
#       p-value: <0.001
#       type: SUPERIORITY_OR_OTHER_LEGACY
# Study: Vocal Warm-up and Respiratory Muscle Training
# ['Respiratory Muscle Training']
#     Analysis comparing groups: Respiratory Muscle Training
#       p-value: 0.76
#       type: SUPERIORITY_OR_OTHER
# Study: Preventing Loss of Independence Through Exercise (PLIÉ) in Persons With Mild Cognitive Impairment (MCI)
# ['PLIE']
#     Analysis comparing groups: PLIE
#       p-value: 0.002
#       type: SUPERIORITY
# Study: Testing and Calibration of Non-Invasive Optical Imaging Technology for Functional Brain Imaging
# ['Baseline']
#     Analysis comparing groups: Baseline
#       p-value: 0.008
#       type: OTHER
# Study: Testing and Calibration of Non-Invasive Optical Imaging Technology for Functional Brain Imaging
# ['Prefrontal Cortex Activation in a Moral Judgment Task Using Functional Near-Infrared Spectroscopy']
#     Analysis comparing groups: Prefrontal Cortex Activation in a Moral Judgment Task Using Functional Near-Infrared Spectroscopy
#       p-value: 0.0105
#       type: OTHER
# Study: Improving the Sleep and Circadian Rhythms of Mechanically Ventilated Patients
# ['Usual Care']
#     Analysis comparing groups: Usual Care
#       p-value: 0.37
#       type: OTHER
# Study: Improving the Sleep and Circadian Rhythms of Mechanically Ventilated Patients
# ['Sleep Promotion Protocol']
#     Analysis comparing groups: Sleep Promotion Protocol
#       p-value: 0.0074
#       type: OTHER
# Study: Metacognitive Training to Enhance Strategy Use in Blast-Related TBI
# ['Arm 1: Treatment Goal Management Training']
#     Analysis comparing groups: Arm 1: Treatment Goal Management Training
#       p-value: 0.012
#       type: SUPERIORITY
# Study: Metacognitive Training to Enhance Strategy Use in Blast-Related TBI
# ['Arm 1: Treatment Goal Management Training']
#     Analysis comparing groups: Arm 1: Treatment Goal Management Training
#       p-value: 0.98
#       type: SUPERIORITY
# Study: PLANTS Pilot Trial
# ['PLANTS']
#     Analysis comparing groups: PLANTS
#       p-value: 0.074
#       type: OTHER
# Study: PLANTS Pilot Trial
# ['PLANTS']
#     Analysis comparing groups: PLANTS
#       p-value: 0.827
#       type: OTHER
# Study: PLANTS Pilot Trial
# ['PLANTS']
#     Analysis comparing groups: PLANTS
#       p-value: 0.003
#       type: OTHER
# Study: PLANTS Pilot Trial
# ['PLANTS']
#     Analysis comparing groups: PLANTS
#       p-value: 0.002
#       type: OTHER
# Study: Prevention of Weight Loss in Long Term Care Veterans
# ['Overall (Both Groups Combined)']
#     Analysis comparing groups: Overall (Both Groups Combined)
#       p-value: <0.05
#       type: SUPERIORITY_OR_OTHER
# Study: Single Arm Trial of a Multi-component Commercial Digital Weight Loss Program
# ['Lifestyle Modification Program']
#     Analysis comparing groups: Lifestyle Modification Program
#       p-value: <0.001
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Experimental Group 1 - Straw Phonation']
#     Analysis comparing groups: Experimental Group 1 - Straw Phonation
#       p-value: 0.035
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Experimental Group 2 - Resonant Voice Therapy']
#     Analysis comparing groups: Experimental Group 2 - Resonant Voice Therapy
#       p-value: 0.038
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: 1.000
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Experimental Group 1 - Straw Phonation']
#     Analysis comparing groups: Experimental Group 1 - Straw Phonation
#       p-value: 0.731
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Experimental Group 2 - Resonant Voice Therapy']
#     Analysis comparing groups: Experimental Group 2 - Resonant Voice Therapy
#       p-value: 0.217
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: 0.253
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Experimental Group 1 - Straw Phonation']
#     Analysis comparing groups: Experimental Group 1 - Straw Phonation
#       p-value: 0.099
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Experimental Group 2 - Resonant Voice Therapy']
#     Analysis comparing groups: Experimental Group 2 - Resonant Voice Therapy
#       p-value: 0.074
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: 0.472
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Experimental Group 1 - Straw Phonation']
#     Analysis comparing groups: Experimental Group 1 - Straw Phonation
#       p-value: 0.025
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Experimental Group 2 - Resonant Voice Therapy']
#     Analysis comparing groups: Experimental Group 2 - Resonant Voice Therapy
#       p-value: 0.794
#       type: OTHER
# Study: Effect of Semi-occluded Vocal Tract Therapy on the Phonation of Children With Vocal Fold Nodules
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: 0.760
#       type: OTHER
# Study: Substance Use Prevention Campaign for American Indian Youth
# ['Be Under Your Own Influence Intervention']
#     Analysis comparing groups: Be Under Your Own Influence Intervention
#       p-value: .004
#       type: SUPERIORITY
# Study: Substance Use Prevention Campaign for American Indian Youth
# ['Be Under Your Own Influence Intervention']
#     Analysis comparing groups: Be Under Your Own Influence Intervention
#       p-value: .037
#       type: SUPERIORITY
# Study: An Open Label Demonstration Project and Phase II Safety Study of Pre-Exposure Prophylaxis Use Among 15 to 17 Year Old Young Men Who Have Sex With Men (YMSM)
# ['PCC Behavioral Intervention Group']
#     Analysis comparing groups: PCC Behavioral Intervention Group
#       p-value: < 0.0001
#       type: OTHER
# Study: An Open Label Demonstration Project and Phase II Safety Study of Pre-Exposure Prophylaxis Use Among 15 to 17 Year Old Young Men Who Have Sex With Men (YMSM)
# ['PCC Behavioral Intervention Group']
#     Analysis comparing groups: PCC Behavioral Intervention Group
#       p-value: 0.0236
#       type: OTHER
# Study: An Open Label Demonstration Project and Phase II Safety Study of Pre-Exposure Prophylaxis Use Among 15 to 17 Year Old Young Men Who Have Sex With Men (YMSM)
# ['PCC Behavioral Intervention Group']
#     Analysis comparing groups: PCC Behavioral Intervention Group
#       p-value: 0.0003
#       type: OTHER
# Study: An Open Label Demonstration Project and Phase II Safety Study of Pre-Exposure Prophylaxis Use Among 15 to 17 Year Old Young Men Who Have Sex With Men (YMSM)
# ['PCC Behavioral Intervention Group']
#     Analysis comparing groups: PCC Behavioral Intervention Group
#       p-value: 0.0236
#       type: OTHER
# Study: STEM (Science, Technology, Engineering & Math) Familia Talk
# ['Talk STEM Familia App']
#     Analysis comparing groups: Talk STEM Familia App
#       p-value: .003
#       type: SUPERIORITY
# Study: STEM (Science, Technology, Engineering & Math) Familia Talk
# ['Talk STEM Familia App']
#     Analysis comparing groups: Talk STEM Familia App
#       p-value: .022
#       type: SUPERIORITY
# Study: STEM (Science, Technology, Engineering & Math) Familia Talk
# ['Talk STEM Familia App']
#     Analysis comparing groups: Talk STEM Familia App
#       p-value: .016
#       type: SUPERIORITY
# Study: STEM (Science, Technology, Engineering & Math) Familia Talk
# ['Talk STEM Familia App']
#     Analysis comparing groups: Talk STEM Familia App
#       p-value: .002
#       type: SUPERIORITY
# Study: Investigation of the Role of Pictorial Asthma Action Plans to Promote Self-management in Rural Youth With Asthma
# ['Pictorial Asthma Action Plan']
#     Analysis comparing groups: Pictorial Asthma Action Plan
#       p-value: 0.006
#       type: SUPERIORITY
# Study: Investigation of the Role of Pictorial Asthma Action Plans to Promote Self-management in Rural Youth With Asthma
# ['Written Asthma Action Plan']
#     Analysis comparing groups: Written Asthma Action Plan
#       p-value: 0.006
#       type: SUPERIORITY
# Study: Training Attention and Eye Movement in ASD
# ['Eye Movement Game Control']
#     Analysis comparing groups: Eye Movement Game Control
#       p-value: 0.00005
#       type: OTHER
# Study: Training Attention and Eye Movement in ASD
# ['Eye Movement Game Control']
#     Analysis comparing groups: Eye Movement Game Control
#       p-value: 0.018
#       type: OTHER
# Study: The Effect of Using Mobile Applications for Improving Oral Hygiene
# ['Mobile Phone Application']
#     Analysis comparing groups: Mobile Phone Application
#       p-value: 0.0002
#       type: SUPERIORITY
# Study: The Effect of Using Mobile Applications for Improving Oral Hygiene
# ['Mobile Phone Application']
#     Analysis comparing groups: Mobile Phone Application
#       p-value: 0.0283
#       type: SUPERIORITY
# Study: The Effect of Using Mobile Applications for Improving Oral Hygiene
# ['Mobile Phone Application']
#     Analysis comparing groups: Mobile Phone Application
#       p-value: 0.0002
#       type: SUPERIORITY
# Study: The Effect of Using Mobile Applications for Improving Oral Hygiene
# ['Verbal Oral Hygiene Instructions']
#     Analysis comparing groups: Verbal Oral Hygiene Instructions
#       p-value: 0.4809
#       type: SUPERIORITY
# Study: Screen to Save: A Colorectal Cancer Educational Intervention
# ['Inflatable Colon Educational Module']
#     Analysis comparing groups: Inflatable Colon Educational Module
#       p-value: 0.0001
#       type: SUPERIORITY
# Study: A Virtual Navigation Intervention to Reduce Behavioral Health Admissions From Rural Emergency Departments
# ['Behavioral Health - Virtual Patient Navigation']
#     Analysis comparing groups: Behavioral Health - Virtual Patient Navigation
#       p-value: 0.27
#       type: SUPERIORITY
# Study: Testing Glial Pathways to HAAF in Human Subjects Using Carbon 13 Magnetic Resonance Spectroscopy
# ['Healthy Men']
#     Analysis comparing groups: Healthy Men
#       p-value: 0.0053
#       type: OTHER
# Study: Oscillatory Contributions to Working Memory and Attention
# ['Sub-study 2']
#     Analysis comparing groups: Sub-study 2
#       p-value: .335
#       type: SUPERIORITY
# Study: Oscillatory Contributions to Working Memory and Attention
# ['Sub-study 2']
#     Analysis comparing groups: Sub-study 2
#       p-value: .016
#       type: SUPERIORITY
# Study: Effects of Low Sodium Intake on the Anti-proteinuric Efficacy in Hypertensive Patient With Olmesartan
# ['Conventional Education of Low-salt Diet Group']
#     Analysis comparing groups: Conventional Education of Low-salt Diet Group
#       p-value: 0.99
#       type: SUPERIORITY_OR_OTHER
# Study: Effects of Low Sodium Intake on the Anti-proteinuric Efficacy in Hypertensive Patient With Olmesartan
# ['Intensive Education of Low-salt Diet Group']
#     Analysis comparing groups: Intensive Education of Low-salt Diet Group
#       p-value: 0.001
#       type: SUPERIORITY_OR_OTHER
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Developmental Language Disorder']
#     Analysis comparing groups: Children With Developmental Language Disorder
#       p-value: <0.0001
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Typical Language Development']
#     Analysis comparing groups: Children With Typical Language Development
#       p-value: <0.00001
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Developmental Language Disorder']
#     Analysis comparing groups: Children With Developmental Language Disorder
#       p-value: <0.00001
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Typical Language Development']
#     Analysis comparing groups: Children With Typical Language Development
#       p-value: <0.00001
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Developmental Language Disorder']
#     Analysis comparing groups: Children With Developmental Language Disorder
#       p-value: =0.78
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Typical Language Development']
#     Analysis comparing groups: Children With Typical Language Development
#       p-value: <.00001
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Developmental Language Disorder']
#     Analysis comparing groups: Children With Developmental Language Disorder
#       p-value: =1.00
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Typical Language Development']
#     Analysis comparing groups: Children With Typical Language Development
#       p-value: <0.00001
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Developmental Language Disorder']
#     Analysis comparing groups: Children With Developmental Language Disorder
#       p-value: =0.75
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Typical Language Development']
#     Analysis comparing groups: Children With Typical Language Development
#       p-value: <0.01
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Developmental Language Disorder']
#     Analysis comparing groups: Children With Developmental Language Disorder
#       p-value: <0.00001
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Typical Language Development']
#     Analysis comparing groups: Children With Typical Language Development
#       p-value: =0.62
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Developmental Language Disorder']
#     Analysis comparing groups: Children With Developmental Language Disorder
#       p-value: =0.16
#       type: SUPERIORITY
# Study: Retrieval-Based Word Learning in Developmental Language Disorder: Verb Learning
# ['Children With Typical Language Development']
#     Analysis comparing groups: Children With Typical Language Development
#       p-value: =0.33
#       type: SUPERIORITY
# Study: Automatic Self Transcending Meditation Versus Treatment as Usual
# ['Automatic Self Transcending Meditation and Treatment as Usual']
#     Analysis comparing groups: Automatic Self Transcending Meditation and Treatment as Usual
#       p-value: 0.28
#       type: SUPERIORITY
# Study: Automatic Self Transcending Meditation Versus Treatment as Usual
# ['Automatic Self Transcending Meditation and Treatment as Usual']
#     Analysis comparing groups: Automatic Self Transcending Meditation and Treatment as Usual
#       p-value: 0.89
#       type: SUPERIORITY
# Study: Prevention of Depression in Spouses of People With Cognitive Impairment
# ['Problem Solving Intervention']
#     Analysis comparing groups: Problem Solving Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: Supporting Family Caregivers With Technology for Dementia Home Care
# ['Intervention FamTechCare']
#     Analysis comparing groups: Intervention FamTechCare
#       p-value: <.001
#       type: SUPERIORITY
# Study: Supporting Family Caregivers With Technology for Dementia Home Care
# ['Intervention FamTechCare']
#     Analysis comparing groups: Intervention FamTechCare
#       p-value: .005
#       type: SUPERIORITY
# Study: Supporting Family Caregivers With Technology for Dementia Home Care
# ['Intervention FamTechCare']
#     Analysis comparing groups: Intervention FamTechCare
#       p-value: .020
#       type: SUPERIORITY
# Study: Therapist-Guided Smartphone-Delivered CBT for MDD
# ['Therapist-guided Smartphone-delivered CBT']
#     Analysis comparing groups: Therapist-guided Smartphone-delivered CBT
#       p-value: =.0719
#       type: SUPERIORITY
# Study: Therapist-Guided Smartphone-Delivered CBT for MDD
# ['Therapist-guided Smartphone-delivered CBT']
#     Analysis comparing groups: Therapist-guided Smartphone-delivered CBT
#       p-value: =.6316
#       type: SUPERIORITY
# Study: Therapist-Guided Smartphone-Delivered CBT for MDD
# ['Therapist-guided Smartphone-delivered CBT']
#     Analysis comparing groups: Therapist-guided Smartphone-delivered CBT
#       p-value: =.2225
#       type: SUPERIORITY
# Study: Therapist-Guided Smartphone-Delivered CBT for MDD
# ['Therapist-guided Smartphone-delivered CBT']
#     Analysis comparing groups: Therapist-guided Smartphone-delivered CBT
#       p-value: =.7873
#       type: SUPERIORITY
# Study: Implementing PTSD Treatment in FQHCs for Michigan Medicaid Enrollees
# ['PE-PC']
#     Analysis comparing groups: PE-PC
#       p-value: <.001
#       type: OTHER
# Study: Encouraging Judicious Prescribing of Opioids in Los Angeles County
# ['Comparator Letter']
#     Analysis comparing groups: Comparator Letter
#       p-value: <0.05
#       type: SUPERIORITY
# Study: Twitter Based Social Support for Hispanic and Black Dementia Caregivers
# ["African American Family Members of Persons With Alzheimer's Disease and Related Dementias"]
#     Analysis comparing groups: African American Family Members of Persons With Alzheimer's Disease and Related Dementias
#       p-value: < 0.0001
#       type: SUPERIORITY
# Study: Twitter Based Social Support for Hispanic and Black Dementia Caregivers
# ["Hispanic Family Members of Persons With Alzheimer's Disease and Related Dementias"]
#     Analysis comparing groups: Hispanic Family Members of Persons With Alzheimer's Disease and Related Dementias
#       p-value: <0.0001
#       type: SUPERIORITY
# Study: Twitter Based Social Support for Hispanic and Black Dementia Caregivers
# ["African American Family Members of Persons With Alzheimer's Disease and Related Dementias"]
#     Analysis comparing groups: African American Family Members of Persons With Alzheimer's Disease and Related Dementias
#       p-value: <0.0001
#       type: SUPERIORITY
# Study: Twitter Based Social Support for Hispanic and Black Dementia Caregivers
# ["Hispanic Family Members of Persons With Alzheimer's Disease and Related Dementias"]
#     Analysis comparing groups: Hispanic Family Members of Persons With Alzheimer's Disease and Related Dementias
#       p-value: <0.0001
#       type: SUPERIORITY
# Study: An Implementation Strategy for the Adoption of an Evidence-Based Guideline for Pit-and-Fissure Sealants
# ['Deliberative Loop']
#     Analysis comparing groups: Deliberative Loop
#       p-value: 0.18
#       type: SUPERIORITY
# Study: Reduction of Claustrophobia and Patient Motion After Training of MRI Personnel in Comfort TalkTM
# ['Comfort TalkTM Training']
#     Analysis comparing groups: Comfort TalkTM Training
#       p-value: <0.0001
#       type: SUPERIORITY
# Study: Reduction of Claustrophobia and Patient Motion After Training of MRI Personnel in Comfort TalkTM
# ['Comfort TalkTM Training']
#     Analysis comparing groups: Comfort TalkTM Training
#       p-value: <0.0001
#       type: SUPERIORITY
# Study: The University of Michigan PCOS Intervention Using Nutritional Ketosis
# ['Complete Diet and Lifestyle Program']
#     Analysis comparing groups: Complete Diet and Lifestyle Program
#       p-value: <.001
#       type: SUPERIORITY
# Study: Assessing the Effect of Distance Learning Vocational Rehabilitation on Employment Outcomes of Veterans With Psychiatric Illness and Histories of Legal Convictions
# ['Self-help Resources']
#     Analysis comparing groups: Self-help Resources
#       p-value: =.016
#       type: SUPERIORITY
# Study: Behavioral Activation (BA) for Medication-responsive Chronically Depressed Patients With Impaired Social Functioning
# ['Behavioral Activation for Return to Work']
#     Analysis comparing groups: Behavioral Activation for Return to Work
#       p-value: 0.005
#       type: SUPERIORITY_OR_OTHER
# Study: Computerized Tailored Intervention for Behavioral Sequelae of PTSD in Veterans
# ['Mean Difference in PCL (T1, T3) (Negative Change is Better)']
#     Analysis comparing groups: Mean Difference in PCL (T1, T3) (Negative Change is Better)
#       p-value: .001
#       type: SUPERIORITY_OR_OTHER
# Study: Seniors Health and Activity Research Program-Pilot
# ['Healthy Aging']
#     Analysis comparing groups: Healthy Aging
#       p-value: 0.66
#       type: EQUIVALENCE
# Study: Seniors Health and Activity Research Program-Pilot
# ['Healthy Aging']
#     Analysis comparing groups: Healthy Aging
#       p-value: 0.55
#       type: EQUIVALENCE
# Study: Seniors Health and Activity Research Program-Pilot
# ['Cognitive Training']
#     Analysis comparing groups: Cognitive Training
#       p-value: 0.95
#       type: EQUIVALENCE
# Study: Seniors Health and Activity Research Program-Pilot
# ['Cognitive Training']
#     Analysis comparing groups: Cognitive Training
#       p-value: 0.48
#       type: EQUIVALENCE
# Study: Promoting Risk Reduction Among Young Adults With Asthma During Wildfire Smoke Events (TRAK)
# ['Control']
#     Analysis comparing groups: Control
#       p-value: >0.05
#       type: SUPERIORITY
# Study: Promoting Risk Reduction Among Young Adults With Asthma During Wildfire Smoke Events (TRAK)
# ['Smoke Sense']
#     Analysis comparing groups: Smoke Sense
#       p-value: >0.05
#       type: SUPERIORITY
# Study: Promoting Risk Reduction Among Young Adults With Asthma During Wildfire Smoke Events (TRAK)
# ['Smoke Sense Plus']
#     Analysis comparing groups: Smoke Sense Plus
#       p-value: 0.0172
#       type: SUPERIORITY
# Study: Promoting Risk Reduction Among Young Adults With Asthma During Wildfire Smoke Events (TRAK)
# ['Control']
#     Analysis comparing groups: Control
#       p-value: .0320
#       type: SUPERIORITY
# Study: Promoting Risk Reduction Among Young Adults With Asthma During Wildfire Smoke Events (TRAK)
# ['Smoke Sense']
#     Analysis comparing groups: Smoke Sense
#       p-value: >0.05
#       type: SUPERIORITY
# Study: Promoting Risk Reduction Among Young Adults With Asthma During Wildfire Smoke Events (TRAK)
# ['Smoke Sense Plus']
#     Analysis comparing groups: Smoke Sense Plus
#       p-value: 0.0008
#       type: SUPERIORITY
# Study: Reintegration: The Role of Spouse Telephone BATTLEMIND Pilot Study
# ['Telephone Support']
#     Analysis comparing groups: Telephone Support
#       p-value: .003
#       type: SUPERIORITY_OR_OTHER
# Study: Reintegration: The Role of Spouse Telephone BATTLEMIND Pilot Study
# ['Telephone Support']
#     Analysis comparing groups: Telephone Support
#       p-value: <.001
#       type: SUPERIORITY_OR_OTHER
# Study: Reintegration: The Role of Spouse Telephone BATTLEMIND Pilot Study
# ['Telephone Support']
#     Analysis comparing groups: Telephone Support
#       p-value: .26
#       type: SUPERIORITY_OR_OTHER
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.01
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.10
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.10
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.10
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.10
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.01
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.10
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.10
#       type: SUPERIORITY
# ...
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.10
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.01
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: <.10
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.001
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Control Group']
#     Analysis comparing groups: Control Group
#       p-value: >.05
#       type: SUPERIORITY
# Study: TOGETHER: A Couple's Model to Enhance Relationships and Economic Stability
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: <.10
#       type: SUPERIORITY
# Study: Evaluation of Secondary Distribution of HIV Self-screening Tests by Women With HIV
# ['Standard of Care']
#     Analysis comparing groups: Standard of Care
#       p-value: <0.05
#       type: SUPERIORITY
# Study: Cognitive Behavioral Therapy for Treatment of Adult Attention Deficit Hyperactivity Disorder
# ['Cognitive-Behavioral Therapy (CBT)']
#     Analysis comparing groups: Cognitive-Behavioral Therapy (CBT)
#       p-value: <.03
#       type: SUPERIORITY_OR_OTHER
# Study: Novel Methods for Implementing Measurement-Based Care for Youth in Low-resource Environments
# ['Measurement Based Care Implementation']
#     Analysis comparing groups: Measurement Based Care Implementation
#       p-value: >.01
#       type: OTHER
# Study: Teaching Young Children Swim Survival Skills
# ['Self-rescue Training']
#     Analysis comparing groups: Self-rescue Training
#       p-value: <.01
#       type: SUPERIORITY
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY)
#       p-value: 1.00
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (Telehealth Intervention)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (Telehealth Intervention)
#       p-value: 0.914
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY)
#       p-value: 0.655
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (Telehealth Intervention)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (Telehealth Intervention)
#       p-value: 0.564
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY)
#       p-value: 0.014
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (Telehealth Intervention)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (Telehealth Intervention)
#       p-value: 0.705
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY)
#       p-value: 0.096
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (Telehealth Intervention)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (Telehealth Intervention)
#       p-value: 0.732
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY)
#       p-value: 1.00
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (Telehealth Intervention)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (Telehealth Intervention)
#       p-value: 0.705
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY)
#       p-value: 0.442
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (Telehealth Intervention)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (Telehealth Intervention)
#       p-value: 0.458
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY)
#       p-value: 0.35
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (Telehealth Intervention)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (Telehealth Intervention)
#       p-value: 0.68
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY) - Children']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY) - Children
#       p-value: 0.004
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY) - Children']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY) - Children
#       p-value: 0.084
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY)
#       p-value: 0.42
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (Telehealth Intervention)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (Telehealth Intervention)
#       p-value: 0.171
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (In-person Intervention ONLY)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (In-person Intervention ONLY)
#       p-value: 0.011
#       type: OTHER
# Study: Tailoring Treatment Targets for Early Autism Intervention in Africa
# ['Caregiver-Child Dyads With ASD (Telehealth Intervention)']
#     Analysis comparing groups: Caregiver-Child Dyads With ASD (Telehealth Intervention)
#       p-value: 0.049
#       type: OTHER
# Study: Acceptance and Commitment Therapy for Chronic Pain in Cancer Survivors
# ['Intervention']
#     Analysis comparing groups: Intervention
#       p-value: 0.05
#       type: SUPERIORITY
# Study: Effect of Violent First-Person Shooter (FPS) Video Games on Shooting Accuracy
# ['Pilot Study: Non-violent Shooter Game']
#     Analysis comparing groups: Pilot Study: Non-violent Shooter Game
#       p-value: 0.04
#       type: OTHER
# Study: Effect of Violent First-Person Shooter (FPS) Video Games on Shooting Accuracy
# ['Pilot Study: Violent Shooter Game']
#     Analysis comparing groups: Pilot Study: Violent Shooter Game
#       p-value: .0001
#       type: OTHER
# Study: Stress-Reactivity and Cannabis Use in Cannabis-Using Older Adults
# ['Independent of Intervention']
#     Analysis comparing groups: Independent of Intervention
#       p-value: 0.005
#       type: OTHER
# Study: Interdisciplinary Study of A Novel Anticonvulsant in Alcoholism
# ['Placebo & Computerized Psychotherapy']
#     Analysis comparing groups: Placebo & Computerized Psychotherapy
#       p-value: .98
#       type: SUPERIORITY
# Study: Interdisciplinary Study of A Novel Anticonvulsant in Alcoholism
# ['Placebo & Computerized Psychotherapy']
#     Analysis comparing groups: Placebo & Computerized Psychotherapy
#       p-value: .13
#       type: SUPERIORITY
# Study: Interdisciplinary Study of A Novel Anticonvulsant in Alcoholism
# ['Placebo & Computerized Psychotherapy']
#     Analysis comparing groups: Placebo & Computerized Psychotherapy
#       p-value: .19
#       type: SUPERIORITY
# Study: Interdisciplinary Study of A Novel Anticonvulsant in Alcoholism
# ['Placebo & Computerized Psychotherapy']
#     Analysis comparing groups: Placebo & Computerized Psychotherapy
#       p-value: .05
#       type: SUPERIORITY
# Study: Interdisciplinary Study of A Novel Anticonvulsant in Alcoholism
# ['Placebo & Computerized Psychotherapy']
#     Analysis comparing groups: Placebo & Computerized Psychotherapy
#       p-value: .71
#       type: SUPERIORITY
# Study: Interdisciplinary Study of A Novel Anticonvulsant in Alcoholism
# ['Placebo & Computerized Psychotherapy']
#     Analysis comparing groups: Placebo & Computerized Psychotherapy
#       p-value: .12
#       type: SUPERIORITY
# Study: Interdisciplinary Study of A Novel Anticonvulsant in Alcoholism
# ['Placebo & Computerized Psychotherapy']
#     Analysis comparing groups: Placebo & Computerized Psychotherapy
#       p-value: .98
#       type: SUPERIORITY
# Study: Interdisciplinary Study of A Novel Anticonvulsant in Alcoholism
# ['Placebo & Computerized Psychotherapy']
#     Analysis comparing groups: Placebo & Computerized Psychotherapy
#       p-value: .13
#       type: SUPERIORITY

# %%
s, o = xs[1]
o
# Out:
# {'type': 'PRIMARY',
#  'title': 'Participant Acceptability Ratings for ED-based Relationship Intervention in ED-Heart Intervention Arm',
#  'description': '1 survey item (investigator-developed) on acceptability of emergency department based healthy/unhealthy relationships intervention, rated using 5-point Likert scale (strongly disagree/1 to strongly agree/5)',
#  'populationDescription': 'Intervention participants answering follow up survey acceptability of ED-based adolescent relationship intervention',
#  'reportingStatus': 'POSTED',
#  'paramType': 'COUNT_OF_PARTICIPANTS',
#  'unitOfMeasure': 'Participants',
#  'timeFrame': '12 weeks',
#  'groups': [{'id': 'OG000',
#    'title': 'ED-HEART (Intervention Arm)',
#    'description': 'All adolescents take a baseline survey in the Emergency Department (ED), receive Emergency Department Healthcare Education Assessment and Response for Teen Relationships (ED HEART) by a trained health educator, complete an exit survey while in the ED, complete a 6-week check-in to confirm contact information and aid retention, and complete a 12-week follow up survey.\n\nED-HEART: Behavioral intervention that assesses 1) healthy and unhealthy relationship behaviors, 2) conversation with partners around boundaries within relationships, 3) harm reduction strategies, and 4) resources for Adolescent Relationship Abuse (ARA) and related concerns, including Point of Care (POC) Reproductive and Sexual Health (RSH) harm reduction resources.'}],
#  'denoms': [{'units': 'Participants',
#    'counts': [{'groupId': 'OG000', 'value': '45'}]}],
#  'classes': [{'categories': [{'title': 'Strongly agree/agree',
#      'measurements': [{'groupId': 'OG000', 'value': '34'}]},
#     {'title': 'Strongly disagree/disagree/neutral',
#      'measurements': [{'groupId': 'OG000', 'value': '11'}]}]}],
#  'analyses': [{'groupIds': ['OG000'],
#    'groupDescription': 'Our null hypothesis for the acceptabnility of the ED-Heart was P0 great than or equal to 85% vs. the alternative P0 less than 85%. Acceptability responses were dichotomized to include neutral with strongly disagree/disagree.',
#    'nonInferiorityType': 'OTHER',
#    'pValue': '.038',
#    'statisticalMethod': 'one sample test of proportions',
#    'statisticalComment': 'Hypothesis was evaluated using a one-tailed, one-proportion z-test'}]}

# %%
from collections import Counter
ni_types = []

for s in raw_studies_p:
    # id_mod = s["protocolSection"]["identificationModule"]
    # outcomes = s["resultsSection"]["outcomeMeasuresModule"]["outcomeMeasures"]
    # primary_outcomes_results = [o for o in outcomes if o["type"] == "PRIMARY"]
    # print("Study:", id_mod["briefTitle"])
    # print("https://clinicaltrials.gov/study/" + id_mod["nctId"])
    # if len(primary_outcomes_results) == 0:
    #     print("No primary outcomes results")
    #     continue
    for i, o in enumerate(primary_outcomes_results):
        # print(f"Primary outcome result {i+1}:")
        # print("  Title:", o["title"])
        # if "description" in o and o["description"]:
        #     print("  Description:", o["description"])
        # if "timeFrame" in o and o["timeFrame"]:
        #     print("  Time frame:", o["timeFrame"])
        if "analyses" in o:
            for analysis in o["analyses"]:
                if "pValue" in analysis:
                    # print(f"    p-value: {analysis['pValue']}")
                    # print(f"    p-value: {analysis['pValue']}")
                    ni_types.append(analysis["nonInferiorityType"])
       
    # print("-" * 40)

Counter(ni_types)
# Out:
# Counter({'SUPERIORITY': 9005, 'OTHER': 3602})

# %%
for group in s["resultsSection"]["participantFlowModule"]["groups"]:
    print(group["title"])
    display(group)
# Out:
# All Groups
# {'id': 'FG000',
#  'title': 'All Groups',
#  'description': 'Since participants\' data are only analyzed if they completed all assignments, and the order of assignment was immaterial to the trial, as it was a basic experiment studying humans, there was no reason to separate out the participants based on the order of interventions. Hence, the milestones listed below, other than "Completed," do not represent the actual sequential order for all participants.'}

# %%
primary_outcomes_results[0]['groups']
# primary_outcomes_results[0]
# Out:
# [{'id': 'OG000',
#   'title': 'TMS to dlPFC, Without a Concurrent Task (Passive)',
#   'description': "TMS (intermittent theta burst stimulation) will be applied to the dlPFC, when subjects are in a resting state\n\nTMS: Intermittent theta burst stimulation TMS applied to the cortex to excite cerebral cortex\n\nn-back working memory task: Subjects perform an executive function task, in which they view the serial presentation of letters and decide whether or not a letter matches a letter presented 'n' letters back (2 letters or 1 letter)"},
#  {'id': 'OG001',
#   'title': 'TMS to Vertex, Without Concurrent Task (Control)',
#   'description': "TMS (intermittent theta burst stimulation) will be applied to the cerebral vertex, when subjects are in a resting state\n\nTMS: Intermittent theta burst stimulation TMS applied to the cortex to excite cerebral cortex\n\nn-back working memory task: Subjects perform an executive function task, in which they view the serial presentation of letters and decide whether or not a letter matches a letter presented 'n' letters back (2 letters or 1 letter)"},
#  {'id': 'OG002',
#   'title': 'TMS to dlPFC, During Task (Active)',
#   'description': "TMS (intermittent theta burst stimulation) will be applied to the dlPFC, when subjects are engaged in the n-back working memory task\n\nTMS: Intermittent theta burst stimulation TMS applied to the cortex to excite cerebral cortex\n\nn-back working memory task: Subjects perform an executive function task, in which they view the serial presentation of letters and decide whether or not a letter matches a letter presented 'n' letters back (2 letters or 1 letter)"}]

# %%
s["protocolSection"]["descriptionModule"]
# Out:
# {'briefSummary': 'This study will develop an integrated treatment for adolescents who are depressed and suicidal and their parents who are depressed and have a history of suicidality.',
#  'detailedDescription': 'Depression, like many psychiatric disorders, has a genetic component that makes it more likely that members of the same family will have the disorder. Depression in parents, particularly mothers, may put the children at greater risk for depression. When an adolescent whose parent is depressed develops depression himself or herself, treating both the parent and the adolescent may be more effective than treating only the adolescent. This study will test a depression treatment that targets depressed suicidal adolescents with a parent or primary caretaker who is also depressed and has a history of suicidality.\n\nParticipation in this study will last 6 months. Participants will be randomly assigned to receive either concurrent parent and adolescent treatment or adolescent only treatment. For those assigned to concurrent treatment, both the adolescent participants and one of their parents will receive individual cognitive behavioral therapy (CBT) counseling sessions and joint family counseling sessions. In the adolescent only treatment condition, adolescent participants will receive individual CBT sessions, but parents will not, and both will receive joint family sessions. Counseling sessions will last 1 hour and occur weekly for 3 months, and then every other week for 3 months. CBT identifies and attempts to change problematic thought patterns. All participants will receive medication consultation if necessary.\n\nParticipants will complete assessments at baseline, post-treatment, and 6 months after completing treatment. These assessments will include questionnaires and interviews about depression, suicidal thoughts, mood regulation, behavioral problems, and family. At post-treatment and the 6-month follow-up, participants will also be asked to give feedback about the counseling, medication consultation, and their satisfaction.'}

# %%
from typing import Any

@dataclass
class PValue:
    comparator: str
    value: float



@dataclass
class Intervention:
    name: str
    type: str
    description: str
    arm_group_labels: list[str]

@dataclass
class Group:
    id: str
    title: str
    description: str
    num_participants: int
    interventions: list[Intervention]

@dataclass
class PrimaryOutcome:
    nct_id: str
    title: str
    description: str
    population_description: str
    timeframe: str
    groups: list[Group]
    p_value: PValue



@dataclass
class ValidStudy:
    nct_id: str
    title: str
    description: str
    conditions: list[str]
    keywords: list[str]
    brief_description: str
    primary_outcomes: list[PrimaryOutcome]
    interventions: list[Intervention]





valid_studies: list[ValidStudy] = []

def extract_interventions(protocol_section: dict[str, Any]) -> list[Intervention]:
    """Extract intervention information"""

    arms_module = protocol_section.get('armsInterventionsModule', {})
    interventions_data = arms_module.get('interventions', [])
    
    interventions = []
    for i, intervention_data in enumerate(interventions_data):
        intervention = Intervention(
            name=intervention_data.get('name', f'Intervention {i+1}'),
            type=intervention_data.get('type', 'OTHER'),
            description=intervention_data.get('description', ''),
            arm_group_labels=intervention_data.get('armGroupLabels', [])
        )
        interventions.append(intervention)
    
    return interventions


for s in raw_studies_p:
    primary_outcomes = []
    nct_id = s["protocolSection"]["identificationModule"]["nctId"]
    outcomes = s["resultsSection"]["outcomeMeasuresModule"]["outcomeMeasures"]
    interventions = extract_interventions(s["protocolSection"])
    arm_group_labels_to_intervention: dict[str, list[Intervention]] = {}

    for intervention in interventions:
        for label in intervention.arm_group_labels:
            label = label.lower()
            if label not in arm_group_labels_to_intervention:
                arm_group_labels_to_intervention[label] = []
            arm_group_labels_to_intervention[label].append(intervention)

    pos = [o for o in outcomes if o["type"] == "PRIMARY"]
    for o in pos:
        if "analyses" in o:
            for analysis in o["analyses"]:
                group_id_to_title = {g["id"]: g["title"] for g in o["groups"]}
                group_id_to_count = {}
                for denom in o["denoms"]:
                    if denom["units"].lower() != "participants":
                         continue
                    for c in denom["counts"]:
                        group_id_to_count[c["groupId"]] = c["value"]
                   
                if "pValue" in analysis:
                    groups = [f"{group_id_to_title[gid]} ({group_id_to_count[gid]})" for gid in analysis["groupIds"]]

                    pv = parse_p_value(analysis["pValue"])
                    primary_outcomes.append(PrimaryOutcome(
                        nct_id=nct_id,
                        title=o["title"],
                        description=o.get("description", ""),
                        population_description=o.get("populationDescription", ""),
                        timeframe=o.get("timeFrame", ""),
                        groups=[
                            Group(
                                id=g["id"],
                                title=g["title"],
                                description=g.get("description", ""),
                                interventions=arm_group_labels_to_intervention.get(g["title"].lower(), []),
                                num_participants=group_id_to_count.get(g["id"], 0)
                            ) for g in o["groups"] if g["id"] in analysis["groupIds"]
                        ],
                        p_value=PValue(
                            comparator=pv[0],
                            value=pv[1],
                        )
                    ))
    if primary_outcomes:
        dmod = s["protocolSection"]["descriptionModule"]
        valid_studies.append(ValidStudy(
            nct_id=nct_id,
            title=s["protocolSection"]["identificationModule"]["briefTitle"],
            description=dmod.get("detailedDescription", ""),
            brief_description=dmod.get("briefSummary", ""),
            primary_outcomes=primary_outcomes,
            interventions=interventions,
            conditions=s["protocolSection"]["conditionsModule"].get("conditions", []),
            keywords=s["protocolSection"]["conditionsModule"].get("keywords", []),
        ))


v = valid_studies[1]
# pprint(valid_studies[0])
pprint(v.primary_outcomes[0].groups)
pprint(v.interventions)
# Out:
# [Group(id='OG000',
#        title='Peer-mediated Pivotal Response Intervention',
#        description='Facilitators hold four 15-minute training sessions with '
#                    'the peer group to engage the target child. The facilitator '
#                    'explicitly identifies the "buddy" and asks the children to '
#                    'use four strategies to play with the child during center '
#                    'time: (a) offer your buddy some play options; (b) show and '
#                    'talk about how to play with your buddy; (c) compliment '
#                    'your buddy; and (d) show your buddy how to take turns. At '
#                    'each training session the facilitator will describe one '
#                    'strategy, provide examples, and practice the strategy '
#                    'through role play. After trainings, the facilitator '
#                    'provides ongoing support during center time to implement '
#                    'the strategies over 12 weeks during months 3-6 of the 9 '
#                    'months of study participation.\n'
#                    '\n'
#                    'Peer-mediated pivotal response training: Teachers support '
#                    'children in the implementation of three strategies '
#                    'directed toward a target child identified as having '
#                    'language impairment and as isolated from the classroom '
#                    'social network.',
#        num_participants='12',
#        interventions=[Intervention(name='Peer-mediated pivotal response '
#                                         'training',
#                                    type='BEHAVIORAL',
#                                    description='Teachers support children in '
#                                                'the implementation of three '
#                                                'strategies directed toward a '
#                                                'target child identified as '
#                                                'having language impairment and '
#                                                'as isolated from the classroom '
#                                                'social network.',
#                                    arm_group_labels=['Peer-mediated pivotal '
#                                                      'response intervention'])]),
#  Group(id='OG001',
#        title='Control',
#        description='Business as usual',
#        num_participants='13',
#        interventions=[])]
# [Intervention(name='Peer-mediated pivotal response training',
#               type='BEHAVIORAL',
#               description='Teachers support children in the implementation of '
#                           'three strategies directed toward a target child '
#                           'identified as having language impairment and as '
#                           'isolated from the classroom social network.',
#               arm_group_labels=['Peer-mediated pivotal response intervention'])]

# %%
# !pip install pyperclip
# Out:
# Collecting pyperclip
#   Downloading pyperclip-1.11.0-py3-none-any.whl.metadata (2.4 kB)
# Downloading pyperclip-1.11.0-py3-none-any.whl (11 kB)
# Installing collected packages: pyperclip
# Successfully installed pyperclip-1.11.0

# %%
import pyperclip

v = valid_studies[0]
o = v.primary_outcomes[0]
v.keywords

groups_info = []
for g in o.groups:
    groups_info.append("\n".join([
        f"Group title: {g.title}",
        f"Description: {g.description}",
        f"Interventions: {', '.join([f"{i.name}: {i.description}" for i in g.interventions]) if g.interventions else '(uncertain)'}",
    ]))

prompt = f"""
We are creating flashcard summaries for a game where laypeople predict the outcomes of clinical trials (behavioral interventive).

The final question for the flashcard must be of format:
Did [intervention] improve [outcome] in [treatment_group] compared to [comparison_group]?

Keep the questions as short as possible. Use acronyms if needed, as long as they are understandable. If there is a name given to the intervention (e.g. "The Jolly Flower Telephone Protocol for Healthy Ageing"), instead of using the name, simply describe the intervention in layperson's terms (e.g. "calling other elderly people").

Please answer in JSON format with the following fields:
• question: The final question in the specified format with the appropriate placeholders filled in verbatim with the other fields ("Did [intervention] improve [outcome] in [treatment_group] compared to [comparison_group]?")
• purpose: The purpose of the clinical trial, in layperson's terms. This should be directly pluggable into the question template.
• intervention: The main intervention being tested, in layperson's terms. This should be directly pluggable into the question template.
• outcome: The primary outcome being measured, in layperson's terms. This should be directly pluggable into the question template.
• comparison_group: The comparator or control condition, in layperson's terms. This should be directly pluggable into the question template.
• intervention_group_description: A brief description of the intervention group.
• comparator_group_description: A brief description of the comparator/control group.

Please ensure that the answers are concise and easily understandable by someone without a medical background. Avoid technical jargon and use simple language. Where something is technical, give a lay description and then in parentheses the technical term. 

Please create a question based on the following clinical trial information:
• Trial Title: {v.title}
• Trial Description: {v.description}
• Measure: {o.title}
• Measure Description: {o.description}

The groups are as follows (the first is the intervention group):
{'\n\n'.join(groups_info)}


If there is missing intervention or comparator information, please either match to these interventions (if you can tell from the group title/description), or say "Control" if it is a no-treatment or standard care control group, or "Unknown" if you cannot tell.
"""

pyperclip.copy(prompt)

# %%
for v in valid_studies[:5]:
    print(f"Study: {v.nct_id} - {v.title}")
    print(f"Brief Description: {v.brief_description[:200]}...")
    print("Primary Outcomes:")
    for outcome in v.primary_outcomes[:2]:
        print(f"  - Title: {outcome.title}")
        print(f"    Description: {outcome.description}")
        print(f"    Population Description: {outcome.population_description}")
        print(f"    Timeframe: {outcome.timeframe}")
        print(f"    P-Value: {outcome.p_value.comparator}{outcome.p_value.value}")
        print(f"    SUCCESS: {outcome.p_value.comparator != '>' and outcome.p_value.value < 0.05}")
        print("    Groups:")
        for group in outcome.groups:
            print(f"      * ID: {group.id}")
            print(f"        Title: {group.title}")
            print(f"        Description: {group.description}")
            print(f"        Number of Participants: {group.num_participants}")
    print("-" * 80)
# Out:
# Study: NCT03022370 - Stepping Stones and Creating Futures Intervention Trial
# Brief Description: This study evaluates whether the behavioural/structural interventions of Stepping Stones and Creating Futures can reduce the incidence of intimate partner violence in urban informal settlements amongs...
# Primary Outcomes:
#   - Title: Any Past Year Physical Intimate Partner Violence Perpetration (Men) and Experience (Women)
#     Description: Physical intimate partner violence is assessed using five items based on the WHO VAW scale. A positive response to any item leads to a person being classified as perpetrating (men) and experiencing (women) in the past year. With 0=none, 1=yes.
#     Population Description:
#     Timeframe: 24 months post baseline
#     P-Value: =0.686
#     SUCCESS: False
#     Groups:
#       * ID: OG000
#         Title: Women - Intervention
#         Description: Women who received the Stepping Stones and Creating Futures intervention
#         Number of Participants: 260
#       * ID: OG002
#         Title: Women - Control
#         Description: Women in the wait list control
#         Number of Participants: 285
#   - Title: Any Past Year Physical Intimate Partner Violence Perpetration (Men) and Experience (Women)
#     Description: Physical intimate partner violence is assessed using five items based on the WHO VAW scale. A positive response to any item leads to a person being classified as perpetrating (men) and experiencing (women) in the past year. With 0=none, 1=yes.
#     Population Description:
#     Timeframe: 24 months post baseline
#     P-Value: =0.032
#     SUCCESS: True
#     Groups:
#       * ID: OG001
#         Title: Men - Intervention
#         Description: Men who received the intervention
#         Number of Participants: 237
#       * ID: OG003
#         Title: Men - Control
#         Description: Men in the wait list control
#         Number of Participants: 268
# --------------------------------------------------------------------------------
# Study: NCT06182033 - Penetrating the Classroom Social Network for Children With Language Impairment Via Peer Mediated Intervention
# Brief Description: This exploratory experiment is designed to determine the extent to which the socialization experiences and social, behavioral, and linguistic skills of preschoolers with language impairment (LI) can b...
# Primary Outcomes:
#   - Title: Preschool Language Screener 5 (PLS-5) - Growth Scale Value
#     Description: The PLS-5 is used to assess expressive language skills. Specific skills assessed include naming, expressing quantity, describing, using specific prepositions, grammatical markers, sentence structures, and emergent literacy skills. An assessor indicates whether a child passes (1) or does not pass (0) each item. Growth Scale Value: Range: Minimum = 100/Max = 900. Higher scores indicate better expressive language skills. Assessed at baseline, 3 months, and 9 months. Baseline reported.
#     Population Description: At baseline and 3 months, 11 participants were assessed with the PLS-5 in the peer-mediated pivotal response intervention group instead of the total number in the sample (n = 12) because one participant was consistently absent from school during the assessment window. At 9 months, 12 participants were assessed with the PLS-5 in the control group instead of the total number in the sample (n = 13) because one participant was consistently absent from school during the assessment window.
#     Timeframe: at baseline, 3 months, and 9 months
#     P-Value: =0.84
#     SUCCESS: False
#     Groups:
#       * ID: OG000
#         Title: Peer-mediated Pivotal Response Intervention
#         Description: Facilitators hold four 15-minute training sessions with the peer group to engage the target child. The facilitator explicitly identifies the "buddy" and asks the children to use four strategies to play with the child during center time: (a) offer your buddy some play options; (b) show and talk about how to play with your buddy; (c) compliment your buddy; and (d) show your buddy how to take turns. At each training session the facilitator will describe one strategy, provide examples, and practice the strategy through role play. After trainings, the facilitator provides ongoing support during center time to implement the strategies over 12 weeks during months 3-6 of the 9 months of study participation.
#
# Peer-mediated pivotal response training: Teachers support children in the implementation of three strategies directed toward a target child identified as having language impairment and as isolated from the classroom social network.
#         Number of Participants: 12
#       * ID: OG001
#         Title: Control
#         Description: Business as usual
#         Number of Participants: 13
# --------------------------------------------------------------------------------
# Study: NCT04010461 - Theta Burst Transcranial Magnetic Stimulation of Fronto-parietal Networks: Modulation by Mental State
# Brief Description: The purpose of this study is to improve understanding of the way transcranial magnetic stimulation (TMS), a form of non-invasive brain stimulation, affects the brain. The study hypothesis that when th...
# Primary Outcomes:
#   - Title: 2-back Minus 1-back Blood Oxygen Level-Dependent (BOLD) Activation, Voxelwise in FPN
#     Description: Fronto-parietal network (FPN) defined by BOLD change while subject performed the n-back working memory task, contrasting high (2-back) versus low (1-back) loads. Using the SPM12 package, data were normalized per standard, open source routines. Using a General Linear Model framework, a model was estimated with regressors (after convolution with hemodynamic response function) for 2-back \& 1-back conditions for each subject to predict BOLD change each day (arm).For analysis of group effects, second-level, between-subject analyses on normalized images of the 2-back minus 1-back beta estimate from the first level were entered into regression models, with mean frame displacement as a co-variate of no-interest to test contrasts between the arms/interventions. Using a FPN mask, the eigenvalues from the second-level estimates were extracted and entered into the analysis as an outcome measure. Note: eigenvalues are arbitrary units. Larger values indicate more BOLD signal.
#     Population Description: Of the 40 participants, image data from 3 failed quality control.
#     Timeframe: 60 minutes after TMS during fMRI
#     P-Value: =0.11
#     SUCCESS: False
#     Groups:
#       * ID: OG000
#         Title: TMS to dlPFC, Without a Concurrent Task (Passive)
#         Description: TMS (intermittent theta burst stimulation) will be applied to the dlPFC, when subjects are in a resting state
#
# TMS: Intermittent theta burst stimulation TMS applied to the cortex to excite cerebral cortex
#
# n-back working memory task: Subjects perform an executive function task, in which they view the serial presentation of letters and decide whether or not a letter matches a letter presented 'n' letters back (2 letters or 1 letter)
#         Number of Participants: 37
#       * ID: OG002
#         Title: TMS to dlPFC, During Task (Active)
#         Description: TMS (intermittent theta burst stimulation) will be applied to the dlPFC, when subjects are engaged in the n-back working memory task
#
# TMS: Intermittent theta burst stimulation TMS applied to the cortex to excite cerebral cortex
#
# n-back working memory task: Subjects perform an executive function task, in which they view the serial presentation of letters and decide whether or not a letter matches a letter presented 'n' letters back (2 letters or 1 letter)
#         Number of Participants: 37
#   - Title: 2-back Minus 1-back Blood Oxygen Level-Dependent (BOLD) Activation, Voxelwise in FPN
#     Description: Fronto-parietal network (FPN) defined by BOLD change while subject performed the n-back working memory task, contrasting high (2-back) versus low (1-back) loads. Using the SPM12 package, data were normalized per standard, open source routines. Using a General Linear Model framework, a model was estimated with regressors (after convolution with hemodynamic response function) for 2-back \& 1-back conditions for each subject to predict BOLD change each day (arm).For analysis of group effects, second-level, between-subject analyses on normalized images of the 2-back minus 1-back beta estimate from the first level were entered into regression models, with mean frame displacement as a co-variate of no-interest to test contrasts between the arms/interventions. Using a FPN mask, the eigenvalues from the second-level estimates were extracted and entered into the analysis as an outcome measure. Note: eigenvalues are arbitrary units. Larger values indicate more BOLD signal.
#     Population Description: Of the 40 participants, image data from 3 failed quality control.
#     Timeframe: 60 minutes after TMS during fMRI
#     P-Value: =0.94
#     SUCCESS: False
#     Groups:
#       * ID: OG000
#         Title: TMS to dlPFC, Without a Concurrent Task (Passive)
#         Description: TMS (intermittent theta burst stimulation) will be applied to the dlPFC, when subjects are in a resting state
#
# TMS: Intermittent theta burst stimulation TMS applied to the cortex to excite cerebral cortex
#
# n-back working memory task: Subjects perform an executive function task, in which they view the serial presentation of letters and decide whether or not a letter matches a letter presented 'n' letters back (2 letters or 1 letter)
#         Number of Participants: 37
#       * ID: OG001
#         Title: TMS to Vertex, Without Concurrent Task (Control)
#         Description: TMS (intermittent theta burst stimulation) will be applied to the cerebral vertex, when subjects are in a resting state
#
# TMS: Intermittent theta burst stimulation TMS applied to the cortex to excite cerebral cortex
#
# n-back working memory task: Subjects perform an executive function task, in which they view the serial presentation of letters and decide whether or not a letter matches a letter presented 'n' letters back (2 letters or 1 letter)
#         Number of Participants: 37
# --------------------------------------------------------------------------------
# Study: NCT02248649 - Telemedicine Intervention to Improve Cognitive Function
# Brief Description: This project is investigating whether a home-based exercise program will reduce cognitive decline in patients with Parkinson's disease....
# Primary Outcomes:
#   - Title: Change From Baseline on Cognitive Section of Alzheimer Disease Assessment Scale (ADAS-Cog) at Month 6
#     Description: The ADAS-Cog includes items assessing memory, orientation, language, and praxis. Scores range from 0-70 (higher scores indicate worse cognitive function). Change = Score at 6-month - Score at Baseline.
#     Population Description: number of participants analyzed: participants with ADAS-Cog scores at baseline and at 6 months. 4 participants in Physical Activity group and 6 participants in Control group did not have a score at 6 months.
#     Timeframe: Baseline and 6 months
#     P-Value: =0.2
#     SUCCESS: False
#     Groups:
#       * ID: OG000
#         Title: Physical Activity
#         Description: Structured walking program
#
# Structured physical activity: Walking instruction and encouragement
#         Number of Participants: 76
#       * ID: OG001
#         Title: Control
#         Description: Health education attention control
#
# Health education: Provision of general information about a variety of health topics
#
# Provision of general information about a variety of health
#         Number of Participants: 74
# --------------------------------------------------------------------------------
# Study: NCT00250588 - Problem-Solving Skills Training to Improve Care for Children With Asthma
# Brief Description: The purpose of this study is to determine whether Problem-Solving Skills Training is effective in reducing barriers to health care and improving health-related quality of life for children with persis...
# Primary Outcomes:
#   - Title: Parent Proxy-Reported Health-related Quality of Life (Pediatric Quality of Life Inventory)
#     Description: The PedsQL™ 4.0 Generic Core Scales Total Scale Score (PedsQL™), which has been shown to be internally consistent, valid, and responsive to indicators of clinical change for children with asthma (Chan, Mangione-Smith, Burwinkle, Rosen, \& Varni, 2005; Seid et al., in press; Varni et al., 2004). The 23-item PedsQL™ asks respondents how often various issues have been a 'problem' in the past month, yields a score of 0 to 100 (higher scores are better), and includes parallel child self-report (ages 5-18 years) and parent proxy-report (ages 2-18 years) forms. We measured both self- and proxy-report, although our a priori primary outcome was parent proxy-report.
#     Population Description: All analyses were intent-to-treat and carried out according to a pre-established plan using SAS 9.1.3. All subjects with data at T2 or T3 were included in the analyses.
#     Timeframe: Baseline (T1), Post Intervention (3mo, T2), 6-month follow up (9mo post baseline, T3)
#     P-Value: =0.05
#     SUCCESS: False
#     Groups:
#       * ID: OG001
#         Title: Care Coordination+Problem Solving
#         Description: The CC+PST consisted of CC plus a 6-session (45-60 minutes, weekly) problem-solving skills training intervention. Participants are taught to approach problems proactively, define the problem, generate alternative solutions, choose the best, implement the solution, and evaluate how well that solution worked. Session 1 was devoted to rapport building, understanding the relevant social and medical situation, presenting an overview of the PST curriculum, and assigning the first homework - identifying a solvable problem. Session 2 reviewed prior homework, introduced the idea of developing alternative solutions, and assigned homework - defining and evaluating options. Session 3 reviewed homework, developed an action plan and assigned homework - implementing the action plan. Sessions 4-6 depended on the outcome of the actions, focusing on alternative plans if the results of the action plan were not satisfactory to the client or on additional problems if the results were satisfactory.
#         Number of Participants: 65
#       * ID: OG002
#         Title: Standard Care
#         Description: The standard care wait list control group received ongoing asthma care from their place of care during the trial. They were offered the CC+PST intervention after the T3 follow up.
#         Number of Participants: 74
#   - Title: Parent Proxy-Reported Health-related Quality of Life (Pediatric Quality of Life Inventory)
#     Description: The PedsQL™ 4.0 Generic Core Scales Total Scale Score (PedsQL™), which has been shown to be internally consistent, valid, and responsive to indicators of clinical change for children with asthma (Chan, Mangione-Smith, Burwinkle, Rosen, \& Varni, 2005; Seid et al., in press; Varni et al., 2004). The 23-item PedsQL™ asks respondents how often various issues have been a 'problem' in the past month, yields a score of 0 to 100 (higher scores are better), and includes parallel child self-report (ages 5-18 years) and parent proxy-report (ages 2-18 years) forms. We measured both self- and proxy-report, although our a priori primary outcome was parent proxy-report.
#     Population Description: All analyses were intent-to-treat and carried out according to a pre-established plan using SAS 9.1.3. All subjects with data at T2 or T3 were included in the analyses.
#     Timeframe: Baseline (T1), Post Intervention (3mo, T2), 6-month follow up (9mo post baseline, T3)
#     P-Value: =0.05
#     SUCCESS: False
#     Groups:
#       * ID: OG000
#         Title: Care Coordination
#         Description: The 5-session (45-60 minutes, weekly) CC was based on NHLBI guidelines and the RWJF's Allies Against Asthma community health worker model (Friedman et al., 2006) and was delivered by two bachelor's level bilingual, bicultural asthma home visitors. The home visitors implemented a structured set of educational interventions, with written materials in English or Spanish, on the following topics: what is asthma, asthma medications and devices, asthma action plan, how to recognize and respond to symptom onset, and how to reduce irritants and allergens in the home. Home visitors referred families, when necessary, to existing health insurance enrollment assistance, smoking cessation, and other community support services. Home visitors communicated with the primary care provider via FAX, giving summaries of interventions, updates on progress, and noting family difficulties and needs (for example, needing equipment, prescriptions, or an (updated) asthma treatment plan).
#         Number of Participants: 72
#       * ID: OG002
#         Title: Standard Care
#         Description: The standard care wait list control group received ongoing asthma care from their place of care during the trial. They were offered the CC+PST intervention after the T3 follow up.
#         Number of Participants: 74
# --------------------------------------------------------------------------------

# %%
s["resultsSection"]

def find_paths_to_key(data, key_prefix, current_path=""):
    """
    Recursively find all paths to keys that start with the given prefix.
    
    Args:
        data: The data structure to search (dict, list, or other)
        key_prefix: The prefix to search for in dictionary keys
        current_path: The current path (used for recursion)
    
    Returns:
        List of paths where keys starting with key_prefix are found
    """
    paths = []
    
    if isinstance(data, dict):
        for key, value in data.items():
            new_path = f"{current_path}.{key}" if current_path else key
            
            # Check if this key starts with our prefix
            if key.startswith(key_prefix):
                paths.append(new_path)
            
            # Recursively search the value
            paths.extend(find_paths_to_key(value, key_prefix, new_path))
    
    elif isinstance(data, list):
        for i, item in enumerate(data):
            new_path = f"{current_path}[{i}]" if current_path else f"[{i}]"
            paths.extend(find_paths_to_key(item, key_prefix, new_path))
    
    return paths

# Find all paths to keys starting with "armGroup"
armgroup_paths = find_paths_to_key(s, "armGroup")
print("Paths to keys starting with 'armGroup':")
for path in armgroup_paths:
    print(f"  {path}")
# Out:
# Paths to keys starting with 'armGroup':
#   protocolSection.armsInterventionsModule.armGroups
#   protocolSection.armsInterventionsModule.interventions[0].armGroupLabels
#   protocolSection.armsInterventionsModule.interventions[1].armGroupLabels

# %%
s["resultsSection"]['participantFlowModule'].keys()
# Out:
# dict_keys(['groups', 'periods'])
