# %%
import sys
import os
from dataclasses import dataclass
from dotenv import load_dotenv
from openai import OpenAI
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading

sys.path.insert(0, "../src")

from extract_valid_studies import main
from models import ValidStudy, PrimaryOutcome

load_dotenv()
# Out:
# True

# %%
MODEL = "gpt-5-mini"
RAW_STUDIES_DIR = "../data/raw_studies"
STUDIES_PROCESSED_OUTPUT_DIR= "../data/studies_processed"
CARDS_OUTPUT_DIR = "../data/cards"
MAX_WORKERS = 100
NUM_CARDS = 500

# %%
from pydantic import BaseModel, Field, model_validator

class LLMResponse(BaseModel):
    question: str = Field(..., description="The final question in the specified format with the appropriate placeholders filled in verbatim with the other fields.")
    intervention_fragment: str = Field(..., description="The main intervention being tested, in layperson's terms. This should be directly pluggable into the question template.")
    intervention_group_fragment: str = Field(..., description="The purpose of the clinical trial, in layperson's terms. This should be directly pluggable into the question template.")
    outcome_fragment: str = Field(..., description="The primary outcome being measured, in layperson's terms. This should be directly pluggable into the question template.")
    comparator_group_fragment: str = Field(..., description="The comparator or control condition, in layperson's terms. This should be directly pluggable into the question template.")
    timeframe_fragment: str = Field(..., description="The timeframe of the outcome measurement, in layperson's terms. This should be directly pluggable into the question template.")
    intervention_group_description: str = Field(..., description="A brief description of the intervention group.")
    comparator_group_description: str = Field(..., description="A brief description of the comparator/control group.")

    @model_validator(mode="after")
    def ensure_question_valid(self):
        expected_question = f"Did {self.intervention_fragment} improve {self.outcome_fragment} in {self.intervention_group_fragment} compared to {self.comparator_group_fragment} after {self.timeframe_fragment}?"
        if self.question != expected_question:
            raise ValueError(f"Question does not match the expected format. Got: {self.question}, Expected: {expected_question}")
        return self


@dataclass
class ProcessingInformation:
    study: ValidStudy
    outcome_id: str
    llm_response: LLMResponse

    def to_dict(self):
        def recursive_asdict(obj):
            if isinstance(obj, list):
                return [recursive_asdict(item) for item in obj]
            elif isinstance(obj, dict):
                return {key: recursive_asdict(value) for key, value in obj.items()}
            elif hasattr(obj, "__dict__"):
                return {key: recursive_asdict(value) for key, value in obj.__dict__.items()}
            else:
                return obj
        return {
            "study": recursive_asdict(self.study),
            "outcome_id": self.outcome_id,
            "llm_response": self.llm_response.model_dump(),
        }

# %%
@dataclass
class UsageTracker:
    total_api_calls: int = 0
    total_input_tokens: int = 0
    total_output_tokens: int = 0


    def cost(self) -> float:
        c_i = {
            "gpt-5": 1.25,
            "gpt-5-mini": 0.25,
        }
        c_o = {
            "gpt-5": 10,
            "gpt-5-mini": 2,
        }
        input_cost = (self.total_input_tokens / 1_000_000) * c_i[MODEL]
        output_cost = (self.total_output_tokens / 1_000_000) * c_o[MODEL]

        return input_cost + output_cost

    def summary(self):
        print(f"Total API calls: {self.total_api_calls}")
        print(f"Total input tokens: {self.total_input_tokens}")
        print(f"Total output tokens: {self.total_output_tokens}")
        print(f"Estimated cost: ${self.cost():.4f}")

tracker = UsageTracker()

# %%
def mk_prompt(v: ValidStudy, o: PrimaryOutcome) -> str:
    groups_info = []
    for g in o.groups:
        groups_info.append("\n".join([
            f"Group title: {g.title}",
            f"Description: {g.description}",
            f"Interventions: {', '.join([f"{i.name}: {i.description}" for i in g.interventions]) if g.interventions else '(uncertain)'}",
        ]))


    return f"""
We are creating flashcard summaries for a game where laypeople predict the outcomes of clinical trials (behavioral interventive).

The final question for the flashcard must be of format:
"Did [intervention_fragment] improve [outcome_fragment] in [intervention_group_fragment] compared to [comparator_group_fragment] after [timeframe_fragment]?"

Keep the questions as short as possible. Use acronyms if needed, as long as they are understandable. If there is a name given to the intervention (e.g. "The Jolly Flower Telephone Protocol for Healthy Ageing"), instead of using the name, simply describe the intervention in layperson's terms (e.g. "calling other elderly people").

Remember to keep the question short. Do not include examples. Do not include any additional text or explanation.

Recall that the question should be reconstructable by verbatim plugging in the other fields.


Please ensure that the answers are concise and easily understandable by someone without a medical background. Avoid technical jargon and use simple language. Where something is technical, give a lay description and then in parentheses the technical term. 

Please create a question based on the following clinical trial information:
• Trial Title: {v.title}
• Trial Description: {v.description}
• Measure: {o.title}
• Measure Description: {o.description}
• Timeframe: {o.timeframe}

The groups are as follows (the first is the intervention group):
{'\n\n'.join(groups_info)}


If there is missing intervention or comparator information, please either match to these interventions (if you can tell from the group title/description), or say "Control" if it is a no-treatment or standard care control group, or "Unknown" if you cannot tell.
    """

# %%
valid_studies = main(RAW_STUDIES_DIR, NUM_CARDS)
# Out:
#  85%|████████▍ | 29359/34562 [00:07<00:01, 4084.48it/s]
# Loaded 5000 raw studies with results
# 1736 out of 5000 (34.72%) studies have p-values reported in primary outcomes analyses.

# %%
def process_single_outcome(study: ValidStudy, o: PrimaryOutcome, tracker_lock: threading.Lock) -> ProcessingInformation:
    """Process a single study and return the result or raise an exception."""
    MAX_TRIES = 3
    success = False
    n_tries = 0

    client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    while not success and n_tries < MAX_TRIES:
        n_tries += 1

        try:
            response = client.responses.parse(
                model=MODEL,
                input=[
                    {
                        "role": "system",
                        "content": "You are an expert clinical trial analyst."
                    },
                    {"role": "user", "content": mk_prompt(study, o)},
                ],
                text_format=LLMResponse,
            )

            # Track token usage (thread-safe)
            with tracker_lock:
                tracker.total_api_calls += 1
                tracker.total_input_tokens += response.usage.input_tokens
                tracker.total_output_tokens += response.usage.output_tokens

            # Parse response
            llm_response = response.output_parsed

            return ProcessingInformation(
                study=study,
                outcome_id=o.id,
                llm_response=llm_response
            )
        except Exception as e:
            # Re-raise with study info for better error handling
            if n_tries >= MAX_TRIES - 1:
                raise Exception(f"Failed processing {study.nct_id}: {str(e)}")


def process_studies_multithreaded(studies: list[ValidStudy], max_workers: int = MAX_WORKERS) -> tuple[list[ProcessingInformation], list[tuple[str, str]]]:
    """Process studies using multiple threads."""
    results = []
    failures = []
    tracker_lock = threading.Lock()
    
    # Use ThreadPoolExecutor for concurrent API calls
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        # Submit all tasks
        future_to_study = {
            executor.submit(process_single_outcome, study, study.primary_outcomes[0], tracker_lock): study
            for study in studies
        }
        
        # Process completed tasks with progress bar
        with tqdm(total=len(studies), desc="Processing studies") as pbar:
            for future in as_completed(future_to_study):
                study = future_to_study[future]
                try:
                    result = future.result()
                    results.append(result)
                except Exception as e:
                    failures.append((study.nct_id, str(e)))
                    pbar.set_postfix_str(f"Failures: {len(failures)}")
                
                pbar.update(1)
    
    return results, failures

# %%
# Process studies using multithreading (adjust max_workers based on API rate limits)
results, failures = process_studies_multithreaded(valid_studies[:NUM_CARDS], max_workers=MAX_WORKERS)

tracker.summary()

print(f"Successfully processed: {len(results)} studies")
print(f"Failed: {len(failures)} studies")
if failures:
    print("Failures:")
    for nct_id, error in failures[:5]:  # Show first 5 failures
        print(f"  {nct_id}: {error}")
# Out:
# Processing studies: 100%|██████████| 500/500 [03:15<00:00,  2.55it/s, Failures: 52]
# Total API calls: 448
# Total input tokens: 641911
# Total output tokens: 588290
# Estimated cost: $1.3371
# Successfully processed: 448 studies
# Failed: 52 studies
# Failures:
#   NCT01744977: Failed processing NCT01744977: 1 validation error for LLMResponse
#   Value error, Question does not match the expected format. Got: Did blister-packaging plus adherence education improve statin adherence in people with high LDL or poor adherence compared to the education-only group after 12 months?, Expected: Did blister-packaging plus adherence education improve statin adherence (measured by pill refill) in people with high LDL or poor statin adherence compared to education-only group after 12 months? [type=value_error, input_value={'question': 'Did blister... adherence packaging).'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error
#   NCT03270943: Failed processing NCT03270943: 1 validation error for LLMResponse
#   Value error, Question does not match the expected format. Got: Did an 8-week mindful self-compassion course improve time to incident depression in teens with subsyndromal depression compared to an 8-week healthy lifestyles course after up to 36 weeks?, Expected: Did an 8-week mindful self-compassion course improve time to developing depression (PROMIS pediatric T-score ≥65) in teens (ages 14–17) with subsyndromal depression compared to an 8-week healthy lifestyles course after up to 36 weeks (weekly assessments)? [type=value_error, input_value={'question': 'Did an 8-we... continuation sessions'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error
#   NCT00127790: Failed processing NCT00127790: 1 validation error for LLMResponse
#   Value error, Question does not match the expected format. Got: Did 10 sessions of cognitive-behavioral therapy for insomnia (CBT-I) improve insomnia severity (Insomnia Severity Index total score) in patients with chronic pain compared to wait-list control (no treatment) after about 10 weeks (pre-to-post treatment)?, Expected: Did 10 sessions of cognitive-behavioral therapy for insomnia (CBT-I) improve insomnia severity (Insomnia Severity Index total score) in patients with chronic pain compared to wait-list control (no treatment) after after about 10 weeks (pre-to-post treatment)? [type=value_error, input_value={'question': 'Did 10 sess...period (no treatment).'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error
#   NCT02665468: Failed processing NCT02665468: 1 validation error for LLMResponse
#   Value error, Question does not match the expected format. Got: Did support to adopt secure messaging improve sending secure messages in Veterans receiving the supported adoption intervention compared to Veterans receiving usual care (no extra support) after 6 months?, Expected: Did support to adopt secure messaging (reminders, motivational messages, and education) improve sending secure messages (secure messaging use) in Veterans receiving the supported adoption intervention compared to Veterans receiving usual care (no extra support) after 6 months? [type=value_error, input_value={'question': 'Did support... usual care (control).'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error
#   NCT03552198: Failed processing NCT03552198: 1 validation error for LLMResponse
#   Value error, Question does not match the expected format. Got: Did more specific, targeted AQI health messages improve adoption of protective behaviours to reduce air pollution exposure in the general public compared to usual UK AQI health advice after 4 weeks?, Expected: Did more specific, targeted AQI health messages improve adoption of protective behaviours to reduce air pollution exposure in general public compared to usual UK AQI health advice after 4 weeks? [type=value_error, input_value={'question': 'Did more sp...alerts/standard care).'}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error

# %%
import ujson as json
for result in results:
    with open(os.path.join(STUDIES_PROCESSED_OUTPUT_DIR, f"{result.study.nct_id}_{result.outcome_id}_llm_response.json"), "w") as f:
        json.dump(result.to_dict(), f, indent=4)

# %%
def get_num_participants(groups) -> int:
    n = 0
    for g in groups:
        num = g.num_participants
        if isinstance(num, int):
            n += num
        elif isinstance(num, str):
            new_num = ''
            for c in num:
                if c.isdigit():
                    new_num += c
            n += int(new_num)

    return n

def mk_card(r: ProcessingInformation) -> dict:
    """Create a card dictionary from the processing information."""
    o = next(o for o in r.study.primary_outcomes if o.id == r.outcome_id)
    p_value = f"{o.p_value.comparator}{o.p_value.value}"
    if p_value.startswith("="):
        p_value = p_value[1:]

    success = (o.p_value.value < 0.05 and o.p_value.comparator != ">") or p_value == "<0.05"

    return {
        "study": {
            "nct_id": r.study.nct_id,
            "title": r.study.title,
            "brief_description": r.study.brief_description,
        },
        "card_id": r.outcome_id,
        "front_details": {
            "question": r.llm_response.question,
            "intervention_fragment": r.llm_response.intervention_fragment,
            "intervention_group_fragment": r.llm_response.intervention_group_fragment,
            "outcome_fragment": r.llm_response.outcome_fragment,
            "comparator_group_fragment": r.llm_response.comparator_group_fragment,
            "timeframe_fragment": r.llm_response.timeframe_fragment,
        },
        "p_value": p_value,
        "num_participants": get_num_participants(o.groups),
        "success": success,
        "conditions": r.study.conditions,
        "keywords": r.study.keywords,
    }

cards = [mk_card(r) for r in results]
with open(os.path.join(CARDS_OUTPUT_DIR, "cards.json"), "w") as f:
    json.dump(cards, f, indent=4)

# %%
for c in cards:
    print(c["front_details"]["question"])
    print(c["p_value"])
    print(c["num_participants"])
# Out:
# Did 6-week diabetes self-management classes improve blood sugar control (HbA1c) in adults with T2DM compared to usual care (control) after 12 months?
# 0.771
# 376
# Did using a web-based lung cancer screening decision aid improve decisional conflict (uncertainty about the screening decision) in Veterans who used the decision tool compared to Veterans given general prevention info (not about lung cancer) after 1 month?
# 0.18
# 124
# Did practicing Tai Chi improve knee pain (WOMAC pain score) in people with knee osteoarthritis compared to wellness education and stretching after 12 weeks?
# 0.0005
# 40
# Did patient-parent-coach support with problem-solving, if‑then action plans, and dose reminders improve percent of days with full medication taking (100% taking adherence) in teen kidney transplant recipients compared to attention-control coach visits (no adherence support) after 12 months?
# 0.006
# 138
# Did ibuprofen (200 mg twice daily) plus a 6-week home walking and resistance-band exercise program improve memory (percent correct on a computerized test) in cancer patients on chemotherapy compared to placebo (sugar pill) after 6 weeks?
# 0.9168
# 86
# Did care management plus community health worker visits and home BP monitors improve systolic BP (top number) in people with stroke/TIA compared to usual care (educational materials and standard post‑stroke care) after 12 months?
# 0.73
# 487
# Did tailored education, skills training and counseling improve average nightly CPAP use (hrs/night) in adults with newly diagnosed OSA starting CPAP compared to usual care after 1 week?
# 0.2
# 60
# Did web-based monitoring of symptoms and fecal calprotectin improve medication adherence (MARS score) in children/adolescents with IBD on home meds compared to routine outpatient controls (4 visits/year) after up to 2 years (every 3 months)?
# 0.22
# 53
# Did practicing episodic future thinking (EFT) using app-based future cues improve preference for immediate rewards (delay discounting) in prediabetic adults receiving EFT + a traffic-light weight-loss program compared to prediabetic adults receiving daily app check-ins + the same program (no EFT) after 12 and 24 weeks?
# 0.0035
# 64
# Did a web-based self-management program with nurse coaching improve pain self-efficacy (Pain Self-Efficacy Questionnaire score) in patients using the PainTracker Self-Manager compared to patients getting PainTracker only (usual care) after 3 and 6 months?
# <0.05
# 82
# Did twice-daily exenatide injections improve body weight (weight loss) in overweight/obese non-diabetic women compared to placebo injections after 12 weeks?
# <0.05
# 108
# Did moderate-dose SSRI (sertraline/escitalopram) improve panic symptoms (PDSS score) in the moderate sertraline treatment group compared to unknown comparator after 6 weeks?
# 0.0
# 39
# Did chewing gum improve math scores (TAKS) in students who chewed gum compared to students who did not chew gum after 14 weeks (end of the semester)?
# 0.05
# 106
# Did a 1-year intensive physical activity counseling program improve walking speed (gait speed) in older veterans compared to usual care after 12 months?
# 0.47
# 355
# Did automated phone refill reminders improve inhaler medication adherence (mMPR) in people with asthma compared to usual care after 19 months?
# 0.002
# 6431
# Did in-person highly challenging balance exercise improve fall rate (number of falls) in VA patients with mild-to-moderate Parkinson's disease compared to health education after 3 months?
# <0.05
# 104
# Did a text-message gamified adherence game improve blood HIV level (HIV-1 viral load, log10-transformed) in young people living with HIV in Ghana compared to brief in-person adherence counseling (standard care) after 90 days?
# <0.05
# 48
# Did ranolazine + glimepiride improve HbA1c (average blood sugar over 3 months) in people with type 2 diabetes compared to placebo + glimepiride after 24 weeks?
# <0.001
# 372
# Did online personalized feedback (PFI) after lab alcohol-cue exposure improve drinks per week (typical week; Daily Drinking Questionnaire) in young adults who received the PFI compared to assessment-only control (no personalized feedback) after 2-week and 3-month follow-ups?
# 0.83
# 93
# Did using a mobile self-help app (IntelliCare) daily improve depression severity (PHQ-9 score) in college students compared to control after 8 weeks (weekly reports at Wks 1,2,4,6,8)?
# 0.83
# 73
# Did mailed educational outreach (physician letter, brochure, DVD) improve colorectal cancer screening completion in patients with uncompleted CRC screening orders compared to usual care after 3 months post randomization?
# <0.05
# 628
# Did using an online CBT program with crowd features improve depression (DASS depression score) in people using the crowd-powered online CBT program compared to people using a self-guided online CBT program without crowd features after 16 weeks?
# 0.79
# 70
# Did smartphone self-control training (daily app prompts) improve average daily steps (objective physical activity) in sedentary middle-aged and older adults in the self-control group compared to Fitbit with a minimal app (daily reminders only, control) after weeks 2–8 (pretest to posttest)?
# 0.038
# 75
# Did computer-based working memory training improve consideration of future consequences (CFCS-14) in at-risk adolescents in underserved communities compared to Control after 7 weeks?
# 0.473
# 9
# Did nurse care manager monitoring and patient counseling improve self-reported opioid misuse risk (COMM) in patients on long-term prescription opioids compared to usual care (no nurse care manager) after 12 months?
# <0.05
# 258
# Did a 3-week mindfulness training app improve brain activity (BOLD signal on fMRI) in smokers in the mindfulness app group compared to smokers using a standard smoking-cessation app after 1 month?
# 0.92
# 67
# Did group training to strengthen social bonds and relationship skills improve suicide severity score (0–100; higher = greater risk) in early-career enlisted U.S. Airmen compared to 2‑hr stress-management training with follow-up text messages after 6 months?
# 0.062
# 571
# Did adding traditional aerobic exercise to brain training improve Bird Safari visual speed (T-score; lower = better) in the brain-training + traditional exercise group compared to brain training alone after 16 weeks (Week 16)?
# <0.001
# 64
# Did community nurse visit plus twice-daily SMS med reminders and sexual-health messages improve rate of positive gonorrhea or chlamydia tests in young women (13–21) diagnosed with PID compared to enhanced standard care after 90 days?
# 0.07
# 260
# Did using the All About Me tablet games (Fun Facts + Survey Says) improve constructive engagement (doing or commenting on the activity) in people with dementia who used the All About Me app compared to standard activities at baseline after 10 weeks (baseline Wk1–4 vs treatment Wk5–10)?
# <0.01
# 21
# Did adding mindfulness training with home practice to diabetes education improve diabetes-related distress (PAID score) in Veterans receiving DSME plus mindfulness training compared to Veterans receiving DSME alone (usual care) after 12 and 24 weeks?
# 0.153
# 132
# Did using a mobile VR police-safety module improve police interaction assessment scores in adolescents and adults with autism (ASD) compared to video-based BE SAFE training after about 2 weeks?
# 0.23
# 47
# Did group dance exergaming (Xbox Kinect) 60 min, 3×/week for 12 weeks improve visceral fat (measured by MRI) in adolescent girls in the exergame group compared to no-contact control (self-directed care) after 13 weeks (baseline to final visit)?
# 0.05
# 33
# Did frequent hand washing and cough/sneeze hygiene improve days off from work due to own respiratory or gastrointestinal infections in office workers taught better hand-hygiene compared to office workers with usual hand-hygiene after 16 months?
# 0.004
# 481
# Did worksite environmental changes to promote healthy eating, activity, and weight monitoring improve body mass index (BMI) in employees at intervention worksites compared to employees at control worksites after 24 months?
# 0.36
# 1322
# Did adding a Life Care Specialist (LCS) who provides opioid education, behavioral pain coaching, naloxone education and referrals improve average pain (NRS) score in orthopaedic trauma patients compared to standard pain care after 3 months?
# 0.035
# 129
# Did entering family history into an online tool with decision support for patient and doctor improve getting guideline-recommended colorectal cancer screening referral (risk-appropriate) in patients who completed the tool at enrollment (immediate group) compared to patients who completed the tool 12 months later (delayed/wait-list) after 12 months?
# 0.16
# 505
# Did a reminder phone call one week before the appointment improve attendance at clinic appointments in asthma outpatients compared to no reminder (usual care) after 1 week?
# 0.004
# 362
# Did upregulating the left amygdala with real-time fMRI neurofeedback (thinking of positive memories) improve depressive symptoms (MADRS score) in MDD patients receiving left amygdala neurofeedback compared to MDD patients receiving HIPS (non-emotional region) neurofeedback after 2 weeks?
# <0.001
# 34
# Did using a web-based decision aid improve agreement with clinicians on the patient's 1-year survival chance (concordance score, CSCS) in surrogate decision makers of patients on prolonged mechanical ventilation compared to usual ICU care after 2-7 days?
# <0.05
# 249
# Did semi-automated breastfeeding-support text messages improve perceived milk supply (H&H Lactation Scale score) in first-time mothers planning to breastfeed exclusively or nearly exclusively compared to Text4Baby general support text messages after 8 weeks postpartum?
# 0.272
# 191
# Did screening, testing, hepatitis A and B vaccination, risk-reduction counseling, and referrals improve hepatitis A and B immunization in people with both a mental disorder and a substance abuse disorder compared to enhanced usual care (education and referral for testing and vaccines) after 6 months?
# <0.001
# 182
# Did adding medication decision-making and coordinated med management to behavioral support improve ADHD symptoms and related problems (delinquency, substance use, internalizing/externalizing) in adolescents with ADHD compared to behavioral-only treatment (CASH-AA) after one year?
# 0.05
# 145
# Did IPS supported employment in primary care improve steady worker status (≥50% of weeks in a competitive job) in unemployed Veterans in primary care (PACT) with non‑serious mental disorders compared to usual VA vocational rehab/Transitional Work (TAU‑VR) after 12 months?
# 0.02
# 119
# Did single-session life-steps adherence training improve glucose monitoring adherence in people with type 2 diabetes and depression compared to multiple-session CBT for adherence and depression after 4 months?
# <0.0001
# 87
# Did a group-based 2-hour HIV prevention session improve safer sexual behavior (fewer reports of any unprotected anal or vaginal sex in past 90 days) in African American heterosexual men compared to a group cancer screening/prevention education session after six months?
# 0.04
# 650
# Did onsite collaborative care (obstetrician + care manager; local training and hands-on help to start OUD treatment) improve treatment engagement (baseline assessment + >2 OUD treatment visits) in pregnant and postpartum women with opioid use disorder compared to remote ECHO telesupport (video mentoring for providers) after 30 days from baseline?
# 0.534
# 343
# Did access to behavioral-health patient navigators alongside consistent usual care improve ED-to-inpatient admission rate after a behavioral health consult in ED patients compared to usual care after 5 days?
# 0.06
# 637
# Did wearing a UV dosimeter sticker and receiving daily personalized text messages based on sensor readings improve acceptability of wearing the UV sensor and receiving texts (system usability score, 6–42; higher better) in melanoma survivors in Cohort Study 1 Arm 1 (n=31) compared to melanoma survivors in Cohort Study 1 Arm 2 (n=29; daily texts + unstructured goal responses) after 21 days?
# <0.01
# 102
# Did daily self-weighing plus small diet/exercise changes improve weight maintenance (mean weight change from baseline) in young adults (18-35) in the small-changes self-regulation group compared to control (self-guided behavior changes) after 3 years?
# <0.05
# 402
# Did adding a peer (consumer) provider to intensive case management teams improve psychiatric symptoms (BASIS-R) in MHICM patients with a consumer provider compared to MHICM patients with usual care after 12 months?
# 0.5
# 238
# Did abstinence-only sex education improve abstinence (not starting sex) in young African-American adolescents compared to health-promotion control after 24 months?
# 0.03
# 183
# Did eating a protein-enriched bar before meals improve average blood sugar (HbA1c) in patients with type 2 diabetes receiving the premeal protein bar plus diet education compared to diabetes diet education alone after 12 weeks?
# 0.933
# 40
# Did a sex-positive interactive sexual health mobile app improve condom use (less condomless anal or vaginal sex) in young Black men ages 14-19 attracted to men compared to a general health website after 3 months?
# 0.94
# 148
# Did remote ESDM-informed parent coaching (telehealth) improve caregiver use of ESDM strategies (P-ESDM fidelity score) in children with autism and ADHD and their caregivers compared to baseline (pre-intervention) after Week 9?
# 0.0047
# 24
# Did MBCT-S (mindfulness + safety planning) improve rates of suicide events (attempts, preparatory acts, or ideation needing ED/hospital care) in high-risk Veterans compared to TAU (VA standard care) after 12 months?
# 0.015
# 135
# Did daily naltrexone SR 16 mg + bupropion SR 360 mg improve percent weight change in overweight/obese adults compared to placebo after 56 weeks?
# <0.001
# 982
# Did a 2-step transitional care program (SNF planning + nurse home visit within 24h) improve preparedness for discharge (Care Transitions Measure-15 score) in seriously ill SNF patients discharged to home compared to usual SNF discharge planning (no structured home visit) after 7 days?
# 0.62
# 283
# Did starting methadone in jail plus a patient navigator after release improve opioid-positive urine tests in jail inmates who started methadone and got a patient navigator compared to jail inmates who started methadone only after 1, 3, 6, and 12 months after release?
# 0.32
# 197
# Did a voice-activated smart speaker CBT-I program improve insomnia symptoms (ISI score) in breast cancer survivors using the smart-speaker program compared to a website with CBT-I info after 6 weeks?
# <0.05
# 70
# Did implementation facilitation (helping HIV clinics adopt addiction treatments) improve provision of addiction treatments (medications or counseling) in patients with opioid use disorder (OUD) compared to usual care (pre-implementation) after 6 months?
# 0.55
# 277
# Did automated calls/texts/email + hospital tobacco coach with 8 weeks free NRT (TTCM) improve biochemically confirmed tobacco abstinence (7-day no tobacco, saliva or breath test) in hospitalized adult smokers planning to quit after discharge compared to eReferral to the state Quitline (QL) after 6 months?
# 0.19
# 1409
# Did a tablet system that sends daily pain reports to nurses, gives nurse decision-support, and offers tailored multimedia education improve analgesic adherence (percent of prescribed pain meds taken) in home hospice cancer patients and their lay caregivers compared to usual hospice care after 1 week (average daily adherence, days 1–7)?
# 0.43
# 234
# Did AF decision support recommendations for blood thinners improve alignment between patients' blood-thinner treatment and the tool's recommendation in patients whose doctors received education plus decision support compared to patients whose doctors received education only after one year?
# 0.02
# 801
# Did pentoxifylline (anti-inflammatory) plus CBT improve blood vessel function (brachial flow-mediated dilation, FMD) in older adults with depression (no heart disease) compared to placebo plus CBT after 12 weeks?
# 0.474
# 8
# Did a web-based media-literacy sexual and relationship health program improve relationship satisfaction in community college students (ages 18-19) compared to a wait-list control (no program until after study) after 4 weeks?
# 0.983
# 465
# Did in-person dementia care management improve caregiver burden (Zarit score) in caregivers of people with dementia in underserved communities compared to telephone-only dementia care management after 6 and 12 months?
# 0.76
# 144
# Did a 4-week digital breathing and emotion-regulation program to reduce drinking improve drinks per week in risky drinkers with emotional stress compared to Unknown after post-intervention and 30-day follow-up?
# <0.001
# 27
# Did health coaching (coach visits, community resources, interactive text messages) improve BMI z-score (age-adjusted BMI) in overweight children and parents receiving health coaching compared to enhanced primary care (best-practice care with EHR alerts, clinician tools, and resources) after one year?
# 0.3928
# 721
# Did mnemonic strategy training (memory strategies) improve memory for trained object-location associations (percent correct) in people with mild cognitive impairment (MCI) compared to spaced retrieval training after up to 1 month?
# <0.001
# 57
# Did taking 600 mg/day mifepristone improve drinking (fewer standard drinks/day) in people with alcohol use disorder compared to placebo after 12 weeks?
# 0.51
# 103
# Did phone/video psychoeducation and relaxation for caregivers (fPER) improve patients' quality of life (FACT-BMT score) in allogeneic HSCT patients whose caregivers received fPER compared to those whose caregivers received usual care (TAU) after 6 months post-transplant?
# 0.96
# 139
# Did practicing resisting cigarettes when craving improve self-control (change in hand-grip hold time) in adult smokers not trying to quit compared to practicing good posture after one week?
# 0.503
# 69
# Did adaptive interpersonal therapy (IPT-A) with stepping up to extra sessions or adding an SSRI if needed improve depressive symptoms (CDRS-R score; higher = worse) in adolescents with depression receiving the IPT-A adaptive strategy compared to usual care (therapists' usual therapy, may change session frequency or start SSRI) after 16 weeks?
# 0.76
# 90
# Did a very-low-calorie diet (VLCD) improve striatal dopamine D2 receptor binding (DRD2 binding potential) in obese participants after the diet compared to the same obese participants at baseline after 8–10 days on the VLCD?
# <0.05
# 33
# Did the 12-session SEI curriculum improve pregnancy risk (recent sex without birth control or condoms) in SEI classroom students compared to 3-session control classroom students after 1 year?
# 0.643
# 1447
# Did retrained-provider intrapartum testing and intensive postpartum counseling improve postpartum contraceptive use in women receiving retrained-provider testing and counseling compared to women receiving usual-provider testing and counseling after 12 months?
# <0.05
# 697
# Did access to mobile games improve percent change in average cigarettes smoked per day from baseline in smokers using nicotine patch and brief counseling with mobile games compared to smokers using nicotine patch and brief counseling without mobile games after the first 4 weeks of the quit attempt?
# 0.85
# 30
# Did financial incentives for buprenorphine use improve buprenorphine adherence (% buprenorphine-positive urine tests) in adults with opioid use disorder in the incentives-for-use group compared to no incentives (control) after 12 weeks?
# 0.22
# 252
# Did a structured sleep program (behavioral strategies, then melatonin if needed) improve nightly sleep duration (minutes, actigraphy) in children with ADHD in the immediate-treatment group compared to delayed-treatment (no treatment first 5 weeks) after week 5?
# <0.05
# 8
# Did home-based program to replace sugary drinks with filtered tap water (weekly home visits + water filter) improve parents' sugary drink intake (ounces/day) in low-income parents with children aged 6 months–3 years compared to standard home-visiting curriculum plus a water filter pitcher after 12 weeks (measured 12–16 weeks after start)?
# 0.15
# 92
# Did a 3-session online program teaching healthy relationship skills improve rates of physical dating violence perpetration in high-school students at risk for dating violence compared to a 3-session online healthy-lifestyle program (physical activity, screen time, healthy eating) after one year?
# <0.0001
# 2605
# Did adding 8 coaching sessions to a Fitbit improve minutes of moderate-to-vigorous physical activity (MVPA) in young adults with congenital heart disease compared to Fitbit only after baseline to follow-up (≈22 weeks)?
# 0.023
# 30
# Did taking 600mg zonisamide (ZNS) improve VAQ score (subjective cocaine effects & craving) in 20mg cocaine + 600mg zonisamide compared to 20mg cocaine + no zonisamide (0mg) after Weeks 1-5 (mean of weeks 1, 3 & 5)?
# <0.01
# 72
# Did mailed decision aids plus nurse health-coach calls improve monthly total medical costs (total paid for covered services) in patients with knee, hip or herniated disc compared to no condition-specific outreach (control) after 6 months?
# 0.9602
# 5858
# Did four coaching sessions to support CGM use improve blood sugar control (hemoglobin A1c) in adults with type 1 diabetes not using CGM regularly compared to CGM supplies only (no coaching) after 3, 6, and 12 months?
# 0.8875
# 110
# Did VR street-crossing training improve street-crossing safety (average hits/close calls per 30 virtual crossings) in children trained in a virtual pedestrian environment compared to streetside one-on-one training after post-training and at 6 months?
# <0.05
# 211
# Did protective step training (repeated-slip perturbation training) improve protective stepping (margin of stability) in people with MS in the step-training group compared to Unknown after the 2-week training (baseline to post-test)?
# 0.036
# 27
# Did interactive pain-management video + nurse telecare call + PCP notification improve pain severity and interference (combined BPI-SF score) in older adults with acute musculoskeletal pain compared to usual care after 1 to 6 months?
# 0.13
# 314
# Did computerized brain-training exercises improve auditory memory and attention (Auditory Memory Attention Index) in people with mild cognitive impairment (MCI) compared to control computerized cognitive exercises after 13 weeks?
# <0.01
# 113
# Did internet CBT-I (self-guided program) improve hsCRP level (blood inflammation marker) in virologically-suppressed HIV+ adults with insomnia compared to sleep education/hygiene (education calls) after 24 weeks?
# 0.607
# 21
# Did brief behavioral insomnia treatment (BBTI: 4 sessions, in-person + phone) improve insomnia severity (Insomnia Severity Index) in Veterans with chronic insomnia receiving BBTI compared to Veterans receiving standard CBT for insomnia (CBTI: 5 in-person sessions) after post-treatment (BBTI week 5; CBTI weeks 6–9)?
# <0.05
# 39
# Did integrated HIV care centers (one-stop prevention + treatment) improve HIV testing in the past 12 months in high-risk adults (people who inject drugs or men who have sex with men) compared to standard care (usual government/NGO HIV services) after 2 years?
# 0.09
# 21726
# Did social cognition training with real-world (in vivo) exercises improve emotion processing (MSCEIT score) in participants receiving social cognition training with in-vivo augmentation compared to participants receiving social cognition training without in-vivo exercises after 3 months?
# <0.05
# 135
# Did sharing/comparing steps and group chat on WeChat improve average weekly steps (WeRun) in community-dwelling older adults in a WeChat group compared to participants only tracking their own steps on WeChat after 4 and 8 weeks?
# 0.02
# 56
# Did online SDM training with patient narratives improve stigma toward people with opioid use disorder (Difference, Disdain, Blame scores) in primary care clinicians (PCCs) compared to PCCs receiving SDM training only after completion of the online training?
# 0.63
# 85
# Did peer-to-peer parent navigation (support from an experienced parent navigator) improve parents' confidence in caring for their baby (parental self-efficacy) in parents of NICU graduates who got parent navigation + care notebook compared to parents who got a care notebook alone after NICU discharge (12 months)?
# 0.73
# 238
# Did individual coached online CBT (iCBT) improve depression severity (PHQ-9 score) in depressed older adults compared to Unknown after 8 weeks?
# <0.001
# 9
# Did a social exergame with in-app social features improve percent change in steps in family caregivers compared to the non-social exergame (same app without social features) after baseline to weeks 3-8?
# 0.49
# 64
# Did metformin plus lifestyle weight-management program improve body weight (lbs) in postmenopausal participants receiving metformin + lifestyle compared to placebo + lifestyle after 4 months?
# 0.006
# 12
# Did digital CBT-I (online Sleepio programme) improve sleep quality (Sleep Condition Indicator score) in chronic stroke survivors compared to a sleep-hygiene advice leaflet after 8 weeks?
# <0.021
# 84
# Did phone PA coaching with wrist monitor improve weekly MVPA minutes (accelerometer) in patients ≥65 with hip/knee osteoarthritis compared to OA education attention-control calls after 6 months?
# 0.3086
# 164
# Did suppressing sex hormones with monthly GnRH agonist injections improve resting energy expenditure (REE) in women receiving GnRH agonist + placebo compared to women receiving GnRH agonist + estradiol (E2) after 5 months?
# <0.05
# 48
# Did brief alcohol counseling (2 clinic sessions + 2 phone calls) improve drinking days out of the past 90 days (how often they drank) in HIV+ women who binge or hazardously drink compared to standard care after 1 year follow-up?
# <0.005
# 148
# Did doing a 5-min evaluative speech (stress task) improve cell-free mitochondrial DNA in blood in healthy adults during the speech stress session compared to quiet rest (control session) after up to 120 minutes (measured 5 min before to 120 min after the task)?
# 0.86
# 124
# Did paroxetine (SSRI) plus prolonged exposure therapy improve PTSD severity (CAPS score) in WTC attack survivors with PTSD receiving paroxetine + exposure therapy compared to placebo pill plus prolonged exposure therapy after 10 weeks?
# 0.01
# 37
# Did joining a virtual collaborative (webinars, teleconferences, coaching) plus the tool kit improve CLABSI and VAP rates (central line- and ventilator-associated infections per 1,000 device-days) in ICUs in Collaborative hospitals compared to ICUs in Tool Kit-only hospitals after 18 months?
# <0.05
# 59
# Did video-chat social conversations (30 min, 4×/week) improve global cognitive function (MoCA total score) in socially isolated adults 75+ compared to weekly 10-min phone-call monitoring (control) after 6 months (baseline to month 6)?
# 0.87
# 66
# Did two 45–60 minute motivational interviewing (MI) sessions improve weight in people in a behavioural weight-loss program (BWLP) compared to two 45–60 minute attention-control interviews after 12 weeks (end of program)?
# >0.05
# 129
# Did a 2‑hour group workshop teaching coping and communication skills improve maladaptive communication strategies (CPHI; less use = better) in veterans in the workshop + hearing aids compared to veterans with standard hearing‑aid care after 8 weeks?
# 0.69
# 115
# Did video counseling for quitting smoking improve smoking abstinence (verified by salivary cotinine) in women with HIV (video arm) compared to women with HIV (telephone arm) after 6 months?
# <0.05
# 42
# Did 4 h/week intense exercise (2 strength + 2 spinning interval sessions) improve insulin sensitivity (glucose infusion rate from euglycemic hyperinsulinemic clamp) in overweight/dysglycemic adults compared to no-exercise control after 12 weeks?
# <0.05
# 11
# Did adding peer navigators to a behavioral weight-loss program improve weight loss (pounds) in African Americans with serious mental illness receiving BWLI plus peer navigators compared to BWLI alone after 12 months?
# 0.025
# 90
# Did phone counseling and medicine management by a clinical pharmacist improve 10-year heart disease risk (Framingham Risk %) in veterans with cardiovascular disease compared to educational materials about CVD reduction after 6 months?
# 0.1
# 375
# Did gentle hands-on energy therapy improve high pain (pain 6–10 on 0–10 numeric rating scale) in post-cesarean women compared to 15 min quiet time after the session (immediately after)?
# 0.019
# 129
# Did CBT to help Veterans adjust to CPAP improve CPAP use (minutes per night) in Veterans with PTSD and obstructive sleep apnea compared to sleep education after the final 30 days of the 1-year study?
# 0.027
# 49
# Did providing financial incentives for verified smoking abstinence improve 7-day smoking abstinence (no smoking in past 7 days, verified by urine cotinine) in pregnant Medicaid recipients receiving best practices plus financial incentives compared to pregnant Medicaid recipients receiving best practices alone after about 28 weeks' gestation?
# <0.001
# 169
# Did online CBT for weight-related bullying improve traumatic stress (CRIES total score) in adolescents (11-17) who experienced weight-related bullying compared to Control after 3 months?
# 0.047
# 22
# Did a brief 4-session family suicide safety planning program improve suicidal thoughts (C-SSRS score) in Veterans at moderate suicide risk compared to safety planning alone with weekly check-in calls after post-treatment assessment (mean 2.8 months)?
# 0.03
# 30
# Did extended spinal manipulative therapy (extra SMT sessions in weeks 2–4) improve spinal stiffness (stiffness measured by VerteTrack) in patients given extra SMT (weeks 2–4) compared to patients with no extra SMT after 4 and 12 weeks?
# 0.025
# 99
# Did telephone coaching plus a web-based family-training program improve veterans' engagement in mental health care in family members of veterans (coaching group) compared to treatment as usual after up to 1 year?
# >0.05
# 52
# Did providing a geriatric assessment (GA) summary and recommendations improve discussions about age-related concerns during clinic visits in older cancer patients and their caregivers compared to usual care (GA completed, no summary or recommendations) after the first clinic visit (baseline)?
# <0.0001
# 528
# Did using the MACS mobile after-care support app (prompts treatment adherence and active coping) improve treatment satisfaction (Client Satisfaction Questionnaire score) in participants using the MACS app compared to participants using an attention-control mobile app with assessment and psychoeducation after 1 month?
# >0.05
# 22
# Did using a nicotine patch before quit day improve 7-day point-prevalence abstinence (no smoking in past 7 days, self-reported) in people given a pre-quit nicotine patch compared to people given no pre-quit nicotine patch after 16 weeks post-quit?
# 0.341
# 637
# Did D-cycloserine (DCS) with CBT improve OCD symptoms (CY-BOCS) in youth with OCD receiving CBT + DCS compared to CBT + placebo after post-treatment?
# <0.05
# 30
# Did in-person ACT sessions improve pain interference in veterans with chronic pain compared to telehealth ACT after 8 weeks?
# 0.12
# 126
# Did computer-assisted cognitive rehab (home training + 8‑week group strategy/lifestyle sessions) improve verbal memory (words recalled on CVLT‑II) in people with MS in MAPSS‑MS compared to usual care + referral to My Brain Games (online computer games) after 6 months post-intervention?
# 0.926
# 183
# Did board-game training for resuscitation teamwork improve teamwork performance (Team Performance Observation Tool score) in PGY doctors and nurses compared to simulation-based training after 4 weeks?
# <0.05
# 64
# Did an emotional story about a child needing a bone marrow transplant improve intention to join the bone marrow donor registry (likelihood to register) in college students shown an emotional appeal compared to students shown a rational, data-based appeal about registry diversity after post-intervention (immediately after)?
# 0.001
# 361
# Did monthly $500 housing stipends and social work help to find permanent housing improve being housed (housed vs homeless) in people with OUD experiencing homelessness on MOUD compared to Unknown after 12 months?
# 0.125
# 5
# Did OneSheet (EHR dashboard that aggregates chronic-pain info for PCPs) improve documentation of pain and function goals in PCPs (primary care providers) compared to PCPs doing usual care (no OneSheet) after 18 months?
# <0.05
# 135
# Did CBT for insomnia by video (telehealth CBT-I) improve insomnia symptoms (Insomnia Severity Index score) in Veterans with PTSD and chronic insomnia compared to in-person CBT-I after 3 months?
# 0.138
# 48
# Did a clinically supervised ketogenic diet (inducing dietary ketosis) improve cognitive function (MoCA score) in people with selective memory complaints (SMC) or mild cognitive impairment (MCI) and metabolic syndrome compared to their usual diet (standard American diet, SAD) after 12 weeks?
# <0.0001
# 98
# Did nurse-led mobile-van ART delivery (DTP) improve staying in care and viral suppression (HIV <50 copies/mL) in female sex workers living with HIV in Durban compared to peer case-manager support (ICM) after 18 months?
# 0.455
# 777
# Did completing missing-letter words to form non-hostile words improve hostile attribution bias in HBMT participants compared to placebo training participants after 24–96 hours?
# <0.001
# 217
# Did 8-week nicotine patch plus brief in-person counseling and quitline/app support improve smoking abstinence (biochemically confirmed, exhaled CO <6 ppm) in smokers in primary care compared to Unknown after 6 months?
# <0.001
# 315
# Did education and monthly reminders to do skin self-exams (SSE) improve completing skin self-exams (SSE) in women who received an SSE brochure, goal-setting, and reminders compared to women who received a healthy‑living brochure, goal-setting, and reminders after 90 days?
# <0.001
# 989
# Did parents using the FITSTART+ app (personalized norms + alcohol-specific tips) improve typical drinks per week (change from baseline) in first-year students whose parents used the FITSTART+ app compared to first-year students whose parents used a general parenting app after 1 month?
# 0.985
# 217
# Did a stroke self-management and risk-factor program with peer support improve stroke-specific quality of life (SSQoL) in veterans with stroke/TIA compared to staff phone calls (attention control) after 6 months?
# 0.69
# 139
# Did parent-run breathalyzer checks with incentives and parent management training improve alcohol abstinence (measured by ETG-positive urine tests) in adolescents receiving MET/CBT plus family-based CM compared to adolescents receiving MET/CBT alone after 14 weeks (weekly testing)?
# 0.66
# 75
# Did customized adherence support with a long-acting injectable (LAI) antipsychotic improve medication adherence (TRQ: % of prescribed meds missed) in people with schizophrenia at risk for treatment non-adherence and homelessness compared to Unknown after 25 weeks?
# 0.012
# 16
# Did a bus-stop poster calling AMR 'Superbugs' improve attitudes about antimicrobial resistance (survey sentiment score) in people who saw that poster compared to people who saw a poster labeled 'Antimicrobial resistance (AMR)' after 6 weeks?
# 0.017
# 3241
# Did a one-page individualized feedback form for patient and clinician to prompt end-of-life talks improve quality of end-of-life communication (QOC score) in patients with moderate or severe COPD compared to usual care (no feedback form) after 2 weeks after the clinic visit?
# 0.03
# 376
# Did parent training in handling, positioning, and play improve motor development (AIMS percentile change) in preterm infants whose parents received that training compared to preterm infants whose parents received milestone education (CDC/AAP info) after 1 month?
# 0.016
# 20
# Did home visits training caregivers to manage pain and dementia-related problems improve aggression (agitated behaviors) in veterans with dementia whose caregivers received these home visits compared to veterans with dementia whose caregivers got mailed info and brief phone calls after 3, 6, and 12 months post-intervention?
# 0.13
# 203
# Did NMR-guided selection of smoking medication improve 7-day tobacco abstinence (biochemically confirmed) in hospitalized smokers (MIST) compared to guideline-based care after 6 months?
# 0.461
# 601
# Did aerobic exercise (walking 3x/week at target HR) improve aerobic fitness (VO2max) in completers compared to before training (baseline) after 6 months?
# <0.001
# 49
# Did a 4-session group self-management program for sleep apnea improve CPAP use (adherence) in people with OSA on CPAP compared to usual care after 1 month?
# 0.001
# 190
# Did Comfort Talk training for MRI staff improve MRI completion rate (proportion of scheduled scans completed) in three OSU MRI sites with Comfort Talk training compared to three OSU MRI sites without training (control) after one quarter?
# <0.0001
# 6847
# Did home-based exercise with tele-rehab coaching (LTGO) improve average steps per day (change from baseline) in lung transplant recipients compared to enhanced usual care (newsletters + self-monitoring device) after 3 months?
# 0.8793
# 88
# Did a weekly prize-draw incentive for walking/cycling to school improve minutes of moderate-to-vigorous physical activity (MVPA) during parent-reported school-journey times in Year 5 pupils (9–10 y) in the incentive schools compared to Year 5 pupils in schools receiving usual curricular active-travel advice after 9 weeks (1-week baseline + 8-week intervention)?
# 0.02
# 31
# Did coparenting breastfeeding support (in-hospital visit, workbook, video, website, follow-up emails/calls) improve exclusive breastfeeding (only breast milk) in first-time breastfeeding mothers and their partners compared to standard postpartum care (usual care) after 12 weeks postpartum?
# 0.27
# 209
# Did 8 mindfulness sessions over 4 weeks improve salivary cortisol response to a social stress test (stress hormone reactivity) in adolescents receiving mindfulness training compared to treatment-as-usual control after 6–8 weeks from baseline?
# <0.05
# 38
# Did weekly community yoga classes with home practice improve retention (proportion completing the 10-week study) in women with stage I-III breast cancer undergoing chemotherapy compared to weekly wellness education group (active control) after 10 weeks?
# 0.53
# 40
# Did teaching mothers parenting skills to increase infant nighttime sleep and reduce crying improve maternal depression (clinician-rated Hamilton Depression Rating Scale) in pregnant women at risk for postpartum depression compared to Control after 6 weeks postpartum?
# 0.01
# 22
# Did brisk walking improve aerobic capacity (VO2max) in Veterans with schizophrenia or schizoaffective disorder compared to non-aerobic stretching after 12 weeks?
# 0.02
# 40
# Did no background changes (fixed backgrounds) improve ability to tell if the central object moved left or right (horizontal discrimination threshold; lower = better) in Noise Level 0 (no background changes) compared to Noise Level 1 (random background rotation) after about 3 weeks?
# 0.024356
# 20
# Did a VR pain education session improve pain beliefs (pain beliefs questionnaire score) in middle school students compared to Unknown after about 45 minutes (immediately post-intervention)?
# 0.137
# 20
# Did taking varenicline pills plus weekly counseling and text support improve stopping vaping for 4 continuous weeks at end of treatment (saliva cotinine <30 ng/ml) in adolescents who vape and want to quit (age 16–25) compared to placebo pills plus the same weekly counseling and text support after weeks 9–12 (end of 12-week treatment)?
# <0.001
# 175
# Did a personalized medication calendar with pharmacist instruction improve how consistently they refilled/get meds (medication possession ratio, MPR) in patients on BP, diabetes, cholesterol, or heart meds compared to Control after 6 months?
# 0.73
# 23
# Did naltrexone + bupropion pills (plus diet/behavior/exercise counseling) improve body weight (mean % change) in obese adults with type 2 diabetes compared to placebo (plus diet/behavior/exercise counseling) after 56 weeks?
# <0.001
# 424
# Did self-directed online caregiver training with phone coaching and secure portal messaging improve caregiver burden in caregivers of people with dementia (STAR-VTF) compared to attention control (mailed materials, web links, generic portal messages) after 6 months?
# 0.97
# 67
# Did teaching mothers ASL signs for hunger and satiety improve infant weight-for-length z score in mother–infant pairs (responsive feeding training) compared to routine care (no intervention) after 6 months post-baseline?
# 0.07
# 54
# Did yoga (postures + breathing/meditation) improve insomnia (Insomnia Severity Index) in cancer survivors compared to CBT-I (cognitive behavioral therapy for insomnia) after 4–8 weeks (post-intervention)?
# <0.0001
# 365
# Did adding LHW outreach (video group sessions + follow-up) to weekly SMS improve how sure they felt about deciding to get a COVID-19 test (decisional conflict score) in Asian American participants in INFORMED (LHW outreach + SMS) compared to participants getting weekly SMS only after week 16?
# 0.4471
# 232
# Did a waiting-room rPlan app plus brief motivational counseling improve frequency of using condoms with another contraceptive (dual protection) in clinic patients receiving rPlan compared to their baseline (before rPlan) after 3 months?
# 0.177
# 71
# Did a tablet app letting people with dementia lead group activities improve constructive engagement (doing or commenting on the activity) in people with dementia who led tablet-based activities compared to standard activity programming after treatment (Months 2–4 vs baseline Month 1)?
# <0.01
# 84
# Did focused outreach to healthcare workers improve returning saliva COVID-19 test kits (completing testing) in healthcare workers compared to community organization-led outreach after 1 year?
# <0.05
# 1100
# Did weekly interviewer review of recorded data improve adherence to twice-daily symptom self-reports (avg. proportion of days with ≥50% completed) in participants receiving weekly interviewer review compared to participants with no weekly review after 6 weeks?
# 0.99
# 47
# Did mixed professional home visiting improve cognitive ability (IQ) scores in MOM Program children compared to control group after 8 years?
# 0.39
# 187
# Did park prescription + pedometry improve stress (PSS-10) in families given park prescription only compared to park prescription + 3 weekly family outings and case management after 3 months?
# 0.6099
# 65
# Did remote intensive lifestyle treatment improve weight (kg) in all reporting groups compared to baseline after 6 months (Baseline to Month 6)?
# <0.001
# 562
# Did adding cognitive behavioral therapy (CBT) to medication improve ADHD symptoms reported by teens (ADHD Rating Scale-IV) in adolescents receiving CBT plus medication compared to adolescents receiving medication alone (wait-list control) after 4 months?
# <0.0001
# 58
# Did wearing a Fitbit and using its smartphone app improve body mass index (BMI) in overweight/obese adolescents compared to adolescents given a pedometer and food diary after 6 months?
# <0.001
# 40
# Did 6-week cognitive behavioral therapy (CBT) for tinnitus improve tinnitus handicap/distress (THI score) in veterans with chronic bothersome tinnitus from noise exposure compared to tinnitus education (ED) after ~6 weeks (pre- to post-treatment)?
# <0.05
# 20
# Did 8 sessions of interpersonal psychotherapy (IPT) improve depression severity (HRSD-17 score) in people with depression compared to 8 sessions of cognitive behavioral therapy (CBT) after 12 weeks?
# 0.752
# 58
# Did brief mindfulness training (IBMT) improve brain activity in the self-control region (anterior cingulate cortex) in people with polysubstance use compared to progressive muscle relaxation (RT) after 2 weeks?
# 0.03
# 58
# Did weekly hypnotherapy (self-hypnosis) improve UUI episodes in women with urgency urinary incontinence compared to anticholinergic medication (tolterodine or ER oxybutynin) after 2 months?
# <0.025
# 142
# Did an 8-week online bone-health program (web modules, forums, expert Q&A, library, toolkit and videos) improve osteoporosis knowledge; confidence (self-efficacy) and outcome expectations for calcium and exercise; and calcium intake and exercise behavior in TO-BoneHealth participants compared to control (no intervention) after 8 weeks?
# <0.001
# 705
# Did EX/RP therapy (CBT that exposes patients to feared situations and prevents rituals) improve brain activity during conflict resolution (fMRI BOLD; Incongruent vs Congruent trials) in children/adolescents with OCD compared to healthy control participants after baseline (single time point)?
# 0.0585
# 50
# Did adding practice-based population-health support to an online weight-loss program improve weight loss (change in body weight) in patients using the online program plus population-health support compared to usual care (mailed general weight info) after 12 months?
# 0.00017
# 840
# Did a tailored interactive text-message resilience program improve resilience (CD-RISC score) in hereditary cancer previvors in the pilot compared to Control after 1 month?
# 0.029
# 134
# Did online positive-affect skills training improve study retention (percent completing post-intervention) in adults with fibromyalgia (FMS) compared to daily emotion reporting (attention control) after week 11 (post-intervention)?
# 0.684
# 95
# Did computerized CBT (8 weekly sessions) improve brachial FMD (blood-vessel function) in depressed primary-care patients without heart disease compared to usual care (informed and encouraged to follow up with PCP) after 12 weeks?
# 0.21
# 21
# Did a pedometer plus web-based walking program (feedback, goals, education) improve 6-minute walk distance (exercise capacity) in adults with COPD compared to usual care (verbal and written exercise advice) after 6 months?
# 0.189
# 153
# Did pairing Mexican immigrants with undergraduate student advocates for learning circles and community advocacy improve depression and anxiety symptoms (Hopkins Symptom Checklist-25 score; lower = better) in IWP participants (Mexican immigrants) compared to Unknown after 14 months?
# 0.019
# 39
# Did strength training (leg-focused resistance exercises) improve maximal walking distance in patients with intermittent claudication (leg pain from PAD) compared to treadmill walking training after 12 weeks?
# <0.05
# 30
# Did walking with poles improve exercise duration on a treadmill test in people with poor leg circulation (PAD/PVD) compared to traditional walking after 24 weeks?
# 0.033
# 97
# Did supervised aerobic exercise improve anxiety (HADS-Anxiety score) in patients with coronary heart disease (CHD) and elevated anxiety compared to placebo medication after 3 months?
# 0.038
# 128
# Did home-based problem-solving therapy (PST) improve targeted vision function (less difficulty with important vision tasks; TVF) in people with age-related macular degeneration compared to home-based supportive therapy (ST) after 3 months?
# 0.47
# 218
# Did group training to teach youth to identify and fix environmental barriers to participation (8 sessions, 2 field trips, peer mentors) improve goal attainment for personal participation and related skills (Goal Attainment Scaling) in youth with developmental disabilities ages 14-21 compared to matched controls receiving usual services and a stipend to try a community activity after 12 weeks after intake?
# 0.05
# 77
# Did a simple email highlighting one benefit improve opening the email in patients who started myGeisinger enrollment (Less-is-better email) compared to the standard activation email (Control) after 8–10 days?
# 0.0248
# 8501
# Did chaplain-led dignity therapy (three guided reflection sessions) improve dignity impact (Dignity Impact Scale score) in outpatient palliative care patients compared to usual outpatient palliative care (standard care) after 5 weeks?
# 0.02
# 450
# Did adding behavior therapy to atomoxetine improve classroom rule violations in children with ADHD compared to atomoxetine alone after 8 weeks?
# <0.05
# 56
# Did distancing training improve negative affect (self-reported 1–4; lower=better) in recently bereaved spouses compared to reinterpretation training after sessions 1–5 over two weeks?
# 0.053
# 61
# ...
# <0.001
# 94
# Did brief cognitive-behavioral therapy (12 weekly/biweekly sessions) improve percent making a suicide attempt in active-duty military personnel with suicidality compared to treatment as usual (TAU) after 24 months?
# 0.02
# 152
# Did parent-child therapy focused on feeding, mealtimes, and screen time improve child BMI percentile (age- and sex-adjusted BMI ranking) in children whose parents got that therapy compared to children on a wait-list (no intervention during study period) after 4 months?
# 0.73
# 18
# Did web-based bystander training to teach men to intervene improve intervening to stop inappropriate behavior (prosocial intervening behavior) in male college students in the bystander & sexual violence prevention group compared to male college students in the 3‑hr general health promotion web program after 6 months?
# 0.044
# 215
# Did computer-based cognitive training plus individual drug counseling improve days of heavy drinking in older Veterans starting alcohol treatment compared to computer game-play plus individual drug counseling after 3 months?
# <0.05
# 59
# Did group social-cognitive training (recognizing emotions and understanding others) improve facial emotion identification (facial affect perception) in veterans with schizophrenia or schizoaffective disorder compared to skills training (symptom/medication side-effect ID) after 12 weeks?
# <0.001
# 68
# Did adding weekly CBT to paroxetine improve social anxiety symptoms (change in LSAS score) in patients with social anxiety who had partial response to 12 weeks of paroxetine compared to continuing paroxetine alone after 16 weeks (week 12 to week 28)?
# 0.267
# 61
# Did a collaborative depression care team with regular phone follow-up improve depression treatment response (≥50% drop in SCL-20 score) in VA patients with HIV compared to usual care after 6 months?
# 0.003
# 249
# Did sit-less/stand-more coaching (wristband prompts + standing desk) improve time spent sitting/lying (less sitting) in older adults (60+) with obesity compared to healthy-living phone coaching (no sitting focus) after 6 months?
# 0.003
# 246
# Did a 12-week physical activity program with education, individual goal-setting, and activity tracking improve confidence to be physically active (self-efficacy) in young adults receiving chemotherapy compared to usual guidance from oncology providers (attention control) after about 15 weeks (post-study)?
# 0.22
# 44
# Did a standard EHR flu alert improve getting a flu vaccine in patients assigned to the standard alert compared to patients assigned to high-risk EHR alerts (with or without risk factors) after the 1-day visit?
# 0.517
# 72863
# Did small-group coping & support skills training (CAST-T/HSTS) improve self-reported depressive symptoms (SMFQ score) in at-risk 8th graders in the CAST-T/HSTS program compared to at-risk 8th graders receiving a brief one-on-one clinical follow-up (Brief Intervention) after baseline to 18 months?
# <0.05
# 480
# Did team training on roles, communication, and mutual support improve teamwork knowledge (percent correct on a survey) in staff at rural Child Advocacy Centers (CACs) compared to waitlist control (no immediate training) after 3 months (3-month follow-up)?
# 0.03
# 165
# Did generic COVID-19 best-practice training (standard CDC/state guidelines) improve new lab-confirmed COVID-19 cases per 100 person-months (residents & staff) in group homes receiving GBP compared to group homes receiving TBP after 15 months post-baseline?
# 0.89
# 9374
# Did adding atorvastatin to ezetimibe improve percent reduction in LDL ('bad') cholesterol in Japanese adults with high LDL cholesterol compared to ezetimibe alone after 12 weeks?
# <0.001
# 103
# Did giving a brief EHR-informed prompt form to patients/surrogates and clinicians to prompt goals-of-care talks improve documentation of goals-of-care in the medical record in seriously ill hospitalized patients compared to usual hospital care after hospital discharge (~2 weeks)?
# 0.036
# 150
# Did an app adding scheduling, maps, and social features to encourage walking improve daily steps in sedentary older adults compared to a basic step-counting-and-goal app after one month?
# <0.001
# 63
# Did active tDCS + BrainHQ training improve verbal working memory (MCCB letter-number span score) in people getting active tDCS+BrainHQ compared to people getting sham tDCS+BrainHQ after baseline to post-treatment (up to 4 weeks)?
# 0.923
# 11
# Did sending a timely email when lab results are available improve myGeisinger enrollment in patients with a lab result ready to view compared to no email (control) after 1 week?
# <0.001
# 5009
# Did orchidectomy (removal of testicles) for testicular cancer improve phantom testis pain in patients who had orchidectomy for cancer compared to trans women who had male-to-female sex reassignment surgery after 6 months to 5 years post-surgery?
# 0.013
# 109
# Did HEPA air cleaners + phone motivational interviewing for a home smoking ban improve respiratory quality of life (St. George's Respiratory Questionnaire) in smokers with COPD who continued smoking compared to sham air cleaners with smoking cessation counseling only after 6 months?
# 0.025
# 98
# Did mailed shared decision-making sheet and decision coaching improve shared decision-making about colon cancer screening (SDM score) in patients with colonoscopy delayed due to COVID-19 compared to usual care (scheduling calls/texts) after about 8 weeks?
# <0.001
# 243
# Did drug plus behavioral training improve success (off meds/other therapies and ≥70% fewer leakage episodes) in women with urge urinary incontinence compared to drug alone after 8 months?
# 0.74
# 237
# Did in-person nurse-led Listening Visits improve depressive symptoms (IDAS-GD score) in emotionally distressed NICU mothers compared to usual social-worker care after 4 and 8 weeks?
# <0.05
# 37
# Did a $1 PA scratch-off lottery ticket for getting a flu shot improve getting a flu shot at their appointment in Geisinger patients 18+ with an upcoming PCP or specialist appointment during the 2021–22 flu season compared to $1 cash for getting a flu shot after 3 days after randomization?
# 0.506
# 28788
# Did an online weight-loss program (reduced calories + increased activity, weekly group chats) improve the percent achieving ≥5% weight loss in adults with asthma compared to Control after 6 months?
# 0.35
# 43
# Did combined aerobic + resistance exercise improve number of migraine days per month in people with migraine compared to an unknown comparator after 12 and 20 weeks?
# 0.001
# 8
# Did adding virtual job interview practice and coaching (VR-JIT) improve getting a job (employment rate by self-report) in prison offenders in the Vocational Village program compared to usual Vocational Village services after 6 and 12 months post-release?
# 0.15
# 44
# Did 6 CBT sessions to de-couple anxiety and drinking improve number who relapsed to drinking in the de-coupling group compared to the anxiety-reduction group after 4 months?
# 0.673
# 208
# Did adding a 1-week reminder call/email plus an educational poster and brochure about skin self-exams improve performing a skin self-examination in women who received poster, brochure and a 1-week reminder compared to women who received a brochure only after 3 months?
# 0.12
# 420
# Did 4-h sleep (sleep deprivation) improve piriform cortex decoding of food vs non-food odors (fMRI accuracy) in healthy normal-weight adults compared to 8-h sleep (normal sleep) after the evening (~7pm) following the manipulated night?
# 0.001
# 50
# Did behavioral plus nutrition counseling to increase calorie intake improve energy intake (kcal/day) in preschoolers with cystic fibrosis compared to education/attention control after 6 months?
# <0.001
# 78
# Did using e-books improve infant development (Bayley-3 composite scores) in parent-infant dyads given e-books compared to parent-infant dyads given board books after about 1 month post 12-month visit?
# 0.7635
# 80
# Did an interactive web program to reduce drinking improve weekly alcohol intake (lower = better) in hazardous drinkers compared to minimal information (info + alcohol diary) after 6 weeks?
# 0.0279
# 339
# Did group therapy to reduce antisocial thinking (MRT) improve criminal thinking (risk for reoffending) in justice-involved Veterans in VA residential care compared to usual VA residential care after 6 months?
# >0.05
# 341
# Did five weeks of wheelchair skills training improve wheelchair skills (WST total score) in people with spinal cord injury (SCI) compared to basic health education after 1 year?
# 0.001
# 109
# Did online multi-family psychoeducation (web-based FPE) improve personal goal attainment (Goal Attainment Scale) in Veterans with schizophrenia and their family members compared to in-person MFG (multi-family group psychoeducation) after 3, 6, and 12 months?
# 0.3749
# 23
# Did adding portion-controlled meals (pre-prepared reduced-calorie meals) improve weight loss (weight change from baseline) in suboptimal responders to behavioral weight loss therapy compared to switching to acceptance-based behavioral therapy after 6 and 18 months after baseline?
# 0.25
# 259
# Did patient navigation to complete LDCT lung cancer screening improve getting a low-dose CT (LDCT) for lung cancer screening in homeless people with patient navigation compared to homeless people with usual care without navigation after 6 months (26 weeks)?
# <0.001
# 260
# Did a patient-centered decision-support tool and shared decision-making (SDM) toolkit improve physical health (SF-12 physical component score) in adults at the urban site whose case managers used the tool compared to adults at a similar site receiving usual care after 24 months?
# 0.0679
# 60
# Did a tech-assisted stepped-care program (education, tailored text reminders, and telehealth problem-solving) improve inhaler adherence (percent change via electronic monitoring) in adolescents (12–18) with moderate to severe persistent asthma compared to treatment as usual (no extra intervention) after 30 days?
# <0.001
# 70
# Did viewing AI-guided visual stimuli on a screen improve pain (VAS score) in healthy controls compared to control after up to 2 hours?
# 0.37
# 31
# Did lay health worker coaching about goals of care improve quality of life (Functional Assessment of Cancer Therapy—General, FACT-G) in people with cancer compared to usual care after 4 months (change from baseline)?
# <0.001
# 160
# Did tablet-based attention & interpretation training improve fear of recurrence (Concerns About Recurrence total score) in ACS patients with early PTSD symptoms (CBMT group) compared to attention-control tablet training (placebo) after about 4 weeks (pre- to post-training)?
# 0.698
# 17
# Did 12 sessions of Cognitive Processing Therapy (CPT-C) improve PTSD status (clinician-rated recovery/improvement on CAPS-IV) in Marines with combat-related PTSD compared to 8 sessions of imaginal exposure plus cognitive/experiential therapy after post-treatment (8-12 weeks)?
# 0.05
# 122
# Did telerehabilitation (portable ECG + smartphone app) improve exercise capacity (peak oxygen uptake — VO2 peak) in post–heart-surgery patients compared to routine care (standard rehab) after 4 weeks after randomisation?
# 0.63
# 66
# Did a doctor-led workshop using 7 social-marketing persuasion messages to encourage using an evidence-based asthma EMR template improve use of the evidence-based Asthma AIM EMR template to document outpatient mild persistent asthma in medical students exposed to the persuasion-embedded documentation workshop compared to medical students exposed to the same workshop without the 7 persuasion messages after immediately after and about 35 days later?
# 0.01
# 155
# Did training clinicians in shared decision-making (plus notification) improve shared decision making (SDMP score) in patients (age 76–85) of clinicians who received training and notification compared to patients (age 76–85) of clinicians who received notification only after about 1 week after the visit?
# 0.011
# 454
# Did individualized home environment changes with a personalized sensory kit improve protocol adherence (percent with ≥75% adherence) in Alzheimer's patients and caregivers compared to standard environmental design (non-personalized kit + caregiver training) after 6 weeks?
# 0.12
# 30
# Did regular feedback to urologists about excessive post-op antibiotic use improve excessive post-procedural antibiotic use (prescription on day 1) in patients undergoing TURP, TUBRT, or URS at 3 VHA hospitals compared to the same hospitals during the 2-year baseline after 12 months?
# 0.004
# 1797
# Did computer+simulator training with real-time auditory feedback to curb long glances from the road improve count of long (≥2 s) glances away from the road during a driving simulator in teens with ADHD who received the glance-feedback training compared to teens with ADHD who received rules-of-the-road training (no gaze feedback) after 1 month post-training?
# <0.0001
# 152
# Did experiencing weight discrimination improve negative affect (negative emotions; PANAS-X score) in adults with obesity compared to control experience after 2 minutes?
# 0.007
# 135
# Did a needs-focused mobile app for families and ICU clinicians improve unmet palliative care needs (NEST score) in ICU family members given the app compared to usual ICU care after about 3 days post-randomization?
# 0.018
# 111
# Did peer co-led 12-session self-management group for veterans' physical health improve general health functioning (SF-12 score) in veterans with serious mental illness and at least one chronic medical condition compared to a medical illness education and support group after 3 months (post-intervention)?
# 0.362
# 242
# Did 26 weeks of nicotine patch + gum improve 7-day abstinence (not smoking in past 7 days; self-reported 7-day point-prevalence abstinence) in smokers given 26 weeks of patch + gum compared to smokers given 8 weeks of patch + gum after 52 weeks?
# 0.011
# 544
# Did writing about traumatic experiences in English improve PTSD symptoms (Impact of Event Scale score) in people writing in English about trauma compared to people writing in Spanish about the previous day without emotions after 6 weeks?
# <0.05
# 18
# Did using a 10-week tailored smartphone app (education, self-monitoring, quizzes, messages, social support) improve Life's Simple 7 score (overall heart health) in African-American adults compared to a delayed-intervention control (no app during control period) after 6 months?
# <0.0001
# 55
# Did bupropion (medication) plus brief counseling (MM) improve treatment completion (taking meds ≥80% of the time and attending required counseling sessions) in lighter smokers receiving bupropion + MM (4 brief 15-min sessions) compared to lighter smokers receiving bupropion + Mayo counseling (10 weekly 30-min sessions) after 52 weeks?
# <0.017
# 260
# Did sending a simple message that you can get a flu shot at Geisinger (link to self-schedule) improve self-scheduling a flu shot appointment via the patient portal in Active Control (Nov) compared to Passive Control (Nov) after 4 weeks?
# 0.003
# 46510
# Did a 3-week app-based CBT program with daily self-care activities, symptom tracking, and weekly brief coach calls improve alcohol-related problems (Rutgers Alcohol Problem Index–Short Form, RAPI-S score) in women with recent (≤10 weeks) sexual assault who drink and have elevated distress compared to an assessment-only app (daily surveys and symptom tracker) with weekly safety calls after 3 weeks (post-intervention)?
# 0.6
# 41
# Did motivational interviewing with patient choice (MI-PC) improve treatment engagement (number of sessions attended) in MI-PC non-engaged at 2 weeks compared to MI-IOP non-engaged at 2 weeks after weeks 3–12?
# 0.11
# 189
# Did using a web-based fertility decision aid improve fertility knowledge (percent correct on a 41-item test) in transgender adolescents and young adults compared to before use (pre-test) after immediate post-test (same day)?
# <0.001
# 10

# %%
from pprint import pprint
for r in results:
    o = next(o for o in r.study.primary_outcomes if o.id == r.outcome_id)
    succ = o.p_value.value < 0.05 and o.p_value.comparator is not ">"
    print(f"Study {r.study.nct_id} {r.study.title}:")
    pprint(f"  Question: {r.llm_response.question}")
    print(f"  Answer: {'YES' if succ else 'NO'}")
    print('-'*60)
    
o
# Out:
# Study NCT02665468 eHealth Partnered Evaluation Initiative:
# ('  Question: Did support to encourage secure messaging (reminders, '
#  'motivational messages, education) improve secure messaging use (sent at '
#  'least one secure message) in Veterans given the supported-adoption '
#  'intervention compared to Veterans receiving usual care (no extra support) '
#  'after six months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01872338 Mindfulness-Based Cognitive Therapy for Suicide Prevention:
# ('  Question: Did mindfulness meditation plus suicide safety planning (MBCT-S) '
#  'improve suicide events (attempts, preparatory acts, or suicidal thoughts '
#  'needing emergency care) in high-risk Veterans (VA High Risk for Suicide '
#  'List) compared to VA usual care (treatment as usual) after 12 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01221090 Diabetes Self-Management Models to Reduce Health Disparities:
# ('  Question: Did 6-week self-management education classes improve blood sugar '
#  'control (HbA1c) in adults with type 2 diabetes compared to usual care after '
#  '12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00362453 Tai Chi Mind-Body Therapy for Knee Osteoarthritis:
# ('  Question: Did Tai Chi exercise (Yang style, 60 min twice weekly) improve '
#  'knee pain (WOMAC pain score) in older adults with symptomatic knee '
#  'osteoarthritis compared to wellness education and stretching (attention '
#  'control) after 12 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03670602 Weight Loss for Prediabetes Using Episodic Future Thinking:
# ('  Question: Did using episodic future thinking (EFT) cues via an app improve '
#  'delay discounting (choices for immediate reward) in people with prediabetes '
#  'using EFT plus behavioral weight-loss treatment compared to people with '
#  'prediabetes doing daily app check-ins plus the same behavioral weight-loss '
#  'treatment (no EFT) after 12 and 24 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT04533711 Physical Activity Pathway for Patients With Osteoarthritis in Primary Care (OA-PCP) (R33):
# ('  Question: Did phone-based physical activity coaching (with wrist activity '
#  'monitor) improve weekly minutes of moderate–to–vigorous physical activity '
#  'measured by accelerometer (MVPA per week) in older adults (65+) with hip or '
#  'knee osteoarthritis compared to attention-control calls about OA education '
#  '(same call schedule) after 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01238120 The Effects of Physical Activity and Low-Dose Ibuprofen on Cognitive Function in Cancer Patients:
# ('  Question: Did home-based walking and resistance-band exercise improve '
#  'memory performance (percent correct on delayed matching task) in cancer '
#  'patients receiving chemotherapy compared to placebo (pill only) after 6 '
#  'weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00792116 The Effects of Gum Chewing on Math Scores in Adolescents:
# ('  Question: Did chewing gum improve TAKS math scores in 8th grade students '
#  'compared to students not chewing gum after 14 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02026115 Computerized PAINRelieveIt Protocol for Cancer Pain Control in Hospice:
# ('  Question: Did tablet PAINRelieveIt system (pain reporting + nurse decision '
#  'support + tailored multimedia education) improve patient analgesic adherence '
#  '(percent of prescribed pain meds actually taken) in home hospice cancer '
#  'patients compared to usual hospice care (PAINReportIt summary only) after 7 '
#  'days (average daily adherence, days 1–7)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02234622 Comparing Effects of a Holistic Yoga Program and a Wellness Program on PTSD Symptoms:
# ('  Question: Did a 16-week holistic group yoga program (postures, breathing, '
#  'relaxation) improve PTSD symptoms (clinician-rated severity, CAPS-5) in '
#  'veterans with PTSD compared to a 16-week wellness lifestyle program '
#  '(low-intensity walking and wellness education) after 16 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00414817 Telephone-Based Program to Promote Inhaled Corticosteroid Adherence Among Individuals With Asthma:
# ('  Question: Did automated phone refill reminders improve inhaled '
#  'corticosteroid adherence (modified medication possession ratio, mMPR) in '
#  'asthma patients in the automated phone reminder group compared to usual care '
#  'after 19 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT04154384 Life Care Specialists (LCS) With a Focus on Patient Pain Management and Prevention of Substance Misuse:
# ('  Question: Did a pain coach offering opioid education, behavioral pain '
#  'coaching and care coordination improve average pain (NRS) score in '
#  'orthopaedic trauma patients given the pain coach plus usual care compared to '
#  'standard pain care and discharge instructions after 3 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01763203 The SUCCEED Trial of Secondary Stroke Prevention:
# ('  Question: Did care management + community health worker support (home '
#  'visits, workshops, home BP monitor) improve systolic blood pressure (top BP '
#  'number) in people who had a stroke or TIA compared to usual care '
#  '(educational materials) after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05159622 Water Up@ At Home: An Intervention to Replace Sugary Drinks With Water:
# ('  Question: Did replacing sugary drinks with filtered tap water using home '
#  "visits and a water filter improve parents' daily sugary drink consumption "
#  '(oz/day) in low-income parents with children 6mo–3yr in Early Head Start '
#  'compared to standard Early Head Start education (control) with a token '
#  'filter pitcher after 12–16 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00781079 Do Consumer Providers Enhance Recovery?:
# ('  Question: Did adding a consumer provider to intensive case management '
#  'teams improve psychiatric symptoms (BASIS-R score) in MHICM patients on '
#  'teams with a consumer provider compared to MHICM patients receiving care as '
#  'usual after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02334215 A Randomized Trial of Interim Methadone and Patient Navigation Initiated in Jail:
# ('  Question: Did starting methadone in jail plus patient navigation improve '
#  'opioid-positive urine tests (illicit opioid use) in people who started '
#  'methadone in jail with patient navigation compared to people who started '
#  'methadone in jail without patient navigation (methadone only) after 1, 3, 6, '
#  'and 12 months post-release?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01640379 Technology Enhanced Community Health Nursing (TECH-N) Study:
# ('  Question: Did tech-enhanced community health nursing (CHN visit + '
#  'twice-daily SMS reminders and STI prevention education) improve rates of '
#  'positive gonorrhea or chlamydia tests in young women (13–21) treated for PID '
#  'compared to enhanced standard care after 90 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05873556 Testing Brief Personalized Feedback Integrating Lab-based Alcohol Cue Information:
# ('  Question: Did brief personalized feedback using lab alcohol-cue info '
#  'improve number of standard drinks per week in young adults receiving '
#  'lab-based personalized feedback compared to assessment-only control (no '
#  'personalized feedback) after 2-week and 3-month follow-ups?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01130103 Combination Treatment for Posttraumatic Stress Disorder (PTSD) After the World Trade Center (WTC) Attack:
# ('  Question: Did paroxetine (SSRI) plus prolonged exposure therapy improve '
#  'PTSD severity (Clinician-Administered PTSD Scale, CAPS score) in WTC '
#  'survivors with PTSD compared to placebo pill plus prolonged exposure therapy '
#  'after 10 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02928952 Mindful Stress Reduction in Diabetes Self-management Education for Veterans:
# ('  Question: Did adding mindfulness training to diabetes education improve '
#  'diabetes-related distress (PAID score) in Veterans receiving diabetes '
#  'education plus mindfulness training compared to diabetes education alone '
#  '(usual care) after 24 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04226742 Evaluation of a Crowd-Powered Web Platform for Depression and Anxiety:
# ('  Question: Did ADAPT web platform with crowd features (online iCBT) improve '
#  'depression symptoms (DASS depression subscale score) in participants using '
#  'ADAPT (treatment) compared to participants using a self-guided ADAPT without '
#  'crowd features (control) after week 16?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02079610 Effect of Amygdala Neurofeedback on Depressive Symptoms and Processing Biases:
# ('  Question: Did amygdala real-time fMRI neurofeedback (upregulate via '
#  'positive memories) improve depression symptoms (MADRS score) in MDD patients '
#  'getting left amygdala neurofeedback compared to MDD patients getting HIPS '
#  'neurofeedback (control region) after 2 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02247336 Impact of Family History and Decision Support on High-risk Cancer Screening:
# ('  Question: Did entering family history into an online tool with decision '
#  'support improve risk-appropriate CRC screening referrals in patients '
#  'entering family history at enrollment compared to patients entering family '
#  'history 12 months later after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00564070 CBT for Adherence and Depression in Diabetes:
# ('  Question: Did multiple CBT sessions (10–12) for depression and diabetes '
#  'self-care improve glucose monitoring adherence (percent of checks via '
#  'glucometer) in people with type 2 diabetes and depression compared to '
#  'single-session life-steps adherence training plus enhanced usual care after '
#  '4 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02420990 Integrated Treatment for Adolescents With ADHD:
# ('  Question: Did adding medication decision-making and medication management '
#  'to behavioral support improve ADHD symptoms and related conduct, mood, '
#  'substance use, and behavior problems in teens getting medication decision '
#  'support plus family and academic behavioral help compared to teens getting '
#  'family and academic behavioral help only after one year?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00316303 Effectiveness of the Screen, Test, Immunize, Reduce Risk, and Refer (STIRR) Intervention for People With Both a Mental and Substance Abuse Disorder:
# ('  Question: Did on-site STIRR program (screening, testing, hepatitis A/B '
#  'vaccination, risk-reduction counseling, referrals) improve hepatitis A and B '
#  'immunization (among those not immunized at baseline) in people with both a '
#  'mental disorder and a substance abuse disorder compared to enhanced '
#  'treatment as usual (education and referral for testing/vaccination) after 6 '
#  'months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05233800 mHealth for Breast Cancer Survivors With Insomnia:
# ('  Question: Did voice-activated smart speaker CBT-I program improve insomnia '
#  'symptoms (Insomnia Severity Index score) in breast cancer survivors with '
#  'insomnia compared to a website with CBT-I information after 6 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03045081 PainTracker Self-Manager: a Web-based Platform to Promote and Track Chronic Pain Self-management:
# ('  Question: Did a web-based pain self-management program with nurse coaching '
#  'improve pain self-efficacy (PSEQ score) in early-treatment chronic pain '
#  'patients at a pain clinic compared to usual care (PainTracker only) after 3 '
#  'and 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02124460 Connect 4 Health: An Intervention to Improve Childhood Obesity Outcomes:
# ('  Question: Did health coaching (6 visits) plus interactive texts and '
#  'community resource connection improve BMI z-score (age/sex-adjusted BMI) in '
#  'children with elevated BMI compared to enhanced primary care (EHR flags, '
#  'clinician decision support, resource guide and educational texts) after 1 '
#  'year?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03972969 Highly Challenging Balance Program to Reduce Fall Rate in PD:
# ('  Question: Did in-person highly challenging exercise improve fall rate '
#  "(number of falls) in VA patients with mild-to-moderate Parkinson's disease "
#  'compared to health education after 3 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04240392 Treatment of Pregnant Women With OUD:
# ('  Question: Did onsite collaborative care (care manager + in-person '
#  'training) improve treatment engagement (completed intake and >2 OUD '
#  'treatment visits) in pregnant and postpartum women with opioid use disorder '
#  '(OUD) compared to remote ECHO support (video mentorship for clinicians) '
#  'after 30 days from baseline?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02791399 A Patient-Centered Intervention to Improve Opioid Safety:
# ('  Question: Did adding a nurse care manager to monitor opioid safety improve '
#  'risk of prescription opioid misuse (COMM score) in patients on chronic '
#  'opioid therapy with NCM support compared to treatment as usual (no NCM) '
#  'after 6 and 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02179749 Mifepristone Treatment of Alcohol Use Disorder:
# ('  Question: Did 600 mg/day mifepristone (pill) improve drinks per day '
#  '(standard drinks) in people with alcohol use disorder compared to placebo '
#  '(inactive pill) after 12 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04950686 Study of Long-term Efficacy and Mechanisms Underlying the Impact of a Web-based Sexual and Relationship Health Promotion Program With Young Adult Community College Students:
# ('  Question: Did a web-based media literacy sexual and relationship health '
#  'program improve relationship satisfaction in community college students aged '
#  '18-19 compared to wait-list control (no program) after 4 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04067401 Career Enhancement Training Study (USAF):
# ('  Question: Did training to strengthen social bonds and relationship skills '
#  'improve suicide severity score (0–100, higher = more suicidal thoughts/risk) '
#  'in early‑career enlisted USAF Airmen-in‑Training compared to '
#  'stress-management training (2‑hr class + texts) after 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02724969 A Mobile, Semi-automated Text Message-based Intervention to Prevent Perceived Low or Insufficient Milk Supply:
# ('  Question: Did sending semi-automated breastfeeding support text messages '
#  'improve perceived milk supply in first-time mothers planning to mostly '
#  'breastfeed compared to general prenatal/postpartum texts (Text4Baby) after 8 '
#  'weeks postpartum?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01802554 Reducing CVD Risk in Caregivers: A Brief Behavioral Activation Intervention:
# ('  Question: Did in-home behavioral activation to increase pleasant '
#  'activities improve depressive symptoms (CESD) in dementia caregivers '
#  'compared to support sessions with information brochures after 8 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00435188 Life 2: Improving Fitness and Function in Elders:
# ('  Question: Did a 12-month multi-component physical activity counseling '
#  'program improve walking speed (usual gait speed) in older veterans compared '
#  'to usual care after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02400736 Supported Employment in Patient Aligned Care Teams:
# ('  Question: Did helping veterans find competitive jobs with rapid '
#  'personalized support (IPS) improve steady worker status (worked ≥50% of '
#  'weeks) in veterans in primary care Patient Aligned Care Teams (PACT) '
#  'compared to usual VA vocational rehab/Transitional Work (TAU-VR) after 12 '
#  'months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03204643 Evaluation of Behavioral Health-Virtual Patient Navigation Team (BH-VPN):
# ('  Question: Did full usual care plus behavioral-health patient navigators '
#  'improve ED-to-inpatient admission rate after a behavioral health consult in '
#  'ED patients compared to usual care after 5 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03928717 A Text-Based Adherence Game for Young People Living With HIV in Ghana:
# ('  Question: Did a text-message gamified adherence game improve HIV viral '
#  'load (copies of HIV per mL of blood; log10-transformed) in young people '
#  'living with HIV in Ghana compared to brief in-person adherence counseling '
#  '(standard of care) after 90 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02943499 Mechanisms of Mindfulness for Smoking Cessation:
# ('  Question: Did a 3-week mindfulness app improve brain activity (BOLD signal '
#  'on fMRI) in smokers using the mindfulness app compared to a standard '
#  'smoking-cessation app after 1 month?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05879198 Train Your Brain: A Pilot Project to Improve Memory and Decision Making:
# ('  Question: Did computer-based working memory training improve '
#  'future-oriented thinking (CFCS-14 score) in at-risk adolescents from '
#  'underserved communities compared to Unknown after 7 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02899754 Incorporating Veterans' Preferences Into Lung Cancer Screening Decisions:
# ('  Question: Did using a web-based lung cancer screening decision tool '
#  'improve decisional conflict (uncertainty about the decision) in Veterans '
#  'eligible for lung cancer screening compared to general health info (not '
#  'about lung cancer) after 1 month?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00793455 Outreach for Patients With Uncompleted Colorectal Cancer Screening Orders:
# ('  Question: Did a mailed physician letter plus brochure and DVD about '
#  'colorectal cancer screening improve completion of colorectal cancer '
#  'screening (stool test, sigmoidoscopy, or colonoscopy) in patients with '
#  'uncompleted colorectal cancer screening orders compared to usual care after '
#  '3 months post randomization?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04890652 Digital Interventions to Treat Hazardous Drinking:
# ('  Question: Did a 4-week digital breathing-based emotion-regulation program '
#  'improve drinks per week in risky drinkers with emotional stress compared to '
#  'Unknown after immediately post-intervention and at 30 days?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00118417 Therapies for Treatment-Resistant Panic Disorder Symptoms:
# ('  Question: Did moderate-dose sertraline (an SSRI) improve panic symptoms '
#  '(Panic Disorder Severity Scale score) in patients with panic disorder '
#  'compared to Unknown after 6 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05302414 The Learning Outcome of Resuscitation Teamwork Training in Postgraduate Year Doctors and Nurses:
# ('  Question: Did board-game training for resuscitation teamwork improve '
#  'teamwork performance (Team Performance Observation Tool score) in PGY '
#  'doctors and nurses compared to lecture-based training after 16 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00129649 Service Development: Assessing Non-attendance Rates in Outpatient Clinics:
# ('  Question: Did a reminder phone call improve clinic attendance in asthma '
#  'clinic patients compared to usual care (no reminder) after 1 week?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02421315 Overlapping Neural Circuits in Pediatric OCD:
# ('  Question: Did having OCD improve brain activation during conflict '
#  'resolution (BOLD on task fMRI) in children/adolescents with OCD compared to '
#  'healthy controls after baseline?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02571452 Brief Behavioral Insomnia Treatment Study:
# ('  Question: Did 4-week brief behavioral insomnia treatment (sleep education; '
#  'sleep restriction & stimulus control; 2 in-person + 2 phone sessions) '
#  'improve work and social functioning (WSAS score) in Veterans with insomnia '
#  'compared to progressive muscle relaxation (muscle tensing/relaxing training) '
#  'after mid- to post-treatment (week 3 to 5)?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01860651 Web-based Monitoring in Children and Adolescents With Inflammatory Bowel Disease:
# ('  Question: Did web-based monitoring of symptoms and stool inflammation '
#  '(fecal calprotectin) improve medication adherence (MARS score) in '
#  'children/adolescents with IBD on home meds compared to routine outpatient '
#  'controls (4 clinic visits/year) after up to 2 years (follow-up every 3 '
#  'months)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04015440 Hostile Bias Modification Training Online Study II:
# ('  Question: Did completing word fragments into non-hostile words improve '
#  'tendency to see others as hostile (hostile attribution bias) in people doing '
#  'HBMT compared to people doing placebo word-completion after 24–96 hours?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00821509 STOPFLU: Is it Possible to Reduce the Number of Days Off in Office Work by Improved Hand-hygiene?:
# ('  Question: Did frequent hand washing plus cough/sneeze etiquette improve '
#  'reported days off due to their own infectious disease in office workers '
#  'compared to office workers keeping usual hand hygiene (control) after 16 '
#  'months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05417607 A+ Treatment/Feasibility of Adapted ESDM-informed Caregiver Coaching Delivered Remotely for Children With ASD (Autism Spectrum Disorder) and ADHD (Attention Deficit Hyperactivity Disorder):
# ('  Question: Did remote parent coaching teaching Early Start Denver Model '
#  '(ESDM) strategies improve caregiver fidelity (P-ESDM caregiver fidelity '
#  'score) in children with ASD and ADHD and their caregivers compared to '
#  'baseline (pre-intervention) after Week 9 (post-intervention)?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01494987 Ranolazine When Added to Glimepiride in Subjects With Type 2 Diabetes Mellitus:
# ('  Question: Did adding ranolazine to glimepiride improve blood sugar control '
#  '(HbA1c) in people with type 2 diabetes on glimepiride given ranolazine '
#  'compared to people with type 2 diabetes on glimepiride given placebo after '
#  '24 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01183689 Study of Novel Approaches for Prevention:
# ('  Question: Did daily self-weighing plus small diet/activity changes improve '
#  'mean weight change from baseline (weight gain) in young adults taught daily '
#  'self-weighing and small changes to prevent weight gain compared to '
#  'self-guided education with minimal support (control) after 3 years?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01590433 Weight Loss With Exenatide Treatment:
# ('  Question: Did twice-daily exenatide injections before meals improve weight '
#  'loss (change in body weight) in non-diabetic overweight/obese women (18–70 '
#  'yrs, BMI 28–48 kg/m2) compared to placebo injections after 12 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03603496 Post-Discharge Smoking Cessation Strategies: Helping HAND 4:
# ('  Question: Did proactive automated calls/texts + hospital-based coach and '
#  '8-week nicotine replacement improve no tobacco use confirmed by saliva or '
#  'breath test (biochemically confirmed abstinence) in transitional tobacco '
#  'care management (TTCM) compared to referral to state quitline (QL) after 6 '
#  'months post-discharge?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02871921 Internet-based Conversational Engagement Clinical Trial:
# ('  Question: Did 30-minute video-chat conversations 4×/week improve global '
#  'cognitive function (MoCA total score) in older adults aged 75+ who are '
#  'socially isolated compared to weekly 10-minute phone calls after 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01744977 Cholesterol Medication Packaging Study:
# ('  Question: Did blister packaging for cholesterol meds plus adherence '
#  'education improve cholesterol med adherence (measured by pill refills) in '
#  'patients given blister-pack statins and pharmacist counseling compared to '
#  'education-only (written LDL info) after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00850759 Using Virtual Reality to Train Children in Pedestrian Safety:
# ('  Question: Did VR street-crossing training improve street-crossing safety '
#  '(avg hits/close calls per 30 crossings) in children trained in a virtual '
#  'pedestrian environment compared to one-on-one streetside training after '
#  'post-training and at 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03658954 Multimodal Sleep Intervention Using Wearable Technology:
# ('  Question: Did web sleep advice + daily sleep/alcohol diary + wearable '
#  'feedback & coaching improve total drinks consumed weeks 4–12 '
#  '(log-transformed) in heavy-drinking young adults compared to web-based sleep '
#  'hygiene advice only after weeks 4–12?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04108429 IntelliCare in College Students - Implementation (ICCS-I):
# ('  Question: Did using the IntelliCare mobile mood-management app improve '
#  'depression severity (PHQ-9 score; higher = worse) in college students given '
#  'access to IntelliCare mobile self-help compared to Control after 8 weeks '
#  '(weekly at Wks 1,2,4,6,8)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04533204 Mnemonic Strategy Versus Spaced Retrieval Training in Those With Mild Cognitive Impairment:
# ('  Question: Did memory tricks (mnemonic strategy training) improve memory '
#  'for 45 trained object locations (percent correct) in people with mild '
#  'cognitive impairment (MCI) compared to spaced retrieval training after up to '
#  '1 month?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00532779 A Study of the Safety and Efficacy of Two Doses of Naltrexone SR/Bupropion SR and Placebo in Overweight and Obese Subjects:
# ('  Question: Did taking naltrexone SR 16 mg + bupropion SR 360 mg daily '
#  'improve body weight (percent change) in overweight/obese adults (some with '
#  'hypertension or dyslipidemia) compared to placebo plus '
#  'diet/behavior/exercise counseling after 56 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02037568 Improved Outcome in Allogeneic Hematopoietic Stem Cell Transplant (HSCT) Patients by Reducing Caregiver Distress:
# ('  Question: Did caregiver phone/video psychoeducation & relaxation (fPER) '
#  'improve patient quality of life (FACT-BMT) in HSCT patients whose caregivers '
#  'received fPER compared to HSCT patients whose caregivers received treatment '
#  'as usual (TAU) after 6 months post-transplant?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01356277 Intervention to Improve Adherence in Teen Kidney Transplant:
# ('  Question: Did forming an adherence support team with education, '
#  'problem-solving if-then action plans and pillbox dose reminders improve '
#  "percent of days with all prescribed doses taken (daily 'taking adherence') "
#  'in teen kidney transplant recipients compared to attention-control group '
#  '(coach provided general support, no adherence help) after 12 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02907944 Working With HIV Clinics to Adopt Addiction Treatments Using Implementation Facilitation:
# ('  Question: Did implementation facilitation (support for clinics to offer '
#  'addiction treatments) improve provision of addiction treatments '
#  '(prescriptions and counseling) in patients with opioid use disorder (OUD) '
#  'compared to baseline (pre-implementation) after 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01980771 Barbershop Talk: HIV Prevention for African American Heterosexual Men:
# ('  Question: Did attending a two-hour group HIV-prevention workshop improve '
#  'reports of any unprotected anal or vaginal sex in the past 90 days in '
#  'African American heterosexual men compared to men given a single-session '
#  'cancer prevention/screening education after six months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT04585919 Paired Promotion of Colorectal Cancer and Social Determinants of Health Screening:
# ('  Question: Did paired outreach offering FIT tests and social needs (SDOH) '
#  'screening improve completion of colorectal cancer screening (any '
#  'guideline-based method) in patients needing colorectal cancer screening '
#  'compared to usual care after implementation period (13 months before, 14 '
#  'months after)?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03605368 VR Intervention to Improve Police Safety:
# ('  Question: Did an immersive VR police-safety module (Floreo PSM) improve '
#  'police interaction skills (Police Interaction Assessment score) in '
#  'adolescents and adults with autism spectrum disorder (ASD) compared to BE '
#  'SAFE video-based training (video modeling) after about 2 weeks (pre- to '
#  'post-intervention)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00640653 Efficacy of an Abstinence-Only HIV Risk-Reduction Intervention for Young African-American Adolescents:
# ('  Question: Did an abstinence-only program (teaching to delay sexual '
#  'activity) improve abstinence (not initiating sex) in sexually inexperienced '
#  'young African-American adolescents compared to a health-promotion control '
#  '(smoking/diet/exercise program) after 24 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05516134 All About Me: An Intervention to Ease the Transition to Long Term Care:
# ('  Question: Did playing tablet-based games that let family and residents '
#  'share personal facts and play group games improve constructive engagement '
#  '(doing/commenting on the activity) in residents with dementia who used the '
#  'tablet games compared to standard activities (baseline) after Weeks 5–10 '
#  '(treatment)?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03733483 Sleep Disruption Induced Impairments in Bone Formation:
# ('  Question: Did restricting sleep to 5 h/night for 6 nights improve bone '
#  'formation (P1NP) in sleep-restricted participants compared to control '
#  '(normal sleep) after 6 nights (24‑hr serum before and after)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04078035 Biological Response to Brief Psychological Challenge:
# ('  Question: Did doing a 5-minute socio-evaluative speech (stress task) '
#  'improve cell-free mitochondrial DNA (cell-free mtDNA in blood) in healthy '
#  'adults compared to resting quietly (control session) after the task '
#  '(measured 5 min before to 120 min after)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01751061 Improving Decision Making for Patients With Prolonged Mechanical Ventilation:
# ('  Question: Did a web-based decision aid for surrogate decision makers '
#  'improve agreement about 1-year survival (clinician-surrogate concordance '
#  'score) in surrogates of ICU patients on prolonged mechanical ventilation '
#  'compared to usual ICU care after 2–7 days post-randomization?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04867382 Comparing Two Training Methods for Opioid Wizard:
# ('  Question: Did online SDM training with patient narratives improve stigma '
#  'toward people with opioid use disorder (Difference, Disdain, and Blame '
#  'scales) in primary care clinicians who got SDM training with patient '
#  'narratives compared to primary care clinicians who got SDM training without '
#  'narratives after immediately after the online training?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03810534 Connect-Home Clinical Trial:
# ('  Question: Did individualized discharge planning in the SNF plus a nurse '
#  'home visit within 24 hours (Connect-Home) improve preparedness for discharge '
#  '(Care Transitions Measure-15 score) in seriously ill SNF patients and their '
#  'caregivers discharged to home compared to usual SNF discharge planning only '
#  '(no structured home visit) after 7 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02003963 Social Exergaming for Healthy Weight in Adolescent Girls:
# ('  Question: Did 12-week dance exergaming (Kinect dance video games) improve '
#  'visceral fat (deep belly fat measured by MRI) in adolescent girls assigned '
#  'to dance exergames compared to control (no intervention) after 13 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04135443 Evaluation of 3T, a Sex-Positive HIV/STI Mobile App Intervention for Young Black Men Ages 14-19 Attracted to Men:
# ('  Question: Did using a sex-positive interactive mobile app for HIV/STI '
#  'prevention improve rates of condomless anal or vaginal intercourse '
#  '(unprotected sex) in young Black men ages 14–19 attracted to men (YBMSM) '
#  'compared to a general health information website after 3 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03750695 Acute Exercise Effects in Obese Pregnancy:
# ('  Question: Did a single 40-min resistance workout improve endothelial '
#  'function (% change in reactive hyperemia/augmentation index) in obese women '
#  'in mid-pregnancy compared to 40-min quiet rest after ≈40 minutes (immediate '
#  'post-intervention)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03344796 UV Exposure Assessed With Wearable Sensor and Sun Protection:
# ('  Question: Did wearing a UV sensor sticker plus daily tailored text '
#  'messages with structured goal-setting improve acceptability of wearing the '
#  'UV sensor and receiving text messages (system usability score 6–42; higher = '
#  'better) in melanoma survivors in Cohort Study 1 Arm1 compared to melanoma '
#  'survivors in Cohort Study 1 Arm2 (same texts but unstructured free-text '
#  'goal-setting) after 21 days?')
#   Answer: YES
# ------------------------------------------------------------
# <>:4: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# /var/folders/sl/nv_r__ss6dj_bn0prgcrsgvr0000gn/T/ipykernel_92421/1349048745.py:4: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   succ = o.p_value.value < 0.05 and o.p_value.comparator is not ">"
# PrimaryOutcome(nct_id='NCT03344796', id='NCT03344796_po_0', title='Acceptability of Wearing UV Sensor and Receiving Text Messages', description='Online system usability 6 item scale (Likert 7 items range from strongly disagree to strongly agree Minimum value 6, maximum value 42, higher score better outcome', population_description='Focus groups and structured interviews did not have data collected for acceptability of wearing the UV sensor and receiving text messages.', timeframe='cohort study 1 (arms 1 and 2) at end of 21 days, cohort study 2 (only one arm) at end of 28 days', groups=[Group(id='OG001', title='Cohort Study 1 Arm1', description='31 subjects\n\nFirst cohort study: It is expected that each of 60 melanoma survivors in arms 1+2 will wear the sensor and transmit data for 21 days in the warm weather months of June-Aug 2019. It will take about 2 months to enroll the subjects. Subjects will receive daily text messages in a sequence starting with behavioral facilitation, outcome expectancies, self-efficacy, and self-regulation. On day 10, participants will receive a text message prompting review and reflection on the prior 10 days of UV exposure. Participants will be randomized to receive a survey item inviting selection of strategies to achieve sun-protected outdoor activities (structured goal attainment).\n\nGoal attainment: After reviewing daily UV exposure in the prior 10 days, participants will be randomized to structured (select strategies from a list of 7 items) or unstructured (submit a free text description of a strategy) goal attainment.', num_participants='31', interventions=[]), Group(id='OG002', title='Cohort Study 1 Arm 2', description='29 subjects will receive daily text messages in a sequence starting with behavioral facilitation, outcome expectancies, self-efficacy, and self-regulation. On day 10, participants will receive a text message prompting review and reflection on the prior 10 days of UV exposure. Participants will be randomized tosubmit a free text description of their strategy (unstructured goal attainment).\n\nGoal attainment: After reviewing daily UV exposure in the prior 10 days, participants will be randomized to structured (select strategies from a list of 7 items) or unstructured (submit a free text description of a strategy) goal attainment.', num_participants='29', interventions=[]), Group(id='OG003', title='Cohort Study 2', description='Second cohort study: 42 young adults will wear the sensor and transmit data for 28 days in summer 2020.', num_participants='42', interventions=[])], p_value=PValue(comparator='<', value=0.01))
