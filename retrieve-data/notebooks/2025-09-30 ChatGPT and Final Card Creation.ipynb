# %%
import sys
import os
from dataclasses import dataclass
from dotenv import load_dotenv
from openai import OpenAI
from tqdm import tqdm
from concurrent.futures import ThreadPoolExecutor, as_completed
import threading

sys.path.insert(0, "../src")

from extract_valid_studies import main
from models import ValidStudy, PrimaryOutcome

load_dotenv()
# Out:
# True

# %%
MODEL = "gpt-5-mini"
RAW_STUDIES_DIR = "../data/raw_studies"
STUDIES_PROCESSED_OUTPUT_DIR= "../data/studies_processed"
CARDS_OUTPUT_DIR = "../data/cards"
MAX_WORKERS = 100
NUM_STUDIES = 750

# %%
from pydantic import BaseModel, Field, model_validator

class LLMResponse(BaseModel):
    question: str = Field(..., description="The final question in the specified format with the appropriate placeholders filled in verbatim with the other fields.")
    intervention_fragment: str = Field(..., description="The main intervention being tested, in layperson's terms. This should be directly pluggable into the question template.")
    intervention_group_fragment: str = Field(..., description="The purpose of the clinical trial, in layperson's terms. This should be directly pluggable into the question template.")
    outcome_fragment: str = Field(..., description="The primary outcome being measured, in layperson's terms. This should be directly pluggable into the question template.")
    comparator_group_fragment: str = Field(..., description="The comparator or control condition, in layperson's terms. This should be directly pluggable into the question template.")
    timeframe_fragment: str = Field(..., description="The timeframe of the outcome measurement, in layperson's terms. This should be directly pluggable into the question template.")
    intervention_group_description: str = Field(..., description="A brief description of the intervention group.")
    comparator_group_description: str = Field(..., description="A brief description of the comparator/control group.")
    understandability_score: int = Field(..., description="A 1-10 score representing the understandability of the question by a lay reader.")

    @model_validator(mode="after")
    def ensure_question_valid(self):
        expected_question = f"Did {self.intervention_fragment} improve {self.outcome_fragment} in {self.intervention_group_fragment} compared to {self.comparator_group_fragment} after {self.timeframe_fragment}?"
        if self.question != expected_question:
            raise ValueError(f"Question does not match the expected format. Got: {self.question}, Expected: {expected_question}")
        return self


@dataclass
class ProcessingInformation:
    study: ValidStudy
    outcome_id: str
    llm_response: LLMResponse

    def to_dict(self):
        def recursive_asdict(obj):
            if isinstance(obj, list):
                return [recursive_asdict(item) for item in obj]
            elif isinstance(obj, dict):
                return {key: recursive_asdict(value) for key, value in obj.items()}
            elif hasattr(obj, "__dict__"):
                return {key: recursive_asdict(value) for key, value in obj.__dict__.items()}
            else:
                return obj
        return {
            "study": recursive_asdict(self.study),
            "outcome_id": self.outcome_id,
            "llm_response": self.llm_response.model_dump(),
        }

# %%
@dataclass
class UsageTracker:
    total_api_calls: int = 0
    total_input_tokens: int = 0
    total_output_tokens: int = 0


    def cost(self) -> float:
        c_i = {
            "gpt-5": 1.25,
            "gpt-5-mini": 0.25,
        }
        c_o = {
            "gpt-5": 10,
            "gpt-5-mini": 2,
        }
        input_cost = (self.total_input_tokens / 1_000_000) * c_i[MODEL]
        output_cost = (self.total_output_tokens / 1_000_000) * c_o[MODEL]

        return input_cost + output_cost

    def summary(self):
        print(f"Total API calls: {self.total_api_calls}")
        print(f"Total input tokens: {self.total_input_tokens}")
        print(f"Total output tokens: {self.total_output_tokens}")
        print(f"Estimated cost: ${self.cost():.4f}")

tracker = UsageTracker()

# %%
def mk_prompt(v: ValidStudy, o: PrimaryOutcome) -> str:
    groups_info = []
    for g in o.groups:
        groups_info.append("\n".join([
            f"Group title: {g.title}",
            f"Description: {g.description}",
            f"Interventions: {', '.join([f"{i.name}: {i.description}" for i in g.interventions]) if g.interventions else '(uncertain)'}",
        ]))


    return f"""
We are creating flashcard summaries for a game where laypeople predict the outcomes of clinical trials (behavioral interventive).

The final question for the flashcard must be of format:
"Did [intervention_fragment] improve [outcome_fragment] in [intervention_group_fragment] compared to [comparator_group_fragment] after [timeframe_fragment]?"

Keep the questions as short as possible. Use acronyms if needed, as long as they are understandable. If there is a name given to the intervention (e.g. "The Jolly Flower Telephone Protocol for Healthy Ageing"), instead of using the name, simply describe the intervention in layperson's terms (e.g. "calling other elderly people").

Remember to keep the question short. Do not include examples. Do not include any additional text or explanation.

Recall that the question should be reconstructable by verbatim plugging in the other fields.


Please ensure that the answers are concise and easily understandable by someone without a medical background. Avoid technical jargon and use simple language. Where something is technical, give a lay description and then in parentheses the technical term. 

Please create a question based on the following clinical trial information:
• Trial Title: {v.title}
• Trial Description: {v.description}
• Measure: {o.title}
• Measure Description: {o.description}
• Timeframe: {o.timeframe}

The groups are as follows (the first is the intervention group):
{'\n\n'.join(groups_info)}


If there is missing intervention or comparator information, please either match to these interventions (if you can tell from the group title/description), or say "Control" if it is a no-treatment or standard care control group, or "Unknown" if you cannot tell.


Here are negative examples of questions:

EXAMPLE 1
Did using a web-based lung cancer screening decision aid improve decisional conflict (uncertainty about the screening decision) in Veterans who used the decision tool compared to Veterans given general prevention info (not about lung cancer) after 1 month?

Understandability score: 7/10 (confusing phrasing)

Better version:
Did using a web-based lung cancer screening decision aid reduce uncertainty in deciding whether to screen in Veterans who used the decision tool compared to Veterans given general prevention info (not about lung cancer) after 1 month?

Understandability score: 9/10


EXAMPLE 2
Did upregulating the left amygdala with real-time fMRI neurofeedback (thinking of positive memories) improve depressive symptoms (MADRS score) in MDD patients receiving left amygdala neurofeedback compared to MDD patients receiving HIPS (non-emotional region) neurofeedback after 2 weeks?

Understandability score: 3/10 (unclear what MDD is, what HIPS is)

Problems:
• Intervention seems to be "thinking of positive memories", the rest seems extraneous)
• MDD is not explained


EXAMPLE 3
Did wearing a UV dosimeter sticker and receiving daily personalized text messages based on sensor readings improve acceptability of wearing the UV sensor and receiving texts (system usability score, 6–42; higher better) in melanoma survivors in Cohort Study 1 Arm 1 (n=31) compared to melanoma survivors in Cohort Study 1 Arm 2 (n=29; daily texts + unstructured goal responses) after 21 days?


Understandability score: 5/10 (what is a dosimeter?)

Better version:
Did wearing a UV sensor sticker (UV dosimeter) and receiving daily personalized text messages improve acceptability of wearing a UV sensor and receiving related texts in melanoma survivors compared to melanoma survivors receiving daily texts + unstructured goal responses after 21 days?


EXAMPLE 4
Did family- and home-based behavioral support for ADHD (CASH‑AA) improve ADHD symptoms and related problems (delinquency, substance use, internalizing/externalizing symptoms) in adolescents with ADHD in the behavioral-only group compared to adolescents receiving the behavioral program plus medication integration (MIP) after one year?

Understandability score: 9/10

Better version (less non-core details):
Did family- and home-based behavioral support for ADHD (CASH‑AA) improve ADHD symptoms and related problems in adolescents with ADHD in the behavioral-only group compared to adolescents receiving the behavioral program plus medication integration (MIP) after one year?

Understandability score: 9/10 (no improvement, but more terse)


EXAMPLE 5
Did onsite collaborative care with a care manager (CC) improve treatment engagement (completed baseline and >2 OUD treatment visits) in pregnant and postpartum women with opioid use disorder compared to remote ECHO video mentorship (tele-support for providers) after 30 days from baseline?

Understandability score: 4/10 (what is ECHO, OUD?)

Problems:
• OUD is not explained
• ECHO is not explained


EXAMPLE 6
Did using an AF decision-support tool to recommend antithrombotic therapy improve discordant antithrombotic therapy (patients on treatment that disagreed with the tool's recommendation) in adults with non-valvular AF in primary care compared to educational intervention only (educational conference series) after one year?

Understandability score: 3/10 (what is AF?)

Problems:
• AF is not explained
• Antithrombotic is an unexplained technical term
• The explanation of "patients on treatment that disagreed with the tool's recommendation" is wordy and confusing.

---------------


Here are positive examples of questions:
EXAMPLE 1
Did practicing Tai Chi improve knee pain (WOMAC pain score) in people with knee osteoarthritis compared to wellness education and stretching after 12 weeks?

Understandability score: 10/10

Reason:
Concise, easy to understand, technical term in parenthesis (understanding is not gated by needing to know the technical term).


EXAMPLE 2
Did abstinence-only sex education improve abstinence (not having sex) in young African-American adolescents compared to health-promotion control after 24 months?

Understandability score: 10/10

Reason:
Easy to understand, clear treatment and control groups, short.


EXAMPLE 3
Did video counseling for quitting smoking improve smoking abstinence (verified by salivary cotinine) in women with HIV compared to women with HIV with telephone counseling instead after 6 months?

Understandability score: 10/10

Reason:
Good details, clear
    """

# %%
valid_studies = main(RAW_STUDIES_DIR)
# Out:
# 100%|██████████| 34562/34562 [00:08<00:00, 3863.11it/s]
# Loaded 5858 raw studies with results
# 2033 out of 5858 (34.70%) studies have p-values reported in primary outcomes analyses.

# %%
def process_single_outcome(study: ValidStudy, o: PrimaryOutcome, tracker_lock: threading.Lock) -> ProcessingInformation:
    """Process a single study and return the result or raise an exception."""
    MAX_TRIES = 3
    success = False
    n_tries = 0

    client = OpenAI(api_key=os.getenv("OPENAI_API_KEY"))
    while not success and n_tries < MAX_TRIES:
        n_tries += 1

        try:
            response = client.responses.parse(
                model=MODEL,
                input=[
                    {
                        "role": "system",
                        "content": "You are an expert clinical trial analyst."
                    },
                    {"role": "user", "content": mk_prompt(study, o)},
                ],
                text_format=LLMResponse,
            )

            # Track token usage (thread-safe)
            with tracker_lock:
                tracker.total_api_calls += 1
                tracker.total_input_tokens += response.usage.input_tokens
                tracker.total_output_tokens += response.usage.output_tokens

            # Parse response
            llm_response = response.output_parsed

            return ProcessingInformation(
                study=study,
                outcome_id=o.id,
                llm_response=llm_response
            )
        except Exception as e:
            # Re-raise with study info for better error handling
            if n_tries >= MAX_TRIES - 1:
                raise Exception(f"Failed processing {study.nct_id}: {str(e)}")


def process_studies_multithreaded(studies: list[ValidStudy], max_workers: int = MAX_WORKERS) -> tuple[list[ProcessingInformation], list[tuple[str, str]]]:
    """Process studies using multiple threads."""
    results = []
    failures = []
    tracker_lock = threading.Lock()
    
    # Use ThreadPoolExecutor for concurrent API calls
    with ThreadPoolExecutor(max_workers=max_workers) as executor:
        future_to_study = {}
        # Submit all tasks
        n = 0
        for study in studies:
            for outcome in study.primary_outcomes:
                n += 1
                future_to_study[executor.submit(process_single_outcome, study, outcome, tracker_lock)] = study
       
        # Process completed tasks with progress bar
        with tqdm(total=n, desc="Processing study outcomes") as pbar:
            for future in as_completed(future_to_study):
                study = future_to_study[future]
                try:
                    result = future.result()
                    results.append(result)
                except Exception as e:
                    failures.append((study.nct_id, str(e)))
                    pbar.set_postfix_str(f"Failures: {len(failures)}")
                
                pbar.update(1)
    
    return results, failures

# %%
# Process studies using multithreading (adjust max_workers based on API rate limits)
results, failures = process_studies_multithreaded(valid_studies[:NUM_CARDS], max_workers=MAX_WORKERS)

tracker.summary()

print(f"Successfully processed: {len(results)} outcomes")
print(f"Failed: {len(failures)} outcomes")
if failures:
    print("Failures:")
    for nct_id, error in failures[:5]:  # Show first 5 failures
        print(f"  {nct_id}: {error}")
# Out:
# Processing study outcomes: 100%|██████████| 2606/2606 [14:12<00:00,  3.06it/s, Failures: 405]
# Total API calls: 2201
# Total input tokens: 5517189
# Total output tokens: 3115576
# Estimated cost: $7.6104
# Successfully processed: 2201 studies
# Failed: 405 studies
# Failures:
#   NCT03605368: Failed processing NCT03605368: 1 validation error for LLMResponse
#   Value error, Question does not match the expected format. Got: Did wearing an immersive VR headset to practice police interactions improve police interaction skills (Police Interaction Assessment score) in adolescents and adults with autism compared to BE SAFE video-based instruction after 2 weeks?, Expected: Did wearing an immersive VR headset to practice police interactions improve police interaction skills (Police Interaction Assessment score) in adolescents and adults with autism compared to BE SAFE video-based instruction (video modeling) after 2 weeks? [type=value_error, input_value={'question': 'Did wearing...standability_score': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error
#   NCT04533711: Failed processing NCT04533711: 1 validation error for LLMResponse
#   Value error, Question does not match the expected format. Got: Did phone-based physical activity coaching with a wrist activity monitor improve minutes per week of moderate-to-vigorous physical activity (MVPA) in older adults (≥65) with hip or knee osteoarthritis recruited from primary care compared to attention-control phone calls about OA education after 6 months?, Expected: Did phone-based physical activity coaching with a wrist activity monitor improve minutes per week of moderate-to-vigorous physical activity (MVPA) measured by accelerometer in older adults (≥65) with hip or knee osteoarthritis recruited from primary care compared to attention-control phone calls about osteoarthritis (OA) education after 6 months? [type=value_error, input_value={'question': 'Did phone-b...standability_score': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error
#   NCT05053360: Failed processing NCT05053360: 1 validation error for LLMResponse
#   Value error, Question does not match the expected format. Got: Did gentle touch therapy (Healing Touch) improve anxiety (Hospital Anxiety Scale score; lower is better) in post-cesarean women compared to 15 minutes of quiet time immediately after the session?, Expected: Did gentle touch therapy (Healing Touch) improve anxiety (Hospital Anxiety Scale score; lower is better) in post-cesarean women compared to 15 minutes of quiet time after immediately after the session? [type=value_error, input_value={'question': 'Did gentle ...standability_score': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error
#   NCT03978871: Failed processing NCT03978871: 1 validation error for LLMResponse
#   Value error, Question does not match the expected format. Got: Did teaching a growth emotion mindset improve emotion regulation strategies during a social stress test (Emotion Regulation Strategy Scale) in adolescent girls given a growth emotion mindset lesson compared to girls given neutral brain education after the lesson (post-manipulation)?, Expected: Did teaching a growth emotion mindset lesson (brain/emotion malleability) improve emotion regulation strategies during a social stress test (Emotion Regulation Strategy Scale) in adolescent girls given a growth emotion mindset lesson compared to girls given neutral brain education after after the lesson (post-manipulation)? [type=value_error, input_value={'question': 'Did teachin...standability_score': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error
#   NCT00127790: Failed processing NCT00127790: 1 validation error for LLMResponse
#   Value error, Question does not match the expected format. Got: Did cognitive-behavioral therapy for insomnia (CBT-I) improve pain severity (MPI Pain Severity subscale score) in patients with chronic pain compared to wait-list control (no treatment) after about 10 weeks (pre-to-post treatment)?, Expected: Did cognitive-behavioral therapy for insomnia (CBT-I) improve pain severity (MPI Pain Severity subscale score) in patients with chronic pain receiving CBT-I compared to wait-list control (no treatment) after about 10 weeks (pre-to-post treatment)? [type=value_error, input_value={'question': 'Did cogniti...standability_score': 10}, input_type=dict]
#     For further information visit https://errors.pydantic.dev/2.11/v/value_error

# %%
import ujson as json
for result in results:
    with open(os.path.join(STUDIES_PROCESSED_OUTPUT_DIR, f"{result.study.nct_id}_{result.outcome_id}_llm_response.json"), "w") as f:
        json.dump(result.to_dict(), f, indent=4)

# %%
def get_num_participants(groups) -> int:
    n = 0
    for g in groups:
        num = g.num_participants
        if isinstance(num, int):
            n += num
        elif isinstance(num, str):
            new_num = ''
            for c in num:
                if c.isdigit():
                    new_num += c
            n += int(new_num)

    return n

def mk_card(r: ProcessingInformation) -> dict:
    """Create a card dictionary from the processing information."""
    o = next(o for o in r.study.primary_outcomes if o.id == r.outcome_id)
    p_value = f"{o.p_value.comparator}{o.p_value.value}"
    if p_value.startswith("="):
        p_value = p_value[1:]

    success = (o.p_value.value < 0.05 and o.p_value.comparator != ">") or p_value == "<0.05"

    return {
        "study": {
            "nct_id": r.study.nct_id,
            "title": r.study.title,
            "brief_description": r.study.brief_description,
        },
        "card_id": r.outcome_id,
        "front_details": {
            "question": r.llm_response.question,
            "intervention_fragment": r.llm_response.intervention_fragment,
            "intervention_group_fragment": r.llm_response.intervention_group_fragment,
            "outcome_fragment": r.llm_response.outcome_fragment,
            "comparator_group_fragment": r.llm_response.comparator_group_fragment,
            "timeframe_fragment": r.llm_response.timeframe_fragment,
        },
        "p_value": p_value,
        "num_participants": get_num_participants(o.groups),
        "success": success,
        "conditions": r.study.conditions,
        "keywords": r.study.keywords,
        "decks": r.study.decks,
        "understandability_score": r.llm_response.understandability_score,
    }

cards = []
n_fail = 0
for r in results:
    try:
        card = mk_card(r)
        cards.append(card)
    except Exception as e:
        n_fail += 1
        print(f"Failed to create card for {r.study.nct_id} outcome {r.outcome_id}: {str(e)}")
with open(os.path.join(CARDS_OUTPUT_DIR, "cards.json"), "w") as f:
    json.dump(cards, f, indent=4)

with open(os.path.join(CARDS_OUTPUT_DIR, "questions.txt"), "w") as f:
    for card in cards:
        f.write(card["front_details"]["question"] + "\n")
# Out:
# Failed to create card for NCT04108429 outcome NCT04108429_po_2: invalid literal for int() with base 10: ''
# Failed to create card for NCT04243330 outcome NCT04243330_po_0: invalid literal for int() with base 10: ''
# Failed to create card for NCT04243330 outcome NCT04243330_po_1: invalid literal for int() with base 10: ''

# %%
from pprint import pprint
for r in results:
    o = next(o for o in r.study.primary_outcomes if o.id == r.outcome_id)
    succ = o.p_value.value < 0.05 and o.p_value.comparator is not ">"
    print(f"Study {r.study.nct_id} {r.study.title}:")
    pprint(f"  Question: {r.llm_response.question}")
    print(f"  Answer: {'YES' if succ else 'NO'}")
    print('-'*60)
    
o
# Out:
# Study NCT00362453 Tai Chi Mind-Body Therapy for Knee Osteoarthritis:
# ('  Question: Did practicing Tai Chi improve knee pain (WOMAC pain score) in '
#  'people with knee osteoarthritis compared to wellness education and '
#  'stretching after 12 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03605368 VR Intervention to Improve Police Safety:
# ('  Question: Did three at-home VR sessions practicing police interactions '
#  'improve police interaction skills (Police Interaction Assessment score) in '
#  'adolescents and adults with autism (ASD) compared to no intervention (TAU) '
#  'after about 2 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03605368 VR Intervention to Improve Police Safety:
# ('  Question: Did 3 at-home immersive VR police-safety sessions (Floreo PSM) '
#  'improve police interaction skills (Police Interaction Assessment score '
#  'change) in adolescents and adults with autism compared to treatment-as-usual '
#  '(no intervention) after about 2 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00564070 CBT for Adherence and Depression in Diabetes:
# ('  Question: Did multiple-session CBT for depression and diabetes self-care '
#  'improve glucose monitoring adherence (percent via electronic glucometer) in '
#  'people with type 2 diabetes and depression receiving CBT-AD compared to '
#  'people receiving a single-session adherence training (life-steps) plus '
#  'enhanced usual care after 4 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03045081 PainTracker Self-Manager: a Web-based Platform to Promote and Track Chronic Pain Self-management:
# ('  Question: Did using a web-based PainTracker Self-Manager plus nurse '
#  'care-manager coaching improve confidence to manage pain (pain self-efficacy '
#  'score) in patients offered the web-based PainTracker Self-Manager and nurse '
#  'coaching compared to usual care with PainTracker only after 3 and 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01763203 The SUCCEED Trial of Secondary Stroke Prevention:
# ('  Question: Did care-management plus community health worker support (home '
#  'visits, workshops, home BP monitor) improve systolic blood pressure in '
#  'people who had a stroke or TIA compared to usual care after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02724969 A Mobile, Semi-automated Text Message-based Intervention to Prevent Perceived Low or Insufficient Milk Supply:
# ('  Question: Did semi-automated breastfeeding support text messages improve '
#  'perceived milk supply in first-time mothers planning to exclusively/nearly '
#  'exclusively breastfeed compared to general Text4Baby texts after 8 weeks '
#  'postpartum?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02003963 Social Exergaming for Healthy Weight in Adolescent Girls:
# ('  Question: Did playing active dance video games (exergaming) improve '
#  'visceral fat (by MRI) in adolescent girls in the exergame program compared '
#  'to girls receiving no intervention (telephone reminders only) after 13 '
#  'weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00414817 Telephone-Based Program to Promote Inhaled Corticosteroid Adherence Among Individuals With Asthma:
# ('  Question: Did automated phone refill reminders (interactive voice calls '
#  'with refill reminders and education) improve inhaled corticosteroid '
#  'adherence (modified medication possession ratio, mMPR) in people with asthma '
#  'compared to usual care after 19 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00435188 Life 2: Improving Fitness and Function in Elders:
# ('  Question: Did a one-year physical activity counseling program improve gait '
#  'speed (walking speed) in older veterans compared to usual care after 12 '
#  'months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05302414 The Learning Outcome of Resuscitation Teamwork Training in Postgraduate Year Doctors and Nurses:
# ('  Question: Did board game–based training improve teamwork knowledge '
#  '(Knowledge of Teamwork assessment) in PGY doctors and nurses compared to '
#  'simulation-based and lecture-based training after 4 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04240392 Treatment of Pregnant Women With OUD:
# ('  Question: Did onsite collaborative care support (care manager + provider '
#  'training) improve treatment retention (stayed in treatment; no break >1 '
#  'month) in pregnant and postpartum women with opioid use disorder (OUD) '
#  'compared to remote video-based clinician mentorship (ECHO) after delivery '
#  'and 3 months postpartum?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04533711 Physical Activity Pathway for Patients With Osteoarthritis in Primary Care (OA-PCP) (R33):
# ('  Question: Did phone-based physical activity coaching with a wrist activity '
#  'monitor improve weekly minutes of moderate-to-vigorous physical activity '
#  '(accelerometer) in older adults with hip/knee osteoarthritis compared to '
#  'attention-control OA education calls after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02420990 Integrated Treatment for Adolescents With ADHD:
# ('  Question: Did family- and home-based behavioral support for ADHD (CASH‑AA) '
#  'improve treatment attendance (total number of sessions attended) in '
#  'adolescents with ADHD in the behavioral-only group compared to adolescents '
#  'with ADHD receiving the behavioral program plus medication integration (MIP) '
#  'after one year?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03605368 VR Intervention to Improve Police Safety:
# ('  Question: Did remote at-home VR police safety training (Floreo PSM) '
#  'improve police interaction skills (Police Interaction Assessment score) in '
#  'adolescents and adults with autism spectrum disorder (ASD) compared to '
#  'treatment-as-usual (no intervention) after about 2 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00564070 CBT for Adherence and Depression in Diabetes:
# ('  Question: Did multiple-session CBT for depression and diabetes self-care '
#  'improve depressive symptoms (MADRS score) in people with type 2 diabetes and '
#  'depression compared to single-session adherence training (life-steps) after '
#  '4 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00564070 CBT for Adherence and Depression in Diabetes:
# ('  Question: Did multiple-session CBT for depression and diabetes self-care '
#  'improve depression severity (Clinical Global Impression score; 1–7, higher '
#  'worse) in people with type 2 diabetes and depression compared to '
#  'single-session adherence training plus enhanced usual care after 4 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05302414 The Learning Outcome of Resuscitation Teamwork Training in Postgraduate Year Doctors and Nurses:
# ('  Question: Did board game-based training improve teamwork performance (Team '
#  'Performance Observation Tool score) in postgraduate doctors and nurses '
#  'compared to simulation-based training after 4 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00435188 Life 2: Improving Fitness and Function in Elders:
# ('  Question: Did a 12-month multi-component physical activity counseling '
#  'program improve walking speed (gait speed) in older veterans compared to '
#  'usual care after 12 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00127790 Treatment of Insomnia Secondary to Chronic Pain:
# ('  Question: Did 10-session individual CBT for pain (pain education, pacing, '
#  'problem-solving, relaxation) improve pain severity (MPI Pain Severity '
#  'subscale) in patients with chronic pain compared to wait-list control (no '
#  'treatment) after about 10 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02026115 Computerized PAINRelieveIt Protocol for Cancer Pain Control in Hospice:
# ('  Question: Did a tablet system that reports pain, advises nurses, and gives '
#  'tailored multimedia education improve taking prescribed pain medicines as '
#  'directed (analgesic adherence) in home hospice cancer patients using the '
#  'tablet system compared to home hospice cancer patients receiving usual '
#  'hospice care with tablet pain summaries after 1 week (days 1–7 average)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03605368 VR Intervention to Improve Police Safety:
# ('  Question: Did immersive VR police-safety training (VR headset practice '
#  'with a virtual officer) improve police interaction skills (change in Police '
#  'Interaction Assessment score) in adolescents and adults with autism (ASD) '
#  'compared to video-based BE SAFE police-safety training (videos, worksheets, '
#  'discussion) after about 2 weeks (pre- to post-intervention)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01860651 Web-based Monitoring in Children and Adolescents With Inflammatory Bowel Disease:
# ('  Question: Did web-based symptom and stool inflammation (fecal '
#  'calprotectin) monitoring improve medication adherence (MARS score) in '
#  'children and adolescents with IBD taking medicine at home compared to '
#  'routine quarterly outpatient care after 2 years?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00127790 Treatment of Insomnia Secondary to Chronic Pain:
# ('  Question: Did combined cognitive-behavioral therapy for sleep and pain '
#  '(CBT-I/P) improve insomnia severity (Insomnia Severity Index score) in '
#  'people with chronic pain and insomnia compared to wait-list control (no '
#  'treatment) after about 10 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02420990 Integrated Treatment for Adolescents With ADHD:
# ('  Question: Did family- and home-based behavioral support for ADHD improve '
#  'ADHD symptoms and related problems (delinquency, substance use, '
#  'internalizing/externalizing symptoms) in adolescents with ADHD in the '
#  'behavioral-only group compared to adolescents receiving behavioral support '
#  'plus medication decision-making and management (MIP) after one year?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02247336 Impact of Family History and Decision Support on High-risk Cancer Screening:
# ('  Question: Did entering family health history into MeTree and giving '
#  'patient and provider decision support improve risk-appropriate colorectal '
#  'cancer screening referral in patients who completed MeTree at enrollment '
#  'compared to patients who completed MeTree 12 months later after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04240392 Treatment of Pregnant Women With OUD:
# ('  Question: Did onsite collaborative care with care managers improve '
#  'treatment engagement (completed baseline assessment and >2 opioid treatment '
#  'visits) in pregnant and postpartum women with opioid use disorder (OUD) '
#  'compared to remote ECHO mentorship for providers (video education and '
#  'mentorship) after 30 days from baseline?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03605368 VR Intervention to Improve Police Safety:
# ('  Question: Did immersive VR police-safety training (Floreo PSM) improve '
#  'police interaction skills (change in Police Interaction Assessment scores) '
#  'in adolescents and adults with autism compared to video-based police-safety '
#  'training (BE SAFE video modeling) after about 2 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02899754 Incorporating Veterans' Preferences Into Lung Cancer Screening Decisions:
# ('  Question: Did using a web-based lung cancer screening decision tool '
#  'improve decisional conflict (uncertainty and difficulty making the screening '
#  'decision) in Veterans who used the decision tool compared to Veterans given '
#  'general prevention info (not about lung cancer) after 1 month?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04154384 Life Care Specialists (LCS) With a Focus on Patient Pain Management and Prevention of Substance Misuse:
# ('  Question: Did Life Care Specialist (LCS) pain coaching and opioid '
#  'education improve average pain (NRS) score in orthopaedic trauma patients '
#  'compared to standard pain management after 3 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00564070 CBT for Adherence and Depression in Diabetes:
# ('  Question: Did multiple CBT sessions for depression and diabetes self-care '
#  'improve medication adherence (percent via electronic pill cap) in people '
#  'with type 2 diabetes and depression compared to single-session life-steps '
#  'adherence training plus enhanced usual care after 4 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03750695 Acute Exercise Effects in Obese Pregnancy:
# ('  Question: Did one 40-minute resistance exercise session (strength '
#  'training) improve blood vessel function (endothelial function; percent '
#  'change in reactive hyperemia/augmentation index) in obese pregnant women in '
#  'mid-pregnancy compared to 40 minutes of quiet rest after ~40 minutes '
#  '(immediately post-session)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03045081 PainTracker Self-Manager: a Web-based Platform to Promote and Track Chronic Pain Self-management:
# ('  Question: Did using the PainTracker Self-Manager web program with nurse '
#  'coaching improve confidence to manage pain (pain self-efficacy, PSEQ) in '
#  'patients with chronic pain compared to usual care (PainTracker only) after 3 '
#  'and 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05302414 The Learning Outcome of Resuscitation Teamwork Training in Postgraduate Year Doctors and Nurses:
# ('  Question: Did board game-based resuscitation teamwork training improve '
#  'teamwork knowledge (Knowledge of Teamwork score) in PGY doctors and nurses '
#  'compared to simulation-based and lecture-based learning after 4 and 16 '
#  'weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03620708 Tobacco and Socioeconomic Disadvantage:
# ('  Question: Did a 35-minute motivational counseling session improve '
#  'treatment seeking (contacting a referred quit-smoking service) in '
#  'socioeconomically disadvantaged smokers compared to a written referral only '
#  'after 30 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05302414 The Learning Outcome of Resuscitation Teamwork Training in Postgraduate Year Doctors and Nurses:
# ('  Question: Did board game-based resuscitation teamwork training improve '
#  'teamwork performance (Team Performance Observation Tool score) in '
#  'postgraduate year (PGY) doctors and nurses compared to simulation-based '
#  'resuscitation training after 16 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03605368 VR Intervention to Improve Police Safety:
# ('  Question: Did remote at-home VR police-safety training (Floreo PSM) '
#  'improve police interaction skills (Police Interaction Assessment score) in '
#  'adolescents and adults with autism (ASD) compared to treatment-as-usual (no '
#  'intervention) after about 2 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02420990 Integrated Treatment for Adolescents With ADHD:
# ('  Question: Did family- and home-based behavioral support for ADHD (CASH-AA) '
#  'improve ADHD symptoms and related problems (inattention, '
#  'hyperactivity/impulsivity; delinquency; substance use; '
#  'internalizing/externalizing symptoms) in adolescents with ADHD receiving '
#  'behavioral-only treatment compared to adolescents receiving the behavioral '
#  'program plus medication support (MIP) after one year?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05302414 The Learning Outcome of Resuscitation Teamwork Training in Postgraduate Year Doctors and Nurses:
# ('  Question: Did learning resuscitation teamwork via a board game improve '
#  'teamwork performance (Team Performance Observation Tool score) in PGY '
#  'doctors and nurses in the board game group compared to simulation-based '
#  'learning group after 4 weeks (posttest)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00781079 Do Consumer Providers Enhance Recovery?:
# ('  Question: Did adding a consumer provider to intensive case management '
#  'teams improve psychiatric symptoms (BASIS-R score) in veterans on MHICM '
#  'teams with a consumer provider compared to veterans on MHICM teams with '
#  'usual care after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03344796 UV Exposure Assessed With Wearable Sensor and Sun Protection:
# ('  Question: Did wearing a UV sensor sticker and receiving daily personalized '
#  'text messages with structured goal selection improve acceptability of the UV '
#  'sensor and related text messages (system usability score 6–42; higher '
#  'better) in melanoma survivors in Cohort Study 1 Arm 1 compared to melanoma '
#  'survivors in Cohort Study 1 Arm 2 (daily texts + unstructured goal '
#  'responses) after 21 days?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05302414 The Learning Outcome of Resuscitation Teamwork Training in Postgraduate Year Doctors and Nurses:
# ('  Question: Did board game-based training improve teamwork knowledge '
#  '(Knowledge of Teamwork score) in postgraduate year (PGY) doctors and nurses '
#  'compared to lecture-based training after 4 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03978871 Effect of Emotion Mindsets on Emotion Processing:
# ('  Question: Did teaching a growth emotion mindset (that emotions and the '
#  'teen brain can change) improve frontoparietal network–amygdala connectivity '
#  'during the socioemotional go/no-go task (fMRI) in adolescent girls in the '
#  'growth mindset group compared to adolescent girls in the brain education '
#  'group after post-manipulation baseline?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT06356285 Testing New Ways to Name Antimicrobial Resistance:
# ("  Question: Did seeing a bus-stop poster labeled 'Superbugs' improve correct "
#  'answers on attitude questions about antibiotic resistance (sentiment) in '
#  "people shown a 'Superbugs' bus-stop poster compared to people shown a "
#  "bus-stop poster labeled 'Antimicrobial resistance (AMR)' after 6 weeks?")
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00127790 Treatment of Insomnia Secondary to Chronic Pain:
# ('  Question: Did 10-session cognitive-behavioral therapy for insomnia (CBT-I) '
#  'improve inflammation (blood IL-6 levels) in people with chronic pain '
#  'compared to wait-list control (no treatment) after 10 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02420990 Integrated Treatment for Adolescents With ADHD:
# ('  Question: Did family- and home-based behavioral support for ADHD (CASH‑AA) '
#  'improve ADHD symptoms and related problems (delinquency, substance use, '
#  'internalizing and externalizing symptoms) in adolescents receiving '
#  'behavioral-only treatment compared to adolescents receiving the behavioral '
#  'program plus medication integration (MIP) after one year?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00127790 Treatment of Insomnia Secondary to Chronic Pain:
# ('  Question: Did cognitive-behavioral therapy for pain (CBT-P) improve '
#  'insomnia severity (Insomnia Severity Index score) in patients with chronic '
#  'pain compared to wait-list control (no treatment) after about 10 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00127790 Treatment of Insomnia Secondary to Chronic Pain:
# ('  Question: Did CBT for pain (10 individual sessions) improve IL-6 blood '
#  'levels (interleukin‑6, inflammation marker; lower is better) in patients '
#  'with chronic pain and insomnia compared to wait-list control (no treatment) '
#  'after about 10 weeks (pre to post treatment change)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04240392 Treatment of Pregnant Women With OUD:
# ('  Question: Did onsite collaborative care with a nurse care manager (CC) '
#  'improve patient activation (PAM score: health knowledge, skills and '
#  'confidence to manage illness) in pregnant and postpartum women with opioid '
#  'use disorder (OUD) compared to remote ECHO video mentoring for clinicians '
#  '(tele-support) after baseline, week 26, week 36 and 3 months postpartum?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04890652 Digital Interventions to Treat Hazardous Drinking:
# ('  Question: Did a 4-week digital breathing-based emotion-regulation program '
#  '(telehealth + app) improve drinks per week (average alcoholic beverages per '
#  'week) in risky drinkers with emotional stress compared to Unknown after '
#  'immediately post-intervention and at 30-day follow-up?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03620708 Tobacco and Socioeconomic Disadvantage:
# ('  Question: Did motivational counseling (35 min) improve making a serious '
#  'quit attempt (self-reported) in socioeconomically disadvantaged smokers who '
#  'received motivational counseling (35 min) compared to smokers given only a '
#  'written referral (referral-only) after 30 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01130103 Combination Treatment for Posttraumatic Stress Disorder (PTSD) After the World Trade Center (WTC) Attack:
# ('  Question: Did adding paroxetine (an antidepressant) to prolonged exposure '
#  'therapy improve PTSD symptoms (CAPS score; higher = worse) in WTC attack '
#  'survivors with PTSD compared to placebo plus prolonged exposure therapy '
#  'after 10 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT04240392 Treatment of Pregnant Women With OUD:
# ('  Question: Did onsite collaborative care with a care manager improve '
#  'treatment retention (stayed in treatment without stopping for more than 1 '
#  'month) in pregnant and postpartum women with opioid use disorder (opioid '
#  'addiction) compared to remote video mentorship for clinicians (ECHO '
#  'tele-support) after delivery and 3 months postpartum?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03978871 Effect of Emotion Mindsets on Emotion Processing:
# ('  Question: Did a computer lesson teaching that emotions can change (growth '
#  'emotion mindset) improve confidence in controlling emotions (emotional '
#  'self-efficacy) in adolescent girls given the growth emotion mindset lesson '
#  'compared to adolescent girls given neutral brain education after the lesson?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01130103 Combination Treatment for Posttraumatic Stress Disorder (PTSD) After the World Trade Center (WTC) Attack:
# ('  Question: Did paroxetine (SSRI) plus prolonged exposure therapy improve '
#  'PTSD symptoms (CAPS score; lower is better) in WTC survivors receiving '
#  'paroxetine + prolonged exposure compared to WTC survivors receiving placebo '
#  '+ prolonged exposure after 10 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03978871 Effect of Emotion Mindsets on Emotion Processing:
# ('  Question: Did teaching a growth emotion mindset (that emotions and the '
#  'teenage brain can change) improve amygdala reactivity to negative '
#  'social-evaluation (brain response) in adolescent girls (growth-mindset '
#  'group) compared to adolescent girls (brain-education control) after the '
#  'lesson (post-manipulation)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05417607 A+ Treatment/Feasibility of Adapted ESDM-informed Caregiver Coaching Delivered Remotely for Children With ASD (Autism Spectrum Disorder) and ADHD (Attention Deficit Hyperactivity Disorder):
# ('  Question: Did remote ESDM-informed caregiver coaching (telehealth) improve '
#  'caregiver use of ESDM techniques (P-ESDM fidelity score) in children with '
#  'autism and ADHD and their caregivers compared to Unknown after 9 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00127790 Treatment of Insomnia Secondary to Chronic Pain:
# ('  Question: Did combined CBT for insomnia and pain (CBT‑I/P) improve blood '
#  'IL‑6 levels (interleukin‑6, a marker of inflammation; lower is better) in '
#  'people with chronic pain compared to people on a waitlist (no treatment) '
#  'after about 10 weeks (pre to post treatment)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00793455 Outreach for Patients With Uncompleted Colorectal Cancer Screening Orders:
# ('  Question: Did physician letter plus educational brochure and DVD improve '
#  'colorectal cancer screening completion (stool test, sigmoidoscopy, or '
#  "colonoscopy) in patients who accepted a colonoscopy referral but hadn't "
#  'completed screening compared to usual care after 3 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04890652 Digital Interventions to Treat Hazardous Drinking:
# ('  Question: Did a 4-week digital breathing-based emotion-regulation program '
#  '(telehealth + app) improve drinking days per week (number of drinking days; '
#  'Timeline Follow Back) in risky drinkers with stress-related emotional '
#  'problems compared to Control after the 4-week program and 30-day follow-up?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00316303 Effectiveness of the Screen, Test, Immunize, Reduce Risk, and Refer (STIRR) Intervention for People With Both a Mental and Substance Abuse Disorder:
# ('  Question: Did a 3-session program of screening, testing (HIV/HCV), '
#  'hepatitis A/B vaccination, risk-reduction counseling, and referral improve '
#  'being tested for hepatitis C (self-report) in people with both a mental '
#  'disorder and a substance abuse disorder compared to enhanced treatment as '
#  'usual (comprehensive mental health services, education and referral) after 6 '
#  'months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01130103 Combination Treatment for Posttraumatic Stress Disorder (PTSD) After the World Trade Center (WTC) Attack:
# ('  Question: Did paroxetine (SSRI) plus prolonged exposure therapy improve '
#  'PTSD remission (CAPS ≤20 and CGI change=1) in World Trade Center (WTC) '
#  'attack survivors with PTSD compared to placebo pill plus prolonged exposure '
#  'therapy after 5 and 10 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01709799 Village Interactive Training and Learning Study:
# ('  Question: Did traditional aerobic exercise plus computer brain training '
#  'improve visual processing speed (Sweep Seeker T-score; lower = better) in '
#  'people in the Cognitive Training Plus Exercise group compared to brain '
#  'training alone (no exercise) after 16 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00316303 Effectiveness of the Screen, Test, Immunize, Reduce Risk, and Refer (STIRR) Intervention for People With Both a Mental and Substance Abuse Disorder:
# ('  Question: Did screening, HIV/hepatitis testing, hepatitis A/B vaccination, '
#  'risk-reduction counseling, and referral improve being tested for HIV in '
#  'people with both a mental disorder and a substance abuse disorder compared '
#  'to enhanced treatment as usual (comprehensive mental health care with '
#  'education and referrals) after 6 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00316303 Effectiveness of the Screen, Test, Immunize, Reduce Risk, and Refer (STIRR) Intervention for People With Both a Mental and Substance Abuse Disorder:
# ('  Question: Did screening, testing, hepatitis A/B vaccination, '
#  'risk-reduction counseling, and referral improve referral for hepatitis C '
#  'medical care (self-reported) in people with severe mental illness and '
#  'substance abuse compared to enhanced treatment as usual (comprehensive '
#  'mental health services, education, and referral) after 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01709799 Village Interactive Training and Learning Study:
# ('  Question: Did traditional aerobic exercise plus computer brain training '
#  'improve visual processing speed (Road Tour T‑score; lower = better) in '
#  'people in the exercise + brain training group compared to people in the '
#  'brain training-only group after 16 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01130103 Combination Treatment for Posttraumatic Stress Disorder (PTSD) After the World Trade Center (WTC) Attack:
# ('  Question: Did paroxetine plus prolonged exposure therapy improve remission '
#  'from PTSD (CAPS ≤20 and CGI-change=1) in WTC survivors with PTSD compared to '
#  'placebo pill plus prolonged exposure therapy after 5 and 10 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02037568 Improved Outcome in Allogeneic Hematopoietic Stem Cell Transplant (HSCT) Patients by Reducing Caregiver Distress:
# ('  Question: Did phone/video psychoeducation and relaxation for caregivers '
#  '(fPER) improve patient quality of life (FACT-BMT score) in allogeneic HSCT '
#  'patients with caregivers in fPER compared to allogeneic HSCT patients with '
#  'caregivers in TAU (usual care + workbook) after 6 months post-transplant?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02928952 Mindful Stress Reduction in Diabetes Self-management Education for Veterans:
# ('  Question: Did adding mindfulness training with home practice to diabetes '
#  'education improve diabetes-related distress (PAID score) in Veterans with '
#  'diabetes in DSME + Mind-STRIDE compared to diabetes education alone after 12 '
#  'weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04585919 Paired Promotion of Colorectal Cancer and Social Determinants of Health Screening:
# ('  Question: Did paired outreach offering FIT (stool) tests and social needs '
#  'screening improve colorectal cancer screening completion (any recommended '
#  'method) in patients targeted by the paired outreach compared to patients '
#  'receiving usual care after 14 months post-implementation (vs 13 months '
#  'pre-implementation)?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01454830 Tailored Intervention to Promote Positive Airway Pressure Adherence:
# ('  Question: Did a tailored education, skills training, and belief-focused '
#  'support program improve nightly CPAP use (mean hours/night) in adults with '
#  'newly-diagnosed obstructive sleep apnea (OSA) starting CPAP compared to '
#  'usual care (standard CPAP care) after 1 week?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01454830 Tailored Intervention to Promote Positive Airway Pressure Adherence:
# ('  Question: Did a tailored education, skills, and cognitive-support program '
#  'improve nightly CPAP use (mean hrs/night) in adults with newly diagnosed OSA '
#  'starting CPAP compared to usual care (standard CPAP care) after 3 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04533204 Mnemonic Strategy Versus Spaced Retrieval Training in Those With Mild Cognitive Impairment:
# ('  Question: Did memory strategy training (mnemonic strategies) improve '
#  'memory for trained object-location pairs (percent correct) in people with '
#  'mild cognitive impairment (MCI) compared to spaced retrieval training after '
#  '1 month?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02928952 Mindful Stress Reduction in Diabetes Self-management Education for Veterans:
# ('  Question: Did adding mindfulness training with home practice to diabetes '
#  'education improve diabetes-related distress (PAID score; lower is better) in '
#  'Veterans receiving diabetes education plus mindfulness compared to Veterans '
#  'receiving diabetes education alone (usual care) after 12 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00127790 Treatment of Insomnia Secondary to Chronic Pain:
# ('  Question: Did 10-session CBT for insomnia (CBT‑I) improve insomnia '
#  'severity (Insomnia Severity Index total score) in patients with chronic pain '
#  'compared to wait-list control (no treatment) after about 10 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01454830 Tailored Intervention to Promote Positive Airway Pressure Adherence:
# ('  Question: Did a tailored program (individualized education, skills '
#  'training, cognitive support) improve nightly CPAP use (average hours/night) '
#  'in adults with newly-diagnosed OSA starting CPAP compared to usual care '
#  '(standard CPAP care) after 1 month?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03204643 Evaluation of Behavioral Health-Virtual Patient Navigation Team (BH-VPN):
# ('  Question: Did access to behavioral-health patient navigators and '
#  'navigation services added to usual care improve ED-to-inpatient admission '
#  'rate after a behavioral health consult (ED-to-inpatient conversion) in '
#  'patients receiving consistent usual care plus behavioral-health patient '
#  'navigators compared to patients receiving usual care after 5 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01709799 Village Interactive Training and Learning Study:
# ('  Question: Did adding traditional aerobic exercise to brain training '
#  'improve visual processing speed and accuracy on the Bird Safari game (Bird '
#  'Safari T-score; lower = better) in the cognitive training plus exercise '
#  'group compared to the cognitive training group after 16 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03978871 Effect of Emotion Mindsets on Emotion Processing:
# ('  Question: Did learning a growth emotion mindset (teaching that emotions '
#  'and the teen brain can change) improve emotion regulation strategies used '
#  'during a social stress test in girls in the growth mindset group compared to '
#  'girls in the brain education group after the lesson?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02791399 A Patient-Centered Intervention to Improve Opioid Safety:
# ('  Question: Did adding a nurse care manager who tracks opioid safety and '
#  'meets patients improve risk of prescription opioid misuse (COMM score) in '
#  'patients on long-term prescription opioids for chronic non-cancer pain '
#  'compared to treatment as usual after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00640653 Efficacy of an Abstinence-Only HIV Risk-Reduction Intervention for Young African-American Adolescents:
# ('  Question: Did abstinence-only sex education improve abstinence (not having '
#  'sex) in young African-American adolescents compared to health-promotion '
#  'control after 24 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03810534 Connect-Home Clinical Trial:
# ('  Question: Did Connect-Home transitional care (SNF discharge planning + '
#  'nurse home visit within 24 h) improve preparedness for discharge (Care '
#  'Transitions Measure-15 score) in seriously ill SNF patients discharged to '
#  'home and their caregivers compared to usual SNF discharge planning (no '
#  'structured home visit) after 7 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00708461 Environmental Intervention for Weight Gain Prevention:
# ('  Question: Did worksite environmental changes to promote healthier food '
#  'choices, physical activity, and weight monitoring improve body mass index '
#  '(BMI, kg/m2) in employees at worksites with the environmental intervention '
#  'compared to employees at control worksites (no treatment) after 24 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00127790 Treatment of Insomnia Secondary to Chronic Pain:
# ('  Question: Did CBT for insomnia and pain (10 sessions of '
#  'cognitive-behavioral therapy for sleep and pain) improve pain severity (MPI '
#  'Pain Severity subscale score; lower = less pain) in people with chronic pain '
#  'and insomnia compared to wait-list control (no treatment) after about 10 '
#  'weeks (pre to post treatment)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00316303 Effectiveness of the Screen, Test, Immunize, Reduce Risk, and Refer (STIRR) Intervention for People With Both a Mental and Substance Abuse Disorder:
# ('  Question: Did screening, blood testing, hepatitis A/B vaccination, '
#  'risk-reduction counseling, and referral to care improve rates of hepatitis B '
#  'testing in people with both a mental illness and a substance abuse disorder '
#  'compared to enhanced treatment as usual (comprehensive mental health '
#  'services, education, and referral for testing/vaccination) after 6 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05159622 Water Up@ At Home: An Intervention to Replace Sugary Drinks With Water:
# ('  Question: Did replacing sugary drinks with filtered tap water using a '
#  "home-based curriculum and filter improve parents' sugary drink intake "
#  '(oz/day) in low-income Early Head Start parents (of 6‑month–3‑year olds) '
#  'compared to standard EHS home-visiting education (control) after 12 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03978871 Effect of Emotion Mindsets on Emotion Processing:
# ('  Question: Did a growth emotion‑mindset lesson improve emotion regulation '
#  'self‑efficacy (belief in ability to manage emotions) in adolescent girls '
#  'given the growth emotion‑mindset induction compared to girls given brain '
#  'education after the lesson (pre vs post)?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01183689 Study of Novel Approaches for Prevention:
# ('  Question: Did periodic larger diet and exercise changes to lose weight '
#  'improve average weight change in young adults (18–35 yrs) with BMI 21–30 '
#  'compared to self-guided control (one-session education + newsletters) after '
#  '3 years?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02665468 eHealth Partnered Evaluation Initiative:
# ('  Question: Did proactive support (reminders, motivational messages, '
#  'education) to encourage secure messaging use improve use of secure messaging '
#  '(sent at least one secure message) in Veterans receiving the supported '
#  'adoption intervention compared to Veterans receiving usual care (no extra '
#  'support) after six months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01221090 Diabetes Self-Management Models to Reduce Health Disparities:
# ('  Question: Did 6-week diabetes self-management classes improve blood sugar '
#  'control (HbA1c) in adults with type 2 diabetes compared to usual care after '
#  '12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04950686 Study of Long-term Efficacy and Mechanisms Underlying the Impact of a Web-based Sexual and Relationship Health Promotion Program With Young Adult Community College Students:
# ('  Question: Did a web-based media-literacy sexual and relationship health '
#  'program improve relationship satisfaction (7-item 1–5 scale) in community '
#  'college students (ages 18–19) compared to a wait-list control (no program) '
#  'after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03972969 Highly Challenging Balance Program to Reduce Fall Rate in PD:
# ('  Question: Did facility-based structured exercise improve fall rate (number '
#  "of falls) in Veterans with mild-to-moderate Parkinson's disease compared to "
#  'health education after 3 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02037568 Improved Outcome in Allogeneic Hematopoietic Stem Cell Transplant (HSCT) Patients by Reducing Caregiver Distress:
# ('  Question: Did caregivers receiving phone/video psychoeducation and '
#  'relaxation training (fPER) improve caregiver distress (lower is better; '
#  'composite of depression, anxiety, and stress) in caregivers of allogeneic '
#  'HSCT patients compared to caregivers given treatment as usual (TAU) after 6 '
#  'months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00316303 Effectiveness of the Screen, Test, Immunize, Reduce Risk, and Refer (STIRR) Intervention for People With Both a Mental and Substance Abuse Disorder:
# ('  Question: Did STIRR (screening, testing, hepatitis A/B vaccination, risk '
#  'counseling, and referrals) improve rates of hepatitis A and B immunization '
#  'in people with both a severe mental illness and a substance abuse disorder '
#  'compared to enhanced usual care (mental health services, education, referral '
#  'for testing/vaccines) after 6 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05803603 Social Work Assistance and Stipends for Housing (SASH):
# ('  Question: Did monthly $500 housing stipends and social work help to find '
#  'housing improve housing (being housed) in people with opioid use disorder '
#  '(on medication) who are homeless compared to Unknown after 12 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02334215 A Randomized Trial of Interim Methadone and Patient Navigation Initiated in Jail:
# ('  Question: Did starting methadone in jail plus a patient navigator improve '
#  'entry into opioid treatment (OUD treatment) in people starting methadone in '
#  'jail with navigation compared to people starting methadone in jail without '
#  'navigation after 30 days post-release?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01709799 Village Interactive Training and Learning Study:
# ('  Question: Did adding traditional aerobic exercise to brain training '
#  'improve divided attention (Jewel Diver T-score) in people doing exercise '
#  'plus brain training compared to people doing brain training alone after 16 '
#  'weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT04078035 Biological Response to Brief Psychological Challenge:
# ('  Question: Did doing a 5-minute evaluative speech (stress task) improve '
#  'cell-free mitochondrial DNA (blood mtDNA) in healthy adults in the speech '
#  'session compared to healthy adults resting quietly after 2 hours?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04950686 Study of Long-term Efficacy and Mechanisms Underlying the Impact of a Web-based Sexual and Relationship Health Promotion Program With Young Adult Community College Students:
# ('  Question: Did a web-based media literacy sexual and relationship health '
#  'program improve relationship satisfaction (how well your partner meets your '
#  'needs) in young adult community college students (ages 18–19) compared to a '
#  'web-based sexual and relationship health program without media literacy '
#  'after 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03978871 Effect of Emotion Mindsets on Emotion Processing:
# ('  Question: Did teaching a growth emotion mindset (teens learn emotions and '
#  'brain can change and how to manage emotions) improve response speed on a '
#  'social go/no-go test (reaction time in ms; higher = slower) in adolescent '
#  'girls given growth emotion mindset training compared to adolescent girls '
#  'given neutral brain education after the lesson?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02334215 A Randomized Trial of Interim Methadone and Patient Navigation Initiated in Jail:
# ('  Question: Did starting methadone in jail plus 3 months of patient '
#  'navigation improve opioid use disorder diagnosis (DSM-5) in the past 30 days '
#  'in people receiving methadone plus patient navigation compared to people '
#  'receiving methadone only after 6 months post-release?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01709799 Village Interactive Training and Learning Study:
# ('  Question: Did adding traditional aerobic exercise to brain training '
#  'improve visual processing speed (Sweep Seeker T-score; lower = better) in '
#  'participants doing aerobic exercise plus brain training compared to '
#  'participants doing brain training alone (no exercise) after 16 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT03426787 Helping Empower Liver and Kidney Patients:
# ('  Question: Did using a plain-language personalized decision aid improve '
#  'confidence in making treatment decisions (Decision Self-Efficacy score) in '
#  'people with liver or kidney disease compared to their baseline (pre-test) '
#  'scores after viewing the decision aid (measured immediately, within 30 '
#  'minutes)?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04240392 Treatment of Pregnant Women With OUD:
# ('  Question: Did onsite collaborative care with a care manager improve '
#  'ability to manage their health (Patient Activation Measure, PAM) in pregnant '
#  'and postpartum women with opioid use disorder (opioid addiction) compared to '
#  'remote video-based provider mentorship (ECHO) after baseline, 26 and 36 '
#  'weeks of pregnancy, and 3 months postpartum?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02334215 A Randomized Trial of Interim Methadone and Patient Navigation Initiated in Jail:
# ('  Question: Did starting methadone in jail plus a patient navigator improve '
#  'entry into opioid treatment in people who began methadone in jail and '
#  'received patient navigation compared to people who began methadone in jail '
#  'without navigation (methadone only) after 30 days post-release?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02791399 A Patient-Centered Intervention to Improve Opioid Safety:
# ('  Question: Did adding a nurse care manager to monitor opioid safety (track '
#  'urine drug tests and support clinicians) improve urine drug test results '
#  '(fewer positive tests for illicit or non-prescribed drugs) in patients on '
#  'long-term prescription opioids for chronic pain compared to treatment as '
#  'usual after 6 and 12 months?')
#   Answer: NO
# ...
#  'info (control) after 6 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00625807 Comparison of Two Behavioral Treatments for Stress Reduction:
# ('  Question: Did an 8-week nightly 20-minute relaxation/meditation course '
#  'improve worry (Penn State Worry Questionnaire score) in people in the '
#  'Relaxation Response course compared to another stress-reduction course after '
#  '8 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02079987 An Emergency Department-To-Home Intervention to Improve Quality of Life and Reduce Hospital Use:
# ('  Question: Did a home visit and 3 follow-up calls by an Area Agency on '
#  'Aging coach improve anxiety (PROMIS T-score) in older, chronically ill ED '
#  'patients given the ED-to-home care transition compared to usual care '
#  '(standard ED discharge instructions) after 60 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02054715 Multimedia Psychoeducation or Print Education in Preparing Cancer Patients for Decision Making About Clinical Trials:
# ('  Question: Did reading an NCI print booklet (print education) improve '
#  'preparedness to decide about joining a clinical trial (Preparation for '
#  'Decision Making Scale score) in cancer patients considering clinical trial '
#  'participation compared to patients who viewed a DVD and booklet (multimedia '
#  'psychoeducation) after 3–7 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03130699 Dulce Digital-Me: An Adaptive mHealth Intervention for Underserved Hispanics With Diabetes:
# ('  Question: Did one-size-fits-all educational texts plus nurse monitoring of '
#  'blood glucose improve systolic blood pressure (top blood pressure number, '
#  'SBP) in Hispanic adults of low SES with poorly controlled type 2 diabetes on '
#  'Dulce Digital compared to Dulce Digital-Me (personalized texts with '
#  'goal-setting and feedback delivered automatically or by a medical assistant) '
#  'after 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00064844 Combination Nicotine Replacement for Alcoholic Smokers:
# ('  Question: Did nicotine patch plus active nicotine gum improve smoking '
#  'abstinence (carbon monoxide–verified) in smokers with alcohol problems '
#  'compared to nicotine patch plus placebo gum after 12 months after smoking '
#  'quit date?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05479435 Comparison Effects Of Different Exercise Approaches On Type 2 DM Women:
# ('  Question: Did a tailored exercise program with weekly motivational support '
#  'and home exercise plan improve functional mobility (Timed Up and Go test '
#  'time) in women with type 2 diabetes compared to a video-delivered home '
#  'exercise program after 12 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05560425 Pilot Study on Training Emerging Adults Skills in Navigating College:
# ('  Question: Did mindfulness and meditation training (daily 10-min practice '
#  'and logging) improve compliance with independent skills practice (average '
#  'number of practice/journal entries, score 0-24) in freshman college students '
#  'with a history of binge drinking compared to navigating college training '
#  '(journaling control) after 6 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05479435 Comparison Effects Of Different Exercise Approaches On Type 2 DM Women:
# ('  Question: Did a tailored home exercise program with weekly motivational '
#  'support improve diastolic blood pressure (lower is better) in women with '
#  'type 2 diabetes compared to a video-based home exercise program after 12 '
#  'weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05479435 Comparison Effects Of Different Exercise Approaches On Type 2 DM Women:
# ('  Question: Did a tailored exercise program with weekly motivational support '
#  'improve systolic blood pressure (top blood pressure number) in women with '
#  'type 2 diabetes in the tailored exercise group compared to women with type 2 '
#  'diabetes in supervised group exercise after 12 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT05479435 Comparison Effects Of Different Exercise Approaches On Type 2 DM Women:
# ('  Question: Did a tailored exercise program with weekly motivational support '
#  'and an activity diary improve fasting blood sugar (fasting plasma glucose, '
#  'mg/dL) in women with type 2 diabetes receiving the tailored program compared '
#  'to women with type 2 diabetes doing video-based home exercises after 12 '
#  'weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01600131 RESCUE Stroke Caregiver Website to Enhance Discharge Planning:
# ('  Question: Did online problem-solving training (RESCUE website + messaging) '
#  'improve caregiver burden—task difficulty (Oberst Caregiving Burden Scale '
#  'score) in stroke caregivers in the caregiver education and support group '
#  'compared to caregivers receiving standard care after 11 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02079987 An Emergency Department-To-Home Intervention to Improve Quality of Life and Reduce Hospital Use:
# ('  Question: Did a home visit plus 3 follow-up calls from an Area Agency on '
#  'Aging care coach improve physical function (self-reported physical ability; '
#  'PROMIS T-score) in older, chronically ill ED patients assigned to the '
#  'ED-to-home care transition compared to usual care (standard ED discharge '
#  'instructions) after 60 days?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT03337139 FitLink: Improving Weight Loss Maintenance by Using Digital Data to Provide Support and Accountability:
# ("  Question: Did sharing participants' weight, activity, and food data with "
#  'coaches and tailoring texts/calls improve weekly minutes of '
#  'moderate-to-vigorous physical activity (MVPA) in overweight or obese adults '
#  'in a weight-loss program compared to remote coaching based on self-report '
#  'after 13 and 52 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05479435 Comparison Effects Of Different Exercise Approaches On Type 2 DM Women:
# ('  Question: Did a personalized exercise program with weekly motivational '
#  'support improve bad cholesterol (low-density lipoprotein, LDL) in women with '
#  'type 2 diabetes compared to video-based home exercise after 12 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02090634 Texting to Improve Adherence in HIV+ With Bipolar Disorder:
# ('  Question: Did daily personalized medication reminder texts plus '
#  'psychoeducation improve percent adherence to HIV and psychotropic '
#  'medications (measured by electronic pill‑bottle monitoring, MEMS) in people '
#  'with HIV and bipolar disorder compared to psychoeducation with daily '
#  'mood-check texts (no medication reminders) after 4 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05479435 Comparison Effects Of Different Exercise Approaches On Type 2 DM Women:
# ('  Question: Did a personalized exercise program with weekly motivational '
#  'support and an activity diary improve blood sugar control (HbA1c) in women '
#  'with type 2 diabetes compared to video-based home exercise after 12 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02306122 Pharmacy Home Adherence Reporting and Monitoring Outcomes Study:
# ('  Question: Did pharmacist calls only if the doctor requests improve '
#  'refilling a late prescription (resolution of nonadherence) in patients whose '
#  'doctors received adherence alerts and could request a pharmacist call '
#  'compared to patients with no information sent to their doctor (no pharmacist '
#  'help) after 30 days?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT04042909 Using Counter Attitudinal Advocacy to Change Drinking Behavior:
# ('  Question: Did saying and publicly stating self-generated strategies to '
#  'avoid alcohol-related harms improve alcohol-related consequences (Young '
#  'Adult Alcohol Consequences Questionnaire) in heavy-drinking college students '
#  'compared to assessment-only control (no intervention) after 6 months?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01302379 Reach for Health Study: Obesity-related Mechanisms and Mortality in Breast Cancer Survivors:
# ('  Question: Did metformin plus phone-based diet and exercise coaching '
#  'improve sex hormone–binding globulin (SHBG) percent change in breast cancer '
#  'survivors compared to placebo plus phone-based diet and exercise coaching '
#  'after change from baseline to 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04042909 Using Counter Attitudinal Advocacy to Change Drinking Behavior:
# ('  Question: Did publicly stating self-generated strategies to avoid alcohol '
#  'harms improve drinking (drinks per week) in heavy-drinking college students '
#  'with alcohol-related problems compared to assessment-only control (no '
#  'intervention) after 6 months?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT01444027 Hospice Problem Solving Intervention:
# ('  Question: Did face-to-face problem-solving therapy (PST) improve caregiver '
#  'anxiety (GAD-7 score; lower = less anxiety) in caregivers in the '
#  'face-to-face group compared to caregivers in the video PST group after 4 '
#  'weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT00856609 The Effects of Exenatide (Byetta ) on Energy Expenditure and Weight Loss in Nondiabetic Obese Subjects:
# ('  Question: Did twice-daily exenatide injections (Byetta) improve calorie '
#  'intake (energy intake; lower is better) in obese people without diabetes '
#  'compared to placebo injections after 3 days of treatment (Days 12–14 vs '
#  'baseline Days 6–8)?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT02090634 Texting to Improve Adherence in HIV+ With Bipolar Disorder:
# ('  Question: Did personalized daily text reminders for HIV and psych '
#  'medications improve percent medication adherence (by electronic bottle '
#  'monitoring) in HIV+ people with bipolar disorder (iTAB group) compared to '
#  'psychoeducation with daily mood-check texts (no medication reminders) after '
#  '4 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05479435 Comparison Effects Of Different Exercise Approaches On Type 2 DM Women:
# ('  Question: Did a tailored exercise program with weekly motivational support '
#  'improve physical activity level (MET-min/week) in women with type 2 diabetes '
#  'in the Blue Prescription group compared to video-based home exercise after '
#  '12 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT05479435 Comparison Effects Of Different Exercise Approaches On Type 2 DM Women:
# ('  Question: Did a tailored exercise program with weekly motivational support '
#  'improve HDL cholesterol (good cholesterol) in women with type 2 diabetes '
#  'compared to supervised group exercise after 12 weeks?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT04173663 Advocating for Supports to Improve Service Transitions:
# ('  Question: Did parents attending a 12-week ASSIST advocacy training improve '
#  "their youth's employment or post-secondary education (measured by the "
#  'Vocational Index) in parents of transition-aged youth with autism compared '
#  'to parents given the ASSIST binder and written materials only after 6 months '
#  'post-intervention?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT00625807 Comparison of Two Behavioral Treatments for Stress Reduction:
# ('  Question: Did an 8-week mindfulness meditation course (MBSR) with nightly '
#  '20-minute practice improve worry/stress (Penn State Worry Questionnaire, '
#  'PSWQ) in participants in the MBSR course compared to Unknown after 8 weeks?')
#   Answer: YES
# ------------------------------------------------------------
# Study NCT01790581 Balance Training vs. Balance Training w/ STARS:
# ('  Question: Did 4-week supervised balance training program improve dynamic '
#  'balance (Star Excursion Balance Test) in people with chronic ankle '
#  'instability (CAI) compared to balance training with STARS (sensory-targeted '
#  'ankle techniques) after 1 day?')
#   Answer: NO
# ------------------------------------------------------------
# Study NCT02020252 Effect of Multi-Media Tool on Enrollment in Oncology Clinical Trials:
# ('  Question: Did using an interactive touchscreen clinical-trial education '
#  'tool improve attitudes, knowledge, and willingness about cancer clinical '
#  'trials in new lung, stomach, or pancreatic cancer patients who used the '
#  'touchscreen compared to their responses before using the tool after the '
#  'visit (immediately)?')
#   Answer: NO
# ------------------------------------------------------------
# <>:4: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
# /var/folders/sl/nv_r__ss6dj_bn0prgcrsgvr0000gn/T/ipykernel_63096/1349048745.py:4: SyntaxWarning: "is not" with 'str' literal. Did you mean "!="?
#   succ = o.p_value.value < 0.05 and o.p_value.comparator is not ">"
# PrimaryOutcome(nct_id='NCT02020252', id='NCT02020252_po_0', title='Clinical Trials Attitudes, Knowledge, and Interest', description='We hypothesized that our interactive educational tool would improve patient receptivity, willingness, knowledge, self-efficacy and positive attitudes regarding therapeutic cancer clinical trials through the use of patient-friendly technology in the immediate pre-visit period. Patients used the TT to self-administer 24 items from the Clinical Trial questionnaire developed by Jacobsen and colleagues measuring Receptivity (range: 1-5), Willingness (range: 1-5), Knowledge about cancer clinical trials (range: 0-6), Positive Attitudes toward clinical trials (range: 1-5), and Self-Efficacy (range: 1-5). A high score for each subscale represents a more favorable outcome.', population_description='New lung, gastric and pancreatic cancer patients.', timeframe='Immediately after the visit.', groups=[Group(id='OG000', title='Touchscreen Participants', description="New lung, gastric and pancreatic cancer patients presenting to the University of Chicago outpatient oncology clinics, a large research institution located on Chicago's Southside, were identified for study accrual, using the electronic scheduling system.\n\nTesting an interactive technology in a diverse health literary population: Enrollment in therapeutic cancer trials remains low, and is especially challenging for patients with low health literacy. We tested an interactive technology designed for patients with diverse health literacy skills aimed at improving patient receptiveness, willingness, knowledge, self-efficacy and positive attitudes regarding clinical trials.", num_participants='120', interventions=[Intervention(name='Testing an interactive technology in a diverse health literary population', type='BEHAVIORAL', description='Enrollment in therapeutic cancer trials remains low, and is especially challenging for patients with low health literacy. We tested an interactive technology designed for patients with diverse health literacy skills aimed at improving patient receptiveness, willingness, knowledge, self-efficacy and positive attitudes regarding clinical trials.', arm_group_labels=['Touchscreen Participants'])])], p_value=PValue(comparator='=', value=0.307))
